# %% [markdown]
# # params-iterable-vs-groups — faded example 1: Detect and wrap flat tensor input
#
# > Practice drill from [Delta Drills](https://delta-drills.vercel.app). Atom: `params-iterable-vs-groups`. The last cell reports your progress on the `Config: params iterable vs groups` subtopic back to Delta Drills.
#
# **Most of the code is already written — complete the one blanked step**, run the test to check it, then run the last cell to record your progress.

# %% [markdown]
# ## Setup

# %%
import numpy as np
import torch as t
from torch import Tensor
import einops
from einops import rearrange, reduce, repeat

t.manual_seed(0)
np.random.seed(0)

# %% [markdown]
# ## Connect to Delta Drills
#
# Paste your Delta Drills auth token below so this drill can report progress on the `Config: params iterable vs groups` subtopic. Copy it from your Delta Drills account page.
#
# This standalone exercises the atom **`params-iterable-vs-groups`** (exercise 1). Completion fires the beacon at the bottom.

# %%
# === Delta Drills auth ===
DD_TOKEN = ""  # paste your token here, then run this cell
DD_ATOM_ID = "params-iterable-vs-groups"
DD_SUBTOPIC = "Config: params iterable vs groups"
DD_BACKEND_URL = "https://delta-drills-backend.fly.dev"

_dd_passed = set()

# %% [markdown]
# ## Concept
#
# _First time on this topic? Run the **Setup** cell above and skim it: every class and helper mentioned below is defined there. You don't need to have done any other drill first._
#
# The dispatch in `Optimizer.__init__` branches on the type of the first element after materializing the params iterable to a list. When the first element is a `torch.Tensor`, all elements form a flat collection and must be wrapped into a single group dict containing all the tensors and the default learning rate.

# %% [markdown]
# ## Faded exercise 1
#
# ### Exercise — Detect and wrap flat tensor input
#
# Complete `normalize_flat_detect(params, default_lr)`. The function must:
# 1. Materialize `params` to a list.
# 2. Guard against empty input with `ValueError`.
# 3. If the first element `isinstance(first, t.Tensor)`, wrap all tensors in a single group dict.
# 4. Otherwise raise `TypeError`.
#
# Fill in the single missing step — the wrap-and-return for the tensor branch.
#
# **Your task:** complete the one blanked step in the code cell below. The surrounding code, function signatures, and variable names are given — work out the missing expression yourself, then run the test.

# %%
import torch as t

def normalize_flat_detect(params, default_lr):
    materialized = list(params)
    if not materialized:
        raise ValueError('optimizer got an empty parameter list')
    first = materialized[0]
    if isinstance(first, t.Tensor):
        raise NotImplementedError()  # TODO: fill in this step — read the prompt cell above
    raise TypeError(f'Expected tensor, got {type(first).__name__}')

# Test
t.manual_seed(1)
a = t.randn(3, 3)
b = t.randn(3)
result = normalize_flat_detect([a, b], default_lr=0.005)
print(result[0]['lr'], len(result[0]['params']))


def _test():
    import torch as t
    t.manual_seed(1)
    a = t.randn(3, 3)
    b = t.randn(3)
    result = normalize_flat_detect([a, b], default_lr=0.005)
    assert len(result) == 1, f'expected 1 group, got {len(result)}'
    assert result[0]['lr'] == 0.005
    assert len(result[0]['params']) == 2
    assert result[0]['params'][0] is a
    assert result[0]['params'][1] is b
    try:
        normalize_flat_detect([], 0.01)
        assert False, 'should have raised ValueError'
    except ValueError:
        pass


try:
    _test()
    _dd_passed.add('faded1')
    print('[Delta Drills] faded1 passed.')
except AssertionError as _e:
    print('Test failed:', _e)

# %% [markdown]
# ## Report your progress
#
# Run the cell below to send your progress to Delta Drills. It only counts if the test above passed.

# %%
# === Delta Drills completion beacon ===
import urllib.request as _dd_req, json as _dd_json

_DD_REQUIRED = {'faded1'}

def report_completion():
    missing = _DD_REQUIRED - _dd_passed
    if missing:
        print(f"[Delta Drills] {sorted(missing)} not yet passing — fix the cell above, then re-run this one.")
        return
    if not DD_TOKEN:
        print('[Delta Drills] DD_TOKEN is empty — completion not reported.')
        return
    body = _dd_json.dumps({
        'exercise_title': f'procedural-drill:{DD_ATOM_ID}:faded1',
        'subtopics': [DD_SUBTOPIC],
        'feedback': 'somewhat',
        'correct': True,
    }).encode('utf-8')
    req = _dd_req.Request(
        f'{DD_BACKEND_URL}/api/practice/arena-rating',
        data=body,
        headers={
            'Content-Type': 'application/json',
            'Authorization': f'Bearer {DD_TOKEN}',
        },
        method='POST',
    )
    try:
        with _dd_req.urlopen(req, timeout=5) as r:
            resp = _dd_json.loads(r.read())
        print(f'[Delta Drills] reported {DD_ATOM_ID} (subtopic={DD_SUBTOPIC!r})')
        print(f'[Delta Drills] EWMA updated: {resp}')
    except Exception as e:
        print(f'[Delta Drills] beacon failed: {e}')

report_completion()

# %% [markdown]
# <details><summary>Solution</summary>
#
# ```python
# import torch as t
#
# def normalize_flat_detect(params, default_lr):
#     materialized = list(params)
#     if not materialized:
#         raise ValueError('optimizer got an empty parameter list')
#     first = materialized[0]
#     if isinstance(first, t.Tensor):
#         return [{'params': materialized, 'lr': default_lr}]
#     raise TypeError(f'Expected tensor, got {type(first).__name__}')
#
# # Test
# t.manual_seed(1)
# a = t.randn(3, 3)
# b = t.randn(3)
# result = normalize_flat_detect([a, b], default_lr=0.005)
# print(result[0]['lr'], len(result[0]['params']))
# ```
# </details>
