# %% [markdown]
# # dataclasses-replace-args — faded example 1: Sweep a single named field across a list of values
#
# > Practice drill from [Delta Drills](https://delta-drills.vercel.app). Atom: `dataclasses-replace-args`. The last cell reports your progress on the `Config: dataclasses.replace args` subtopic back to Delta Drills.
#
# **Most of the code is already written — complete the one blanked step**, run the test to check it, then run the last cell to record your progress.

# %% [markdown]
# ## Setup

# %%
import numpy as np
import torch as t
from torch import Tensor
import einops
from einops import rearrange, reduce, repeat

t.manual_seed(0)
np.random.seed(0)

# %% [markdown]
# ## Connect to Delta Drills
#
# Paste your Delta Drills auth token below so this drill can report progress on the `Config: dataclasses.replace args` subtopic. Copy it from your Delta Drills account page.
#
# This standalone exercises the atom **`dataclasses-replace-args`** (exercise 1). Completion fires the beacon at the bottom.

# %%
# === Delta Drills auth ===
DD_TOKEN = ""  # paste your token here, then run this cell
DD_ATOM_ID = "dataclasses-replace-args"
DD_SUBTOPIC = "Config: dataclasses.replace args"
DD_BACKEND_URL = "https://delta-drills-backend.fly.dev"

_dd_passed = set()

# %% [markdown]
# ## Concept
#
# _First time on this topic? Run the **Setup** cell above and skim it: every class and helper mentioned below is defined there. You don't need to have done any other drill first._
#
# A one-axis sweep varies exactly one field while copying the rest from base. `dataclasses.replace(base, **{field: value})` lets the field name be chosen at runtime: you build a one-key dict from the field-name string and splat it. Base is never mutated.

# %% [markdown]
# ## Faded exercise 1
#
# ### Faded — sweep one runtime-named field across values
#
# Implement `sweep_field(base, field, values)`. Given a base `TrainingArgs`, a field *name* string (e.g. `'epochs'`), and a list of `values`, return one fresh variant per value with that single field overridden and all others copied from base. Order matches `values`. Complete the blanked line that builds each variant.
#
# **Your task:** complete the one blanked step in the code cell below. The surrounding code, function signatures, and variable names are given — work out the missing expression yourself, then run the test.

# %%
from dataclasses import dataclass, replace

@dataclass
class TrainingArgs:
    lr: float = 1e-3
    batch_size: int = 32
    epochs: int = 10
    optimizer_name: str = 'adam'

    def __post_init__(self):
        if self.lr <= 0:
            raise ValueError(f'lr must be > 0, got {self.lr}')
        if self.batch_size < 1:
            raise ValueError(f'batch_size must be >= 1, got {self.batch_size}')

def sweep_field(base, field, values):
    out = []
    for v in values:
        variant = None  # TODO: fill in this step — read the prompt cell above
        out.append(variant)
    return out


def _test():
    base = TrainingArgs()
    vals = [1, 5, 20]
    out = sweep_field(base, 'epochs', vals)
    assert len(out) == 3
    for variant, v in zip(out, vals):
        assert isinstance(variant, TrainingArgs)
        assert variant.epochs == v
        assert variant is not base
        # untouched fields copied from base
        assert variant.lr == base.lr
        assert variant.batch_size == base.batch_size
        assert variant.optimizer_name == base.optimizer_name
    # base not mutated
    assert base.epochs == 10
    # works on a different field too
    bs_out = sweep_field(base, 'batch_size', [8, 16])
    assert [x.batch_size for x in bs_out] == [8, 16]
    assert all(x.lr == base.lr for x in bs_out)


try:
    _test()
    _dd_passed.add('faded1')
    print('[Delta Drills] faded1 passed.')
except AssertionError as _e:
    print('Test failed:', _e)

# %% [markdown]
# ## Report your progress
#
# Run the cell below to send your progress to Delta Drills. It only counts if the test above passed.

# %%
# === Delta Drills completion beacon ===
import urllib.request as _dd_req, json as _dd_json

_DD_REQUIRED = {'faded1'}

def report_completion():
    missing = _DD_REQUIRED - _dd_passed
    if missing:
        print(f"[Delta Drills] {sorted(missing)} not yet passing — fix the cell above, then re-run this one.")
        return
    if not DD_TOKEN:
        print('[Delta Drills] DD_TOKEN is empty — completion not reported.')
        return
    body = _dd_json.dumps({
        'exercise_title': f'procedural-drill:{DD_ATOM_ID}:faded1',
        'subtopics': [DD_SUBTOPIC],
        'feedback': 'somewhat',
        'correct': True,
    }).encode('utf-8')
    req = _dd_req.Request(
        f'{DD_BACKEND_URL}/api/practice/arena-rating',
        data=body,
        headers={
            'Content-Type': 'application/json',
            'Authorization': f'Bearer {DD_TOKEN}',
        },
        method='POST',
    )
    try:
        with _dd_req.urlopen(req, timeout=5) as r:
            resp = _dd_json.loads(r.read())
        print(f'[Delta Drills] reported {DD_ATOM_ID} (subtopic={DD_SUBTOPIC!r})')
        print(f'[Delta Drills] EWMA updated: {resp}')
    except Exception as e:
        print(f'[Delta Drills] beacon failed: {e}')

report_completion()

# %% [markdown]
# <details><summary>Solution</summary>
#
# ```python
# from dataclasses import dataclass, replace
#
# @dataclass
# class TrainingArgs:
#     lr: float = 1e-3
#     batch_size: int = 32
#     epochs: int = 10
#     optimizer_name: str = 'adam'
#
#     def __post_init__(self):
#         if self.lr <= 0:
#             raise ValueError(f'lr must be > 0, got {self.lr}')
#         if self.batch_size < 1:
#             raise ValueError(f'batch_size must be >= 1, got {self.batch_size}')
#
# def sweep_field(base, field, values):
#     out = []
#     for v in values:
#         variant = replace(base, **{field: v})
#         out.append(variant)
#     return out
# ```
# </details>
