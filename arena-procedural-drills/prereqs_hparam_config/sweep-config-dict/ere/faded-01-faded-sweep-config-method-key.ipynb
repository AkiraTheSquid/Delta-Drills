# %% [markdown]
# # sweep-config-dict — faded example 1: Sweep Config — fill in the method and metric block
#
# > Practice drill from [Delta Drills](https://delta-drills.vercel.app). Atom: `sweep-config-dict`. The last cell reports your progress on the `Config: wandb sweep config dict` subtopic back to Delta Drills.
#
# **Most of the code is already written — complete the one blanked step**, run the test to check it, then run the last cell to record your progress.

# %% [markdown]
# ## Setup

# %%
import numpy as np
import torch as t
from torch import Tensor
import einops
from einops import rearrange, reduce, repeat

t.manual_seed(0)
np.random.seed(0)

# %% [markdown]
# ## Connect to Delta Drills
#
# Paste your Delta Drills auth token below so this drill can report progress on the `Config: wandb sweep config dict` subtopic. Copy it from your Delta Drills account page.
#
# This standalone exercises the atom **`sweep-config-dict`** (exercise 1). Completion fires the beacon at the bottom.

# %%
# === Delta Drills auth ===
DD_TOKEN = ""  # paste your token here, then run this cell
DD_ATOM_ID = "sweep-config-dict"
DD_SUBTOPIC = "Config: wandb sweep config dict"
DD_BACKEND_URL = "https://delta-drills-backend.fly.dev"

_dd_passed = set()

# %% [markdown]
# ## Concept
#
# _First time on this topic? Run the **Setup** cell above and skim it: every class and helper mentioned below is defined there. You don't need to have done any other drill first._
#
# Every wandb sweep config starts with three required keys: `'method'`, `'metric'`, and `'parameters'`. The method controls how the agent chooses new hyperparameter values. For Bayesian optimization, use `'bayes'`. The metric block tells wandb which logged value to optimize and in which direction.

# %% [markdown]
# ## Faded exercise 1
#
# The parameters block is already complete. **Your task: fill in the `method` and `metric` values** in the config dict below.
#
# Requirements:
# - Use Bayesian search.
# - Minimize `'val_loss'`.
#
# ```python
# def build_config():
#     return {
#         'method': None,  # TODO: set to the bayesian search method string
#         'metric': None,  # TODO: set to the correct metric dict (name + goal)
#         'parameters': {
#             'lr': {'distribution': 'log_uniform_values', 'min': 1e-4, 'max': 1e-1},
#             'batch_size': {'values': [32, 64]},
#         },
#     }
# ```
#
# **Your task:** complete the one blanked step in the code cell below. The surrounding code, function signatures, and variable names are given — work out the missing expression yourself, then run the test.

# %%
def build_config() -> dict:
    return {
        'method': None,  # TODO: fill in this step — read the prompt cell above
        'metric': None,  # TODO: fill in this step — read the prompt cell above
        'parameters': {
            'lr': {'distribution': 'log_uniform_values', 'min': 1e-4, 'max': 1e-1},
            'batch_size': {'values': [32, 64]},
        },
    }

cfg = build_config()
print('method:', cfg['method'])
print('metric:', cfg['metric'])


def _test():
    cfg = build_config()
    assert cfg['method'] == 'bayes', f"got {cfg['method']!r}"
    assert isinstance(cfg['metric'], dict), 'metric must be a dict'
    assert cfg['metric'].get('name') == 'val_loss'
    assert cfg['metric'].get('goal') == 'minimize'
    assert 'parameters' in cfg


try:
    _test()
    _dd_passed.add('faded1')
    print('[Delta Drills] faded1 passed.')
except AssertionError as _e:
    print('Test failed:', _e)

# %% [markdown]
# ## Report your progress
#
# Run the cell below to send your progress to Delta Drills. It only counts if the test above passed.

# %%
# === Delta Drills completion beacon ===
import urllib.request as _dd_req, json as _dd_json

_DD_REQUIRED = {'faded1'}

def report_completion():
    missing = _DD_REQUIRED - _dd_passed
    if missing:
        print(f"[Delta Drills] {sorted(missing)} not yet passing — fix the cell above, then re-run this one.")
        return
    if not DD_TOKEN:
        print('[Delta Drills] DD_TOKEN is empty — completion not reported.')
        return
    body = _dd_json.dumps({
        'exercise_title': f'procedural-drill:{DD_ATOM_ID}:faded1',
        'subtopics': [DD_SUBTOPIC],
        'feedback': 'somewhat',
        'correct': True,
    }).encode('utf-8')
    req = _dd_req.Request(
        f'{DD_BACKEND_URL}/api/practice/arena-rating',
        data=body,
        headers={
            'Content-Type': 'application/json',
            'Authorization': f'Bearer {DD_TOKEN}',
        },
        method='POST',
    )
    try:
        with _dd_req.urlopen(req, timeout=5) as r:
            resp = _dd_json.loads(r.read())
        print(f'[Delta Drills] reported {DD_ATOM_ID} (subtopic={DD_SUBTOPIC!r})')
        print(f'[Delta Drills] EWMA updated: {resp}')
    except Exception as e:
        print(f'[Delta Drills] beacon failed: {e}')

report_completion()

# %% [markdown]
# <details><summary>Solution</summary>
#
# ```python
# def build_config() -> dict:
#     return {
#         'method': 'bayes',
#         'metric': {'name': 'val_loss', 'goal': 'minimize'},
#         'parameters': {
#             'lr': {'distribution': 'log_uniform_values', 'min': 1e-4, 'max': 1e-1},
#             'batch_size': {'values': [32, 64]},
#         },
#     }
#
# cfg = build_config()
# print('method:', cfg['method'])
# print('metric:', cfg['metric'])
# ```
# </details>
