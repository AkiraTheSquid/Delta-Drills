# %% [markdown]
# # wandb-init-run — faded example 3: Return the run handle from wandb.init
#
# > Faded drill from [Delta Drills](https://delta-drills.vercel.app). Atom: `wandb-init-run`. Running the beacon reports progress on the `Logging: wandb.init run` subtopic.
#
# **Most of the solution is filled in — complete the one blanked step**, run the test, then fire the beacon. Less scaffolding than the worked example, more than the full drill.

# %% [markdown]
# ## Setup

# %%
import numpy as np
import torch as t
from torch import Tensor
import einops
from einops import rearrange, reduce, repeat

t.manual_seed(0)
np.random.seed(0)

# %% [markdown]
# ## Connect to Delta Drills
#
# Paste your Delta Drills auth token below so this drill can report progress on the `Logging: wandb.init run` subtopic. Copy it from your Delta Drills account page.
#
# This standalone exercises the atom **`wandb-init-run`** (exercise 1). Completion fires the beacon at the bottom.

# %%
# === Delta Drills auth ===
DD_TOKEN = ""  # paste your token here, then run this cell
DD_ATOM_ID = "wandb-init-run"
DD_SUBTOPIC = "Logging: wandb.init run"
DD_BACKEND_URL = "https://delta-drills-backend.fly.dev"

_dd_passed = set()

# %% [markdown]
# ## Concept
#
# The `wandb.init()` function returns a run handle object. Some workflows use this handle to access the run's ID, update the run summary, or attach artifacts. The canonical pattern is to store and return the run handle from the function that calls `wandb.init`, making it available to the caller.

# %% [markdown]
# ## Faded exercise 3
#
# Implement `open_run(project, name, config)` to open a wandb run and return its handle.
#
# Call `wandb.init` with the three provided arguments and return whatever `wandb.init` returns. Complete the blank that opens the run and captures the return value.
#
# **Fill in:** Call wandb.init(project=project, name=name, config=config) and capture the return value as run, then return run.

# %%
import sys
from unittest.mock import MagicMock
sys.modules.setdefault('wandb', MagicMock())
import wandb

def open_run(project, name, config):
    run = wandb.init(project=project, name=name, config=config)
    return run

wandb.init.reset_mock()
cfg = {'lr': 1e-3, 'batch_size': 32}
run = open_run('proj', 'run-1', cfg)
print('run is init return value:', run is wandb.init.return_value)


import sys
from unittest.mock import MagicMock
sys.modules.setdefault('wandb', MagicMock())
import wandb

def open_run(project, name, config):
    run = wandb.init(project=project, name=name, config=config)
    return run

def _test():
    wandb.init.reset_mock()
    cfg = {'lr': 5e-4, 'bs': 64}
    run = open_run('my-proj', 'experiment-7', cfg)
    assert run is wandb.init.return_value
    kw = wandb.init.call_args.kwargs
    assert kw['project'] == 'my-proj'
    assert kw['name'] == 'experiment-7'
    assert kw['config'] == cfg


try:
    _test()
    _dd_passed.add('faded3')
    print('[Delta Drills] faded3 passed.')
except AssertionError as _e:
    print('Test failed:', _e)

# %% [markdown]
# ## Report completion
#
# Run the cell below to report progress. The beacon fires only if the test above passed.

# %%
# === Delta Drills completion beacon ===
import urllib.request as _dd_req, json as _dd_json

_DD_REQUIRED = {'faded3'}

def report_completion():
    missing = _DD_REQUIRED - _dd_passed
    if missing:
        print(f"[Delta Drills] {sorted(missing)} not yet passing — fix the cell above, then re-run this one.")
        return
    if not DD_TOKEN:
        print('[Delta Drills] DD_TOKEN is empty — completion not reported.')
        return
    body = _dd_json.dumps({
        'exercise_title': f'procedural-drill:{DD_ATOM_ID}:faded1',
        'subtopics': [DD_SUBTOPIC],
        'feedback': 'somewhat',
        'correct': True,
    }).encode('utf-8')
    req = _dd_req.Request(
        f'{DD_BACKEND_URL}/api/practice/arena-rating',
        data=body,
        headers={
            'Content-Type': 'application/json',
            'Authorization': f'Bearer {DD_TOKEN}',
        },
        method='POST',
    )
    try:
        with _dd_req.urlopen(req, timeout=5) as r:
            resp = _dd_json.loads(r.read())
        print(f'[Delta Drills] reported {DD_ATOM_ID} (subtopic={DD_SUBTOPIC!r})')
        print(f'[Delta Drills] EWMA updated: {resp}')
    except Exception as e:
        print(f'[Delta Drills] beacon failed: {e}')

report_completion()

# %% [markdown]
# <details><summary>Solution</summary>
#
# ```python
# import sys
# from unittest.mock import MagicMock
# sys.modules.setdefault('wandb', MagicMock())
# import wandb
#
# def open_run(project, name, config):
#     run = wandb.init(project=project, name=name, config=config)
#     return run
#
# wandb.init.reset_mock()
# cfg = {'lr': 1e-3, 'batch_size': 32}
# run = open_run('proj', 'run-1', cfg)
# print('run is init return value:', run is wandb.init.return_value)
# ```
# </details>
