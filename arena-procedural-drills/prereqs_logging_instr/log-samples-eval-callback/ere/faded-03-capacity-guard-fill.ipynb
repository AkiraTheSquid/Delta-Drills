# %% [markdown]
# # log-samples-eval-callback — faded example 3: Fill the capacity guard
#
# > Faded drill from [Delta Drills](https://delta-drills.vercel.app). Atom: `log-samples-eval-callback`. Running the beacon reports progress on the `Logging: log-samples eval callback` subtopic.
#
# **Most of the solution is filled in — complete the one blanked step**, run the test, then fire the beacon. Less scaffolding than the worked example, more than the full drill.

# %% [markdown]
# ## Setup

# %%
import numpy as np
import torch as t
from torch import Tensor
import einops
from einops import rearrange, reduce, repeat

t.manual_seed(0)
np.random.seed(0)

# %% [markdown]
# ## Connect to Delta Drills
#
# Paste your Delta Drills auth token below so this drill can report progress on the `Logging: log-samples eval callback` subtopic. Copy it from your Delta Drills account page.
#
# This standalone exercises the atom **`log-samples-eval-callback`** (exercise 1). Completion fires the beacon at the bottom.

# %%
# === Delta Drills auth ===
DD_TOKEN = ""  # paste your token here, then run this cell
DD_ATOM_ID = "log-samples-eval-callback"
DD_SUBTOPIC = "Logging: log-samples eval callback"
DD_BACKEND_URL = "https://delta-drills-backend.fly.dev"

_dd_passed = set()

# %% [markdown]
# ## Concept
#
# A capacity-bounded sink stops accepting records once it reaches `max_entries`. The guard `len(sink) >= max_entries` short-circuits further fires; since the sink only grows, you can break out of the loop entirely.

# %% [markdown]
# ## Faded exercise 3
#
# Complete `run_capped(n_steps, eval_every, n_eval, sink, max_entries)`. The cadence is given; fill in the capacity guard that stops logging once the sink is full.
#
# **Fill in:** the condition that detects the sink has reached max_entries

# %%
def run_capped(n_steps, eval_every, n_eval, sink, max_entries):
    n_fires = 0
    for step in range(n_steps):
        if step % eval_every != 0:
            continue
        full = None  # TODO: the condition that detects the sink has reached max_entries
        if full:
            break
        sink.append({'step': step, 'samples': [f'step={step}-sample={i}' for i in range(n_eval)]})
        n_fires += 1
    return n_fires


def _test():
    sink = []
    fires = run_capped(n_steps=30, eval_every=2, n_eval=1, sink=sink, max_entries=3)
    assert fires == 3
    assert len(sink) == 3
    # first three even steps: 0,2,4
    assert [d['step'] for d in sink] == [0, 2, 4]
    # max_entries == 0 -> no fires
    sink2 = []
    assert run_capped(10, 1, 1, sink2, 0) == 0
    assert sink2 == []


try:
    _test()
    _dd_passed.add('faded3')
    print('[Delta Drills] faded3 passed.')
except AssertionError as _e:
    print('Test failed:', _e)

# %% [markdown]
# ## Report completion
#
# Run the cell below to report progress. The beacon fires only if the test above passed.

# %%
# === Delta Drills completion beacon ===
import urllib.request as _dd_req, json as _dd_json

_DD_REQUIRED = {'faded3'}

def report_completion():
    missing = _DD_REQUIRED - _dd_passed
    if missing:
        print(f"[Delta Drills] {sorted(missing)} not yet passing — fix the cell above, then re-run this one.")
        return
    if not DD_TOKEN:
        print('[Delta Drills] DD_TOKEN is empty — completion not reported.')
        return
    body = _dd_json.dumps({
        'exercise_title': f'procedural-drill:{DD_ATOM_ID}:faded1',
        'subtopics': [DD_SUBTOPIC],
        'feedback': 'somewhat',
        'correct': True,
    }).encode('utf-8')
    req = _dd_req.Request(
        f'{DD_BACKEND_URL}/api/practice/arena-rating',
        data=body,
        headers={
            'Content-Type': 'application/json',
            'Authorization': f'Bearer {DD_TOKEN}',
        },
        method='POST',
    )
    try:
        with _dd_req.urlopen(req, timeout=5) as r:
            resp = _dd_json.loads(r.read())
        print(f'[Delta Drills] reported {DD_ATOM_ID} (subtopic={DD_SUBTOPIC!r})')
        print(f'[Delta Drills] EWMA updated: {resp}')
    except Exception as e:
        print(f'[Delta Drills] beacon failed: {e}')

report_completion()

# %% [markdown]
# <details><summary>Solution</summary>
#
# ```python
# def run_capped(n_steps, eval_every, n_eval, sink, max_entries):
#     n_fires = 0
#     for step in range(n_steps):
#         if step % eval_every != 0:
#             continue
#         full = len(sink) >= max_entries
#         if full:
#             break
#         sink.append({'step': step, 'samples': [f'step={step}-sample={i}' for i in range(n_eval)]})
#         n_fires += 1
#     return n_fires
# ```
# </details>
