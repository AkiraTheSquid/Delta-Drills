# %% [markdown]
# # detach-stop-gradient-trick — faded example 3: Complete the detach call and report its graph metadata
#
# > Practice drill from [Delta Drills](https://delta-drills.vercel.app). Atom: `detach-stop-gradient-trick`. The last cell reports your progress on the `GAN: detach stop-gradient trick` subtopic back to Delta Drills.
#
# **Most of the code is already written — complete the one blanked step**, run the test to check it, then run the last cell to record your progress.

# %% [markdown]
# ## Setup

# %%
import numpy as np
import torch as t
from torch import Tensor
import einops
from einops import rearrange, reduce, repeat

t.manual_seed(0)
np.random.seed(0)

# %% [markdown]
# ## Connect to Delta Drills
#
# Paste your Delta Drills auth token below so this drill can report progress on the `GAN: detach stop-gradient trick` subtopic. Copy it from your Delta Drills account page.
#
# This standalone exercises the atom **`detach-stop-gradient-trick`** (exercise 1). Completion fires the beacon at the bottom.

# %%
# === Delta Drills auth ===
DD_TOKEN = ""  # paste your token here, then run this cell
DD_ATOM_ID = "detach-stop-gradient-trick"
DD_SUBTOPIC = "GAN: detach stop-gradient trick"
DD_BACKEND_URL = "https://delta-drills-backend.fly.dev"

_dd_passed = set()

# %% [markdown]
# ## Concept
#
# _First time on this topic? Run the **Setup** cell above and skim it: every class and helper mentioned below is defined there. You don't need to have done any other drill first._
#
# `.detach()` returns a tensor that shares storage with the original but is cut off from autograd: same values, but `requires_grad=False` and `grad_fn=None`. This lets you prove that detaching changes only the backward graph, never the forward numbers.

# %% [markdown]
# ## Faded exercise 3
#
# Implement `detach_report(G, z)` that returns a tuple `(values_equal, detached_requires_grad, detached_has_no_grad_fn)`. Compute `with_graph = G(z)` and a detached copy of the same forward; then compare their values with `torch.allclose`, and inspect the detached tensor's `requires_grad` and whether its `grad_fn` is None. Complete the blanked line that builds the detached tensor.
#
# **Your task:** complete the one blanked step in the code cell below. The surrounding code, function signatures, and variable names are given — work out the missing expression yourself, then run the test.

# %%
import torch.nn as nn

t.manual_seed(0)
G = nn.Linear(5, 3)

def detach_report(G, z):
    with_graph = G(z)
    detached = None  # TODO: fill in this step — read the prompt cell above
    values_equal = bool(t.allclose(with_graph, detached))
    return values_equal, detached.requires_grad, detached.grad_fn is None


def _test():
    import torch.nn as nn
    t.manual_seed(0)
    Gt = nn.Linear(5, 3)
    zt = t.randn(6, 5)
    ve, drg, dno = detach_report(Gt, zt)
    assert ve is True, 'detach must not change the forward values'
    assert drg is False, 'detached tensor must have requires_grad=False'
    assert dno is True, 'detached tensor must have grad_fn=None'


try:
    _test()
    _dd_passed.add('faded3')
    print('[Delta Drills] faded3 passed.')
except AssertionError as _e:
    print('Test failed:', _e)

# %% [markdown]
# ## Report your progress
#
# Run the cell below to send your progress to Delta Drills. It only counts if the test above passed.

# %%
# === Delta Drills completion beacon ===
import urllib.request as _dd_req, json as _dd_json

_DD_REQUIRED = {'faded3'}

def report_completion():
    missing = _DD_REQUIRED - _dd_passed
    if missing:
        print(f"[Delta Drills] {sorted(missing)} not yet passing — fix the cell above, then re-run this one.")
        return
    if not DD_TOKEN:
        print('[Delta Drills] DD_TOKEN is empty — completion not reported.')
        return
    body = _dd_json.dumps({
        'exercise_title': f'procedural-drill:{DD_ATOM_ID}:faded1',
        'subtopics': [DD_SUBTOPIC],
        'feedback': 'somewhat',
        'correct': True,
    }).encode('utf-8')
    req = _dd_req.Request(
        f'{DD_BACKEND_URL}/api/practice/arena-rating',
        data=body,
        headers={
            'Content-Type': 'application/json',
            'Authorization': f'Bearer {DD_TOKEN}',
        },
        method='POST',
    )
    try:
        with _dd_req.urlopen(req, timeout=5) as r:
            resp = _dd_json.loads(r.read())
        print(f'[Delta Drills] reported {DD_ATOM_ID} (subtopic={DD_SUBTOPIC!r})')
        print(f'[Delta Drills] EWMA updated: {resp}')
    except Exception as e:
        print(f'[Delta Drills] beacon failed: {e}')

report_completion()

# %% [markdown]
# <details><summary>Solution</summary>
#
# ```python
# import torch.nn as nn
#
# t.manual_seed(0)
# G = nn.Linear(5, 3)
#
# def detach_report(G, z):
#     with_graph = G(z)
#     detached = G(z).detach()
#     values_equal = bool(t.allclose(with_graph, detached))
#     return values_equal, detached.requires_grad, detached.grad_fn is None
# ```
# </details>
