# %% [markdown]
# # requires-grad-leaf-assert — faded example 1: Assert is_leaf on Each Parameter Before Optimizing (Faded)
#
# > Practice drill from [Delta Drills](https://delta-drills.vercel.app). Atom: `requires-grad-leaf-assert`. The last cell reports your progress on the `Generative: requires_grad leaf assert` subtopic back to Delta Drills.
#
# **Most of the code is already written — complete the one blanked step**, run the test to check it, then run the last cell to record your progress.

# %% [markdown]
# ## Setup

# %%
import numpy as np
import torch as t
from torch import Tensor
import einops
from einops import rearrange, reduce, repeat

t.manual_seed(0)
np.random.seed(0)
import matplotlib.pyplot as plt

# %% [markdown]
# ## Connect to Delta Drills
#
# Paste your Delta Drills auth token below so this drill can report progress on the `Generative: requires_grad leaf assert` subtopic. Copy it from your Delta Drills account page.
#
# This standalone exercises the atom **`requires-grad-leaf-assert`** (exercise 1). Completion fires the beacon at the bottom.

# %%
# === Delta Drills auth ===
DD_TOKEN = ""  # paste your token here, then run this cell
DD_ATOM_ID = "requires-grad-leaf-assert"
DD_SUBTOPIC = "Generative: requires_grad leaf assert"
DD_BACKEND_URL = "https://delta-drills-backend.fly.dev"

_dd_passed = set()

# %% [markdown]
# ## Concept
#
# _First time on this topic? Run the **Setup** cell above and skim it: every class and helper mentioned below is defined there. You don't need to have done any other drill first._
#
# A non-leaf tensor is the output of a computation, not a directly-created variable. Optimizers silently skip non-leaf tensors because they have no stored gradient slot. Asserting `p.is_leaf` for each parameter before building the optimizer catches this class of bug immediately, with a message that includes the tensor's shape for easy identification.

# %% [markdown]
# ## Faded exercise 1
#
# Implement `check_all_leaves(params)` which iterates `params` and asserts `p.is_leaf` for each. On failure, raise `AssertionError` with a message including `tuple(p.shape)`. Return `True` if all pass.
#
# The `requires_grad` check is NOT needed here — only the leaf check.
#
# **Your task:** complete the one blanked step in the code cell below. The surrounding code, function signatures, and variable names are given — work out the missing expression yourself, then run the test.

# %%
import torch as t
import torch.nn as nn

def check_all_leaves(params) -> bool:
    for p in params:
        raise NotImplementedError()  # TODO: fill in this step — read the prompt cell above
    return True


def _test():
    import torch as t
    import torch.nn as nn
    # All leaves should pass
    good = [nn.Parameter(t.randn(3)), nn.Parameter(t.randn(4, 2))]
    assert check_all_leaves(good) is True
    # A non-leaf should raise
    src = t.randn(5, requires_grad=True)
    non_leaf = src + 1  # non-leaf
    try:
        check_all_leaves([non_leaf])
        assert False, 'Should have raised'
    except AssertionError as e:
        msg = str(e)
        assert '(5,)' in msg or 'shape' in msg, f'Message should include shape: {msg}'


try:
    _test()
    _dd_passed.add('faded1')
    print('[Delta Drills] faded1 passed.')
except AssertionError as _e:
    print('Test failed:', _e)

# %% [markdown]
# ## Report your progress
#
# Run the cell below to send your progress to Delta Drills. It only counts if the test above passed.

# %%
# === Delta Drills completion beacon ===
import urllib.request as _dd_req, json as _dd_json

_DD_REQUIRED = {'faded1'}

def report_completion():
    missing = _DD_REQUIRED - _dd_passed
    if missing:
        print(f"[Delta Drills] {sorted(missing)} not yet passing — fix the cell above, then re-run this one.")
        return
    if not DD_TOKEN:
        print('[Delta Drills] DD_TOKEN is empty — completion not reported.')
        return
    body = _dd_json.dumps({
        'exercise_title': f'procedural-drill:{DD_ATOM_ID}:faded1',
        'subtopics': [DD_SUBTOPIC],
        'feedback': 'somewhat',
        'correct': True,
    }).encode('utf-8')
    req = _dd_req.Request(
        f'{DD_BACKEND_URL}/api/practice/arena-rating',
        data=body,
        headers={
            'Content-Type': 'application/json',
            'Authorization': f'Bearer {DD_TOKEN}',
        },
        method='POST',
    )
    try:
        with _dd_req.urlopen(req, timeout=5) as r:
            resp = _dd_json.loads(r.read())
        print(f'[Delta Drills] reported {DD_ATOM_ID} (subtopic={DD_SUBTOPIC!r})')
        print(f'[Delta Drills] EWMA updated: {resp}')
    except Exception as e:
        print(f'[Delta Drills] beacon failed: {e}')

report_completion()

# %% [markdown]
# <details><summary>Solution</summary>
#
# ```python
# import torch as t
# import torch.nn as nn
#
# def check_all_leaves(params) -> bool:
#     for p in params:
#         assert p.is_leaf, f'shape={tuple(p.shape)} is non-leaf — optimizer will silently skip it'
#     return True
# ```
# </details>
