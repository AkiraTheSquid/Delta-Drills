# %% [markdown]
# # bottleneck-latent-projection — faded example 1: Complete the flatten step of the encoder bottleneck
#
# > Practice drill from [Delta Drills](https://delta-drills.vercel.app). Atom: `bottleneck-latent-projection`. The last cell reports your progress on the `Generative: Bottleneck latent projection` subtopic back to Delta Drills.
#
# **Most of the code is already written — complete the one blanked step**, run the test to check it, then run the last cell to record your progress.

# %% [markdown]
# ## Setup

# %%
import numpy as np
import torch as t
from torch import Tensor
import einops
from einops import rearrange, reduce, repeat

t.manual_seed(0)
np.random.seed(0)
import matplotlib.pyplot as plt

# %% [markdown]
# ## Connect to Delta Drills
#
# Paste your Delta Drills auth token below so this drill can report progress on the `Generative: Bottleneck latent projection` subtopic. Copy it from your Delta Drills account page.
#
# This standalone exercises the atom **`bottleneck-latent-projection`** (exercise 1). Completion fires the beacon at the bottom.

# %%
# === Delta Drills auth ===
DD_TOKEN = ""  # paste your token here, then run this cell
DD_ATOM_ID = "bottleneck-latent-projection"
DD_SUBTOPIC = "Generative: Bottleneck latent projection"
DD_BACKEND_URL = "https://delta-drills-backend.fly.dev"

_dd_passed = set()

# %% [markdown]
# ## Concept
#
# _First time on this topic? Run the **Setup** cell above and skim it: every class and helper mentioned below is defined there. You don't need to have done any other drill first._
#
# Before a conv feature map `(B, C, H, W)` can enter a `Linear`, the channel and spatial axes must be flattened into one feature axis with `Rearrange('b c h w -> b (c h w)')`. After flattening, the encoder applies `Linear(C*H*W, hidden)` + ReLU then `Linear(hidden, latent)` with no activation.

# %% [markdown]
# ## Faded exercise 1
#
# Implement `encode(x, W1, b1, W2, b2)` for the bottleneck encoder. The two Linear stages and the ReLU are already written. You must complete the **flatten** step that turns the `(B, C, H, W)` conv feature map into a `(B, C*H*W)` matrix the first Linear can consume. Use einops `rearrange`.
#
# **Your task:** complete the one blanked step in the code cell below. The surrounding code, function signatures, and variable names are given — work out the missing expression yourself, then run the test.

# %%
def encode(x, W1, b1, W2, b2):
    flat = rearrange(x, 'b c h w -> b (c h w)')
    h = t.relu(flat @ W1.T + b1)
    z = h @ W2.T + b2
    return z

t.manual_seed(0)
B, C, H, W = 5, 8, 4, 4
in_f, hidden, latent = C * H * W, 32, 4
x = t.randn(B, C, H, W)
W1 = t.randn(hidden, in_f); b1 = t.randn(hidden)
W2 = t.randn(latent, hidden); b2 = t.randn(latent)
z = encode(x, W1, b1, W2, b2)
print('latent shape:', tuple(z.shape))


def _test():
    t.manual_seed(0)
    B, C, H, W = 5, 8, 4, 4
    in_f, hidden, latent = C * H * W, 32, 4
    x = t.randn(B, C, H, W)
    W1 = t.randn(hidden, in_f); b1 = t.randn(hidden)
    W2 = t.randn(latent, hidden); b2 = t.randn(latent)
    z = encode(x, W1, b1, W2, b2)
    assert z.shape == (B, latent), z.shape
    flat_ref = x.reshape(B, in_f)
    z_ref = t.relu(flat_ref @ W1.T + b1) @ W2.T + b2
    assert t.allclose(z, z_ref, atol=1e-5), 'latent mismatch'


try:
    _test()
    _dd_passed.add('faded1')
    print('[Delta Drills] faded1 passed.')
except AssertionError as _e:
    print('Test failed:', _e)

# %% [markdown]
# ## Report your progress
#
# Run the cell below to send your progress to Delta Drills. It only counts if the test above passed.

# %%
# === Delta Drills completion beacon ===
import urllib.request as _dd_req, json as _dd_json

_DD_REQUIRED = {'faded1'}

def report_completion():
    missing = _DD_REQUIRED - _dd_passed
    if missing:
        print(f"[Delta Drills] {sorted(missing)} not yet passing — fix the cell above, then re-run this one.")
        return
    if not DD_TOKEN:
        print('[Delta Drills] DD_TOKEN is empty — completion not reported.')
        return
    body = _dd_json.dumps({
        'exercise_title': f'procedural-drill:{DD_ATOM_ID}:faded1',
        'subtopics': [DD_SUBTOPIC],
        'feedback': 'somewhat',
        'correct': True,
    }).encode('utf-8')
    req = _dd_req.Request(
        f'{DD_BACKEND_URL}/api/practice/arena-rating',
        data=body,
        headers={
            'Content-Type': 'application/json',
            'Authorization': f'Bearer {DD_TOKEN}',
        },
        method='POST',
    )
    try:
        with _dd_req.urlopen(req, timeout=5) as r:
            resp = _dd_json.loads(r.read())
        print(f'[Delta Drills] reported {DD_ATOM_ID} (subtopic={DD_SUBTOPIC!r})')
        print(f'[Delta Drills] EWMA updated: {resp}')
    except Exception as e:
        print(f'[Delta Drills] beacon failed: {e}')

report_completion()

# %% [markdown]
# <details><summary>Solution</summary>
#
# ```python
# def encode(x, W1, b1, W2, b2):
#     flat = rearrange(x, 'b c h w -> b (c h w)')
#     h = t.relu(flat @ W1.T + b1)
#     z = h @ W2.T + b2
#     return z
#
# t.manual_seed(0)
# B, C, H, W = 5, 8, 4, 4
# in_f, hidden, latent = C * H * W, 32, 4
# x = t.randn(B, C, H, W)
# W1 = t.randn(hidden, in_f); b1 = t.randn(hidden)
# W2 = t.randn(latent, hidden); b2 = t.randn(latent)
# z = encode(x, W1, b1, W2, b2)
# print('latent shape:', tuple(z.shape))
# ```
# </details>
