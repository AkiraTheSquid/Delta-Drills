# %% [markdown]
# # tensor-wraps-ndarray — faded example 1: Wrap an ndarray with from_numpy (aliased)
#
# > Faded drill from [Delta Drills](https://delta-drills.vercel.app). Atom: `tensor-wraps-ndarray`. Running the beacon reports progress on the `PyTorch: tensor from ndarray` subtopic.
#
# **Most of the solution is filled in — complete the one blanked step**, run the test, then fire the beacon. Less scaffolding than the worked example, more than the full drill.

# %% [markdown]
# ## Setup

# %%
import numpy as np
import torch as t
from torch import Tensor
import einops
from einops import rearrange, reduce, repeat

t.manual_seed(0)
np.random.seed(0)

# %% [markdown]
# ## Connect to Delta Drills
#
# Paste your Delta Drills auth token below so this drill can report progress on the `PyTorch: tensor from ndarray` subtopic. Copy it from your Delta Drills account page.
#
# This standalone exercises the atom **`tensor-wraps-ndarray`** (exercise 1). Completion fires the beacon at the bottom.

# %%
# === Delta Drills auth ===
DD_TOKEN = ""  # paste your token here, then run this cell
DD_ATOM_ID = "tensor-wraps-ndarray"
DD_SUBTOPIC = "PyTorch: tensor from ndarray"
DD_BACKEND_URL = "https://delta-drills-backend.fly.dev"

_dd_passed = set()

# %% [markdown]
# ## Concept
#
# `t.from_numpy(arr)` shares memory with the source ndarray, so a later in-place mutation of the array is visible in the tensor. It is the no-copy bridge from numpy to torch.

# %% [markdown]
# ## Faded exercise 1
#
# Complete `alias_wrap(arr)` to wrap the ndarray as a storage-sharing tensor. Fill in the wrapping call that aliases (does not copy).
#
# **Fill in:** wrap arr with the aliasing (no-copy) torch factory

# %%
import numpy as np


def alias_wrap(arr):
    wrapped = None  # TODO: wrap arr with the aliasing (no-copy) torch factory
    return wrapped


arr = np.array([1.0, 2.0, 3.0], dtype=np.float32)
w = alias_wrap(arr)

def _test():
    import numpy as np
    arr = np.array([1.0, 2.0, 3.0], dtype=np.float32)
    w = alias_wrap(arr)
    before = w[0].item()
    arr[0] = 42.0
    after = w[0].item()
    assert before == 1.0, 'initial value must match source'
    assert after == 42.0, 'aliased tensor must track the in-place mutation'

try:
    _test()
    _dd_passed.add('faded1')
    print('[Delta Drills] faded1 passed.')
except AssertionError as _e:
    print('Test failed:', _e)

# %% [markdown]
# ## Report completion
#
# Run the cell below to report progress. The beacon fires only if the test above passed.

# %%
# === Delta Drills completion beacon ===
import urllib.request as _dd_req, json as _dd_json

_DD_REQUIRED = {'faded1'}

def report_completion():
    missing = _DD_REQUIRED - _dd_passed
    if missing:
        print(f"[Delta Drills] {sorted(missing)} not yet passing — fix the cell above, then re-run this one.")
        return
    if not DD_TOKEN:
        print('[Delta Drills] DD_TOKEN is empty — completion not reported.')
        return
    body = _dd_json.dumps({
        'exercise_title': f'procedural-drill:{DD_ATOM_ID}:faded1',
        'subtopics': [DD_SUBTOPIC],
        'feedback': 'somewhat',
        'correct': True,
    }).encode('utf-8')
    req = _dd_req.Request(
        f'{DD_BACKEND_URL}/api/practice/arena-rating',
        data=body,
        headers={
            'Content-Type': 'application/json',
            'Authorization': f'Bearer {DD_TOKEN}',
        },
        method='POST',
    )
    try:
        with _dd_req.urlopen(req, timeout=5) as r:
            resp = _dd_json.loads(r.read())
        print(f'[Delta Drills] reported {DD_ATOM_ID} (subtopic={DD_SUBTOPIC!r})')
        print(f'[Delta Drills] EWMA updated: {resp}')
    except Exception as e:
        print(f'[Delta Drills] beacon failed: {e}')

report_completion()

# %% [markdown]
# <details><summary>Solution</summary>
#
# ```python
# import numpy as np
#
#
# def alias_wrap(arr):
#     wrapped = t.from_numpy(arr)
#     return wrapped
#
#
# arr = np.array([1.0, 2.0, 3.0], dtype=np.float32)
# w = alias_wrap(arr)
# ```
# </details>
