# %% [markdown]
# # stack-vs-cat — faded example 2: cat along an existing axis
#
# > Practice drill from [Delta Drills](https://delta-drills.vercel.app). Atom: `stack-vs-cat`. The last cell reports your progress on the `PyTorch: stack vs cat` subtopic back to Delta Drills.
#
# **Most of the code is already written — complete the one blanked step**, run the test to check it, then run the last cell to record your progress.

# %% [markdown]
# ## Setup

# %%
import numpy as np
import torch as t
from torch import Tensor
import einops
from einops import rearrange, reduce, repeat

t.manual_seed(0)
np.random.seed(0)

# %% [markdown]
# ## Connect to Delta Drills
#
# Paste your Delta Drills auth token below so this drill can report progress on the `PyTorch: stack vs cat` subtopic. Copy it from your Delta Drills account page.
#
# This standalone exercises the atom **`stack-vs-cat`** (exercise 1). Completion fires the beacon at the bottom.

# %%
# === Delta Drills auth ===
DD_TOKEN = ""  # paste your token here, then run this cell
DD_ATOM_ID = "stack-vs-cat"
DD_SUBTOPIC = "PyTorch: stack vs cat"
DD_BACKEND_URL = "https://delta-drills-backend.fly.dev"

_dd_passed = set()

# %% [markdown]
# ## Concept
#
# _First time on this topic? Run the **Setup** cell above and skim it: every class and helper mentioned below is defined there. You don't need to have done any other drill first._
#
# `t.cat` joins along an existing axis without changing the rank. Concatenating two `(3, 5)` tensors along `dim=0` produces `(6, 5)`.

# %% [markdown]
# ## Faded exercise 2
#
# Two `(3, 5)` tensors `a` and `b` are given. Complete the line that concatenates them along the existing batch axis to make a `(6, 5)` tensor.
#
# **Your task:** complete the one blanked step in the code cell below. The surrounding code, function signatures, and variable names are given — work out the missing expression yourself, then run the test.

# %%
t.manual_seed(0)
a = t.randn(3, 5)
b = t.randn(3, 5)
stacked = None  # TODO: fill in this step — read the prompt cell above

def _test():
    t.manual_seed(0)
    aa = t.randn(3, 5)
    bb = t.randn(3, 5)
    assert tuple(stacked.shape) == (6, 5), 'cat dim=0 must give (6,5)'
    assert t.equal(stacked[:3], aa), 'first 3 rows must equal a'
    assert t.equal(stacked[3:], bb), 'last 3 rows must equal b'

try:
    _test()
    _dd_passed.add('faded2')
    print('[Delta Drills] faded2 passed.')
except AssertionError as _e:
    print('Test failed:', _e)

# %% [markdown]
# ## Report your progress
#
# Run the cell below to send your progress to Delta Drills. It only counts if the test above passed.

# %%
# === Delta Drills completion beacon ===
import urllib.request as _dd_req, json as _dd_json

_DD_REQUIRED = {'faded2'}

def report_completion():
    missing = _DD_REQUIRED - _dd_passed
    if missing:
        print(f"[Delta Drills] {sorted(missing)} not yet passing — fix the cell above, then re-run this one.")
        return
    if not DD_TOKEN:
        print('[Delta Drills] DD_TOKEN is empty — completion not reported.')
        return
    body = _dd_json.dumps({
        'exercise_title': f'procedural-drill:{DD_ATOM_ID}:faded1',
        'subtopics': [DD_SUBTOPIC],
        'feedback': 'somewhat',
        'correct': True,
    }).encode('utf-8')
    req = _dd_req.Request(
        f'{DD_BACKEND_URL}/api/practice/arena-rating',
        data=body,
        headers={
            'Content-Type': 'application/json',
            'Authorization': f'Bearer {DD_TOKEN}',
        },
        method='POST',
    )
    try:
        with _dd_req.urlopen(req, timeout=5) as r:
            resp = _dd_json.loads(r.read())
        print(f'[Delta Drills] reported {DD_ATOM_ID} (subtopic={DD_SUBTOPIC!r})')
        print(f'[Delta Drills] EWMA updated: {resp}')
    except Exception as e:
        print(f'[Delta Drills] beacon failed: {e}')

report_completion()

# %% [markdown]
# <details><summary>Solution</summary>
#
# ```python
# t.manual_seed(0)
# a = t.randn(3, 5)
# b = t.randn(3, 5)
# stacked = t.cat([a, b], dim=0)
# ```
# </details>
