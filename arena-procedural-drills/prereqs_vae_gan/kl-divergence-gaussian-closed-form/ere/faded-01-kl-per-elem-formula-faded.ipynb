# %% [markdown]
# # kl-divergence-gaussian-closed-form — faded example 1: KL closed form — fill in the per-element expression
#
# > Practice drill from [Delta Drills](https://delta-drills.vercel.app). Atom: `kl-divergence-gaussian-closed-form`. The last cell reports your progress on the `VAE: KL divergence Gaussian closed-form` subtopic back to Delta Drills.
#
# **Most of the code is already written — complete the one blanked step**, run the test to check it, then run the last cell to record your progress.

# %% [markdown]
# ## Setup

# %%
import numpy as np
import torch as t
from torch import Tensor
import einops
from einops import rearrange, reduce, repeat

t.manual_seed(0)
np.random.seed(0)
import matplotlib.pyplot as plt

# %% [markdown]
# ## Connect to Delta Drills
#
# Paste your Delta Drills auth token below so this drill can report progress on the `VAE: KL divergence Gaussian closed-form` subtopic. Copy it from your Delta Drills account page.
#
# This standalone exercises the atom **`kl-divergence-gaussian-closed-form`** (exercise 1). Completion fires the beacon at the bottom.

# %%
# === Delta Drills auth ===
DD_TOKEN = ""  # paste your token here, then run this cell
DD_ATOM_ID = "kl-divergence-gaussian-closed-form"
DD_SUBTOPIC = "VAE: KL divergence Gaussian closed-form"
DD_BACKEND_URL = "https://delta-drills-backend.fly.dev"

_dd_passed = set()

# %% [markdown]
# ## Concept
#
# _First time on this topic? Run the **Setup** cell above and skim it: every class and helper mentioned below is defined there. You don't need to have done any other drill first._
#
# The per-element KL between `N(mu, sigma^2)` and `N(0,1)` is `0.5*(mu^2 + exp(2*logsigma) - 1 - 2*logsigma)`. This is the building block: sum it over the latent dimension to get per-sample KL, then average over the batch.

# %% [markdown]
# ## Faded exercise 1
#
# The structure of `kl_gaussian` is provided. Fill in the per-element expression that computes the KL contribution for each `(batch, latent_dim)` coordinate.
#
# **Your task:** complete the one blanked step in the code cell below. The surrounding code, function signatures, and variable names are given — work out the missing expression yourself, then run the test.

# %%
import torch as t

def kl_gaussian(mu: t.Tensor, logsigma: t.Tensor):
    """Returns (per_sample_kl: (B,), scalar_kl: scalar)."""
    per_elem = None  # TODO: fill in this step — read the prompt cell above
    per_sample = per_elem.sum(dim=-1)
    scalar = per_sample.mean()
    return per_sample, scalar


def _test():
    import torch as t

    # At prior: mu=0, logsigma=0 -> KL=0
    mu0 = t.zeros(3, 4)
    ls0 = t.zeros(3, 4)
    ps, sc = kl_gaussian(mu0, ls0)
    assert ps.shape == (3,)
    assert abs(sc.item()) < 1e-5, f'KL at prior should be 0, got {sc.item()}'

    # Shifted: KL > 0
    mu1 = t.ones(3, 4) * 2.0
    ls1 = t.zeros(3, 4)
    ps2, sc2 = kl_gaussian(mu1, ls1)
    assert (ps2 > 0).all(), 'Shifted KL should be positive'


try:
    _test()
    _dd_passed.add('faded1')
    print('[Delta Drills] faded1 passed.')
except AssertionError as _e:
    print('Test failed:', _e)

# %% [markdown]
# ## Report your progress
#
# Run the cell below to send your progress to Delta Drills. It only counts if the test above passed.

# %%
# === Delta Drills completion beacon ===
import urllib.request as _dd_req, json as _dd_json

_DD_REQUIRED = {'faded1'}

def report_completion():
    missing = _DD_REQUIRED - _dd_passed
    if missing:
        print(f"[Delta Drills] {sorted(missing)} not yet passing — fix the cell above, then re-run this one.")
        return
    if not DD_TOKEN:
        print('[Delta Drills] DD_TOKEN is empty — completion not reported.')
        return
    body = _dd_json.dumps({
        'exercise_title': f'procedural-drill:{DD_ATOM_ID}:faded1',
        'subtopics': [DD_SUBTOPIC],
        'feedback': 'somewhat',
        'correct': True,
    }).encode('utf-8')
    req = _dd_req.Request(
        f'{DD_BACKEND_URL}/api/practice/arena-rating',
        data=body,
        headers={
            'Content-Type': 'application/json',
            'Authorization': f'Bearer {DD_TOKEN}',
        },
        method='POST',
    )
    try:
        with _dd_req.urlopen(req, timeout=5) as r:
            resp = _dd_json.loads(r.read())
        print(f'[Delta Drills] reported {DD_ATOM_ID} (subtopic={DD_SUBTOPIC!r})')
        print(f'[Delta Drills] EWMA updated: {resp}')
    except Exception as e:
        print(f'[Delta Drills] beacon failed: {e}')

report_completion()

# %% [markdown]
# <details><summary>Solution</summary>
#
# ```python
# import torch as t
#
# def kl_gaussian(mu: t.Tensor, logsigma: t.Tensor):
#     per_elem = 0.5 * (mu.pow(2) + (2 * logsigma).exp() - 1 - 2 * logsigma)
#     per_sample = per_elem.sum(dim=-1)
#     scalar = per_sample.mean()
#     return per_sample, scalar
# ```
# </details>
