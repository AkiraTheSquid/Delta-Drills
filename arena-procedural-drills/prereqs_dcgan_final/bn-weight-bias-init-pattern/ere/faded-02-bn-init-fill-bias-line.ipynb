# %% [markdown]
# # bn-weight-bias-init-pattern — faded example 2: Fill the beta-zeroing line
#
# > Practice drill from [Delta Drills](https://delta-drills.vercel.app). Atom: `bn-weight-bias-init-pattern`. The last cell reports your progress on the `GAN: BN weight=1 bias=0 init` subtopic back to Delta Drills.
#
# **Most of the code is already written — complete the one blanked step**, run the test to check it, then run the last cell to record your progress.

# %% [markdown]
# ## Setup

# %%
import numpy as np
import torch as t
from torch import Tensor
import einops
from einops import rearrange, reduce, repeat

t.manual_seed(0)
np.random.seed(0)
import torch.nn as nn
import matplotlib.pyplot as plt

# %% [markdown]
# ## Connect to Delta Drills
#
# Paste your Delta Drills auth token below so this drill can report progress on the `GAN: BN weight=1 bias=0 init` subtopic. Copy it from your Delta Drills account page.
#
# This standalone exercises the atom **`bn-weight-bias-init-pattern`** (exercise 1). Completion fires the beacon at the bottom.

# %%
# === Delta Drills auth ===
DD_TOKEN = ""  # paste your token here, then run this cell
DD_ATOM_ID = "bn-weight-bias-init-pattern"
DD_SUBTOPIC = "GAN: BN weight=1 bias=0 init"
DD_BACKEND_URL = "https://delta-drills-backend.fly.dev"

_dd_passed = set()

# %% [markdown]
# ## Concept
#
# _First time on this topic? Run the **Setup** cell above and skim it: every class and helper mentioned below is defined there. You don't need to have done any other drill first._
#
# After applying DCGAN BN init, gamma is `N(1, 0.02)` and beta is exactly zero. The zero bias is what makes the BN affine map a pure scale with no shift at initialization.

# %% [markdown]
# ## Faded exercise 2
#
# ### Faded — fill the beta-zeroing line
#
# A single `nn.BatchNorm2d` layer is built and its gamma is already initialized for you. Complete the ONE line that sets the bias (beta) to exactly zero, then the eval-mode forward pass is run for you.
#
# **Your task:** complete the one blanked step in the code cell below. The surrounding code, function signatures, and variable names are given — work out the missing expression yourself, then run the test.

# %%
import torch.nn as nn

t.manual_seed(0)

layer = nn.BatchNorm2d(16)
nn.init.normal_(layer.weight, 1.0, 0.02)
raise NotImplementedError()  # TODO: fill in this step — read the prompt cell above

x = t.randn(4, 16, 5, 5)
layer.eval()
with t.no_grad():
    y = layer(x)


def _test():
    # beta must be exactly zero
    assert t.allclose(layer.bias, t.zeros_like(layer.bias)), "BN bias must be all zeros"
    # at init in eval mode (running_mean=0, running_var=1), y == x * gamma + 0
    gamma = layer.weight.view(1, -1, 1, 1)
    expected = x * gamma
    assert t.allclose(y, expected, atol=1e-4), "y should equal x * gamma with zero shift"


try:
    _test()
    _dd_passed.add('faded2')
    print('[Delta Drills] faded2 passed.')
except AssertionError as _e:
    print('Test failed:', _e)

# %% [markdown]
# ## Report your progress
#
# Run the cell below to send your progress to Delta Drills. It only counts if the test above passed.

# %%
# === Delta Drills completion beacon ===
import urllib.request as _dd_req, json as _dd_json

_DD_REQUIRED = {'faded2'}

def report_completion():
    missing = _DD_REQUIRED - _dd_passed
    if missing:
        print(f"[Delta Drills] {sorted(missing)} not yet passing — fix the cell above, then re-run this one.")
        return
    if not DD_TOKEN:
        print('[Delta Drills] DD_TOKEN is empty — completion not reported.')
        return
    body = _dd_json.dumps({
        'exercise_title': f'procedural-drill:{DD_ATOM_ID}:faded1',
        'subtopics': [DD_SUBTOPIC],
        'feedback': 'somewhat',
        'correct': True,
    }).encode('utf-8')
    req = _dd_req.Request(
        f'{DD_BACKEND_URL}/api/practice/arena-rating',
        data=body,
        headers={
            'Content-Type': 'application/json',
            'Authorization': f'Bearer {DD_TOKEN}',
        },
        method='POST',
    )
    try:
        with _dd_req.urlopen(req, timeout=5) as r:
            resp = _dd_json.loads(r.read())
        print(f'[Delta Drills] reported {DD_ATOM_ID} (subtopic={DD_SUBTOPIC!r})')
        print(f'[Delta Drills] EWMA updated: {resp}')
    except Exception as e:
        print(f'[Delta Drills] beacon failed: {e}')

report_completion()

# %% [markdown]
# <details><summary>Solution</summary>
#
# ```python
# import torch.nn as nn
#
# t.manual_seed(0)
#
# layer = nn.BatchNorm2d(16)
# nn.init.normal_(layer.weight, 1.0, 0.02)
# nn.init.zeros_(layer.bias)
#
# x = t.randn(4, 16, 5, 5)
# layer.eval()
# with t.no_grad():
#     y = layer(x)
# ```
# </details>
