# %% [markdown]
# # noise-batch-from-latent — faded example 3: 4-D latent noise with (1, 1) spatial suffix
#
# > Faded drill from [Delta Drills](https://delta-drills.vercel.app). Atom: `noise-batch-from-latent`. Running the beacon reports progress on the `GAN: Noise batch from latent_dim` subtopic.
#
# **Most of the solution is filled in — complete the one blanked step**, run the test, then fire the beacon. Less scaffolding than the worked example, more than the full drill.

# %% [markdown]
# ## Setup

# %%
import numpy as np
import torch as t
from torch import Tensor
import einops
from einops import rearrange, reduce, repeat

t.manual_seed(0)
np.random.seed(0)
import matplotlib.pyplot as plt

# %% [markdown]
# ## Connect to Delta Drills
#
# Paste your Delta Drills auth token below so this drill can report progress on the `GAN: Noise batch from latent_dim` subtopic. Copy it from your Delta Drills account page.
#
# This standalone exercises the atom **`noise-batch-from-latent`** (exercise 1). Completion fires the beacon at the bottom.

# %%
# === Delta Drills auth ===
DD_TOKEN = ""  # paste your token here, then run this cell
DD_ATOM_ID = "noise-batch-from-latent"
DD_SUBTOPIC = "GAN: Noise batch from latent_dim"
DD_BACKEND_URL = "https://delta-drills-backend.fly.dev"

_dd_passed = set()

# %% [markdown]
# ## Concept
#
# DCGAN-style generators take 4-D noise of shape `(B, latent_dim, 1, 1)` — the trailing two dimensions are spatial seeds that the transposed-conv layers expand. The noise is still drawn from `N(0, 1)` via `t.randn`; the shape change is entirely in the arguments to `t.randn`.

# %% [markdown]
# ## Faded exercise 3
#
# Complete `dcgan_noise(batch_size, latent_dim, device)`. The first two lines are provided. Your task: fill in the `t.randn` call that returns a `(batch_size, latent_dim, 1, 1)` tensor on `device`. Do NOT use `.view` or `.reshape` — pass all four size arguments directly to `t.randn`.
#
# **Fill in:** The t.randn call with four explicit size arguments (batch_size, latent_dim, 1, 1) and the device keyword.

# %%
import torch as t

def dcgan_noise(batch_size: int, latent_dim: int, device) -> t.Tensor:
    # shape must be (batch_size, latent_dim, 1, 1)
    raise NotImplementedError()  # TODO: The t.randn call with four explicit size arguments (batch_size, latent_dim, 1, 1) and the device keyword.

# --- run it ---
noise = dcgan_noise(8, 64, t.device('cpu'))
print(f'shape: {noise.shape}')  # [8, 64, 1, 1]
print(f'ndim : {noise.ndim}')   # 4


def _test():
    import torch as t
    noise = dcgan_noise(8, 64, t.device('cpu'))
    ground_truth = t.zeros(8, 64, 1, 1)  # shape-only check
    assert noise.shape == (8, 64, 1, 1), f'Expected (8,64,1,1), got {noise.shape}'
    assert noise.ndim == 4
    assert noise.dtype == t.float32
    assert noise.device.type == 'cpu'
    # Verify it is NOT all zeros (was actually sampled)
    assert noise.abs().max().item() > 0


try:
    _test()
    _dd_passed.add('faded3')
    print('[Delta Drills] faded3 passed.')
except AssertionError as _e:
    print('Test failed:', _e)

# %% [markdown]
# ## Report completion
#
# Run the cell below to report progress. The beacon fires only if the test above passed.

# %%
# === Delta Drills completion beacon ===
import urllib.request as _dd_req, json as _dd_json

_DD_REQUIRED = {'faded3'}

def report_completion():
    missing = _DD_REQUIRED - _dd_passed
    if missing:
        print(f"[Delta Drills] {sorted(missing)} not yet passing — fix the cell above, then re-run this one.")
        return
    if not DD_TOKEN:
        print('[Delta Drills] DD_TOKEN is empty — completion not reported.')
        return
    body = _dd_json.dumps({
        'exercise_title': f'procedural-drill:{DD_ATOM_ID}:faded1',
        'subtopics': [DD_SUBTOPIC],
        'feedback': 'somewhat',
        'correct': True,
    }).encode('utf-8')
    req = _dd_req.Request(
        f'{DD_BACKEND_URL}/api/practice/arena-rating',
        data=body,
        headers={
            'Content-Type': 'application/json',
            'Authorization': f'Bearer {DD_TOKEN}',
        },
        method='POST',
    )
    try:
        with _dd_req.urlopen(req, timeout=5) as r:
            resp = _dd_json.loads(r.read())
        print(f'[Delta Drills] reported {DD_ATOM_ID} (subtopic={DD_SUBTOPIC!r})')
        print(f'[Delta Drills] EWMA updated: {resp}')
    except Exception as e:
        print(f'[Delta Drills] beacon failed: {e}')

report_completion()

# %% [markdown]
# <details><summary>Solution</summary>
#
# ```python
# import torch as t
#
# def dcgan_noise(batch_size: int, latent_dim: int, device) -> t.Tensor:
#     # shape must be (batch_size, latent_dim, 1, 1)
#     return t.randn(batch_size, latent_dim, 1, 1, device=device)
#
# # --- run it ---
# noise = dcgan_noise(8, 64, t.device('cpu'))
# print(f'shape: {noise.shape}')  # [8, 64, 1, 1]
# print(f'ndim : {noise.ndim}')   # 4
# ```
# </details>
