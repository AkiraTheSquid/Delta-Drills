# %% [markdown]
# # channel-list-reverse-build — faded example 3: Compute the generator pairs as the mirror of the discriminator pairs
#
# > Practice drill from [Delta Drills](https://delta-drills.vercel.app). Atom: `channel-list-reverse-build`. The last cell reports your progress on the `GAN: channel-list reverse build` subtopic back to Delta Drills.
#
# **Most of the code is already written — complete the one blanked step**, run the test to check it, then run the last cell to record your progress.

# %% [markdown]
# ## Setup

# %%
import numpy as np
import torch as t
from torch import Tensor
import einops
from einops import rearrange, reduce, repeat

t.manual_seed(0)
np.random.seed(0)
import matplotlib.pyplot as plt

# %% [markdown]
# ## Connect to Delta Drills
#
# Paste your Delta Drills auth token below so this drill can report progress on the `GAN: channel-list reverse build` subtopic. Copy it from your Delta Drills account page.
#
# This standalone exercises the atom **`channel-list-reverse-build`** (exercise 1). Completion fires the beacon at the bottom.

# %%
# === Delta Drills auth ===
DD_TOKEN = ""  # paste your token here, then run this cell
DD_ATOM_ID = "channel-list-reverse-build"
DD_SUBTOPIC = "GAN: channel-list reverse build"
DD_BACKEND_URL = "https://delta-drills-backend.fly.dev"

_dd_passed = set()

# %% [markdown]
# ## Concept
#
# _First time on this topic? Run the **Setup** cell above and skim it: every class and helper mentioned below is defined there. You don't need to have done any other drill first._
#
# Because both halves come from one list, the generator pairs are the exact mirror of the discriminator pairs: reverse the discriminator pair list and swap each tuple. This is algebraically identical to slice-reversing the channel list then pairing — a useful invariant check that the reverse was applied correctly.

# %% [markdown]
# ## Faded exercise 3
#
# ### Derive generator pairs from discriminator pairs by mirroring
#
# Complete `mirror_pairs(disc_pairs)`. Given the discriminator's consecutive `(in_c, out_c)` pairs, produce the generator's pairs *without* re-reversing the channel list — instead reverse the pair list and swap each tuple. Fill in the single line that builds `gen_pairs`.
#
# **Your task:** complete the one blanked step in the code cell below. The surrounding code, function signatures, and variable names are given — work out the missing expression yourself, then run the test.

# %%
def mirror_pairs(disc_pairs):
    gen_pairs = None  # TODO: fill in this step — read the prompt cell above
    return gen_pairs


def _test():
    hidden = [8, 16, 32, 64, 128]
    disc_pairs = list(zip(hidden[:-1], hidden[1:]))
    got = mirror_pairs(disc_pairs)
    rev = hidden[::-1]
    expected_gen = list(zip(rev[:-1], rev[1:]))
    assert got == expected_gen, (got, expected_gen)
    # idempotence: mirroring twice returns the original disc pairs
    assert mirror_pairs(got) == disc_pairs, mirror_pairs(got)


try:
    _test()
    _dd_passed.add('faded3')
    print('[Delta Drills] faded3 passed.')
except AssertionError as _e:
    print('Test failed:', _e)

# %% [markdown]
# ## Report your progress
#
# Run the cell below to send your progress to Delta Drills. It only counts if the test above passed.

# %%
# === Delta Drills completion beacon ===
import urllib.request as _dd_req, json as _dd_json

_DD_REQUIRED = {'faded3'}

def report_completion():
    missing = _DD_REQUIRED - _dd_passed
    if missing:
        print(f"[Delta Drills] {sorted(missing)} not yet passing — fix the cell above, then re-run this one.")
        return
    if not DD_TOKEN:
        print('[Delta Drills] DD_TOKEN is empty — completion not reported.')
        return
    body = _dd_json.dumps({
        'exercise_title': f'procedural-drill:{DD_ATOM_ID}:faded1',
        'subtopics': [DD_SUBTOPIC],
        'feedback': 'somewhat',
        'correct': True,
    }).encode('utf-8')
    req = _dd_req.Request(
        f'{DD_BACKEND_URL}/api/practice/arena-rating',
        data=body,
        headers={
            'Content-Type': 'application/json',
            'Authorization': f'Bearer {DD_TOKEN}',
        },
        method='POST',
    )
    try:
        with _dd_req.urlopen(req, timeout=5) as r:
            resp = _dd_json.loads(r.read())
        print(f'[Delta Drills] reported {DD_ATOM_ID} (subtopic={DD_SUBTOPIC!r})')
        print(f'[Delta Drills] EWMA updated: {resp}')
    except Exception as e:
        print(f'[Delta Drills] beacon failed: {e}')

report_completion()

# %% [markdown]
# <details><summary>Solution</summary>
#
# ```python
# def mirror_pairs(disc_pairs):
#     gen_pairs = [(c, d) for (d, c) in reversed(disc_pairs)]
#     return gen_pairs
# ```
# </details>
