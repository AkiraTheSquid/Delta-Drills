# %% [markdown]
# # generator-loss-fool-discriminator — faded example 1: Fill the generator's target labels
#
# > Faded drill from [Delta Drills](https://delta-drills.vercel.app). Atom: `generator-loss-fool-discriminator`. Running the beacon reports progress on the `GAN: Generator loss to fool D` subtopic.
#
# **Most of the solution is filled in — complete the one blanked step**, run the test, then fire the beacon. Less scaffolding than the worked example, more than the full drill.

# %% [markdown]
# ## Setup

# %%
import numpy as np
import torch as t
from torch import Tensor
import einops
from einops import rearrange, reduce, repeat

t.manual_seed(0)
np.random.seed(0)
import matplotlib.pyplot as plt

# %% [markdown]
# ## Connect to Delta Drills
#
# Paste your Delta Drills auth token below so this drill can report progress on the `GAN: Generator loss to fool D` subtopic. Copy it from your Delta Drills account page.
#
# This standalone exercises the atom **`generator-loss-fool-discriminator`** (exercise 1). Completion fires the beacon at the bottom.

# %%
# === Delta Drills auth ===
DD_TOKEN = ""  # paste your token here, then run this cell
DD_ATOM_ID = "generator-loss-fool-discriminator"
DD_SUBTOPIC = "GAN: Generator loss to fool D"
DD_BACKEND_URL = "https://delta-drills-backend.fly.dev"

_dd_passed = set()

# %% [markdown]
# ## Concept
#
# The non-saturating generator loss is BCE between D's probabilities on the fakes and an all-ones target — the generator labels its fakes 'real' so the gradient drives D's output toward 1.

# %% [markdown]
# ## Faded exercise 1
#
# Implement `generator_loss(d_pred_fake)`. `d_pred_fake` is D's probability output on the fake batch, shape `(B,)`. Build the all-ones target and return the BCE loss. Complete the blanked target construction.
#
# **Fill in:** the all-ones target tensor matching d_pred_fake's shape and dtype

# %%
import torch as t
import torch.nn.functional as F

t.manual_seed(3)

def generator_loss(d_pred_fake):
    targets = None  # TODO: the all-ones target tensor matching d_pred_fake's shape and dtype
    return F.binary_cross_entropy(d_pred_fake, targets)

print(float(generator_loss(t.full((8,), 0.7))))


def _test():
    pred = t.tensor([0.2, 0.5, 0.9, 0.99])
    out = generator_loss(pred)
    # independent ground truth: mean of -log(pred)
    expected = (-t.log(pred)).mean()
    assert t.allclose(out, expected, atol=1e-5), (out, expected)
    # monotone: more-fooled batch has lower loss
    assert float(generator_loss(t.full((4,), 0.95))) < float(generator_loss(t.full((4,), 0.05)))


try:
    _test()
    _dd_passed.add('faded1')
    print('[Delta Drills] faded1 passed.')
except AssertionError as _e:
    print('Test failed:', _e)

# %% [markdown]
# ## Report completion
#
# Run the cell below to report progress. The beacon fires only if the test above passed.

# %%
# === Delta Drills completion beacon ===
import urllib.request as _dd_req, json as _dd_json

_DD_REQUIRED = {'faded1'}

def report_completion():
    missing = _DD_REQUIRED - _dd_passed
    if missing:
        print(f"[Delta Drills] {sorted(missing)} not yet passing — fix the cell above, then re-run this one.")
        return
    if not DD_TOKEN:
        print('[Delta Drills] DD_TOKEN is empty — completion not reported.')
        return
    body = _dd_json.dumps({
        'exercise_title': f'procedural-drill:{DD_ATOM_ID}:faded1',
        'subtopics': [DD_SUBTOPIC],
        'feedback': 'somewhat',
        'correct': True,
    }).encode('utf-8')
    req = _dd_req.Request(
        f'{DD_BACKEND_URL}/api/practice/arena-rating',
        data=body,
        headers={
            'Content-Type': 'application/json',
            'Authorization': f'Bearer {DD_TOKEN}',
        },
        method='POST',
    )
    try:
        with _dd_req.urlopen(req, timeout=5) as r:
            resp = _dd_json.loads(r.read())
        print(f'[Delta Drills] reported {DD_ATOM_ID} (subtopic={DD_SUBTOPIC!r})')
        print(f'[Delta Drills] EWMA updated: {resp}')
    except Exception as e:
        print(f'[Delta Drills] beacon failed: {e}')

report_completion()

# %% [markdown]
# <details><summary>Solution</summary>
#
# ```python
# import torch as t
# import torch.nn.functional as F
#
# t.manual_seed(3)
#
# def generator_loss(d_pred_fake):
#     targets = t.ones_like(d_pred_fake)
#     return F.binary_cross_entropy(d_pred_fake, targets)
#
# print(float(generator_loss(t.full((8,), 0.7))))
# ```
# </details>
