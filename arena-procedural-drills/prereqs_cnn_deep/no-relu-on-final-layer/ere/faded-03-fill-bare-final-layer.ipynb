# %% [markdown]
# # no-relu-on-final-layer — faded example 3: leave the generator's final layer bare
#
# > Practice drill from [Delta Drills](https://delta-drills.vercel.app). Atom: `no-relu-on-final-layer`. The last cell reports your progress on the `CNN: No-ReLU on final layer` subtopic back to Delta Drills.
#
# **Most of the code is already written — complete the one blanked step**, run the test to check it, then run the last cell to record your progress.

# %% [markdown]
# ## Setup

# %%
import numpy as np
import torch as t
from torch import Tensor
import einops
from einops import rearrange, reduce, repeat

t.manual_seed(0)
np.random.seed(0)

# %% [markdown]
# ## Connect to Delta Drills
#
# Paste your Delta Drills auth token below so this drill can report progress on the `CNN: No-ReLU on final layer` subtopic. Copy it from your Delta Drills account page.
#
# This standalone exercises the atom **`no-relu-on-final-layer`** (exercise 1). Completion fires the beacon at the bottom.

# %%
# === Delta Drills auth ===
DD_TOKEN = ""  # paste your token here, then run this cell
DD_ATOM_ID = "no-relu-on-final-layer"
DD_SUBTOPIC = "CNN: No-ReLU on final layer"
DD_BACKEND_URL = "https://delta-drills-backend.fly.dev"

_dd_passed = set()

# %% [markdown]
# ## Concept
#
# _First time on this topic? Run the **Setup** cell above and skim it: every class and helper mentioned below is defined there. You don't need to have done any other drill first._
#
# In a generator/decoder, every block but the last has an activation; the final ConvTranspose must return its raw output so the model can emit any value. The final return is the bare transposed conv applied to the hidden state.

# %% [markdown]
# ## Faded exercise 3
#
# Complete `TinyGenerator.forward` so the last layer (`up2`) has no activation after it. Fill in the final return.
#
# **Your task:** complete the one blanked step in the code cell below. The surrounding code, function signatures, and variable names are given — work out the missing expression yourself, then run the test.

# %%
import torch as t
import torch.nn as nn

t.manual_seed(5)

class TinyGenerator(nn.Module):
    def __init__(self):
        super().__init__()
        self.up1 = nn.ConvTranspose2d(4, 8, kernel_size=4, stride=2, padding=1)
        self.up2 = nn.ConvTranspose2d(8, 1, kernel_size=4, stride=2, padding=1)
    def forward(self, z):
        h = t.relu(self.up1(z))
        raise NotImplementedError()  # TODO: fill in this step — read the prompt cell above

gen = TinyGenerator()
print(gen(t.randn(2, 4, 4, 4)).shape)


def _test():
    t.manual_seed(55)
    gen = TinyGenerator()
    z = t.randn(4, 4, 4, 4)
    out = gen(z)
    # two stride-2 upsamples: 4 -> 8 -> 16
    assert tuple(out.shape) == (4, 1, 16, 16)
    # bare final layer -> substantial negatives present
    assert (out < 0).float().mean().item() > 0.1


try:
    _test()
    _dd_passed.add('faded3')
    print('[Delta Drills] faded3 passed.')
except AssertionError as _e:
    print('Test failed:', _e)

# %% [markdown]
# ## Report your progress
#
# Run the cell below to send your progress to Delta Drills. It only counts if the test above passed.

# %%
# === Delta Drills completion beacon ===
import urllib.request as _dd_req, json as _dd_json

_DD_REQUIRED = {'faded3'}

def report_completion():
    missing = _DD_REQUIRED - _dd_passed
    if missing:
        print(f"[Delta Drills] {sorted(missing)} not yet passing — fix the cell above, then re-run this one.")
        return
    if not DD_TOKEN:
        print('[Delta Drills] DD_TOKEN is empty — completion not reported.')
        return
    body = _dd_json.dumps({
        'exercise_title': f'procedural-drill:{DD_ATOM_ID}:faded1',
        'subtopics': [DD_SUBTOPIC],
        'feedback': 'somewhat',
        'correct': True,
    }).encode('utf-8')
    req = _dd_req.Request(
        f'{DD_BACKEND_URL}/api/practice/arena-rating',
        data=body,
        headers={
            'Content-Type': 'application/json',
            'Authorization': f'Bearer {DD_TOKEN}',
        },
        method='POST',
    )
    try:
        with _dd_req.urlopen(req, timeout=5) as r:
            resp = _dd_json.loads(r.read())
        print(f'[Delta Drills] reported {DD_ATOM_ID} (subtopic={DD_SUBTOPIC!r})')
        print(f'[Delta Drills] EWMA updated: {resp}')
    except Exception as e:
        print(f'[Delta Drills] beacon failed: {e}')

report_completion()

# %% [markdown]
# <details><summary>Solution</summary>
#
# ```python
# import torch as t
# import torch.nn as nn
#
# t.manual_seed(5)
#
# class TinyGenerator(nn.Module):
#     def __init__(self):
#         super().__init__()
#         self.up1 = nn.ConvTranspose2d(4, 8, kernel_size=4, stride=2, padding=1)
#         self.up2 = nn.ConvTranspose2d(8, 1, kernel_size=4, stride=2, padding=1)
#     def forward(self, z):
#         h = t.relu(self.up1(z))
#         return self.up2(h)
#
# gen = TinyGenerator()
# print(gen(t.randn(2, 4, 4, 4)).shape)
# ```
# </details>
