# %% [markdown]
# # boolean-mask-identity-replace — faded example 1: Snap near-zero entries to exactly zero
#
# > Faded drill from [Delta Drills](https://delta-drills.vercel.app). Atom: `boolean-mask-identity-replace`. Running the beacon reports progress on the `Numpy: Indexing and selection` subtopic.
#
# **Most of the solution is filled in — complete the one blanked step**, run the test, then fire the beacon. Less scaffolding than the worked example, more than the full drill.

# %% [markdown]
# ## Setup

# %%
import numpy as np
import torch as t
from torch import Tensor

t.manual_seed(0)
np.random.seed(0)

# %% [markdown]
# ## Connect to Delta Drills
#
# Paste your Delta Drills auth token below so this drill can report progress on the `Numpy: Indexing and selection` subtopic.
# You can copy the token from your Delta Drills account page.
#
# This drill exercises the **atom `boolean-mask-identity-replace`**, which bridges to the bank subtopic `Numpy: Indexing and selection` for EWMA state. Completing all 5 exercises triggers a single `arena-rating` beacon at the end of the notebook.

# %%
# === Delta Drills auth ===
DD_TOKEN = ""  # paste your token here, then run this cell
DD_ATOM_ID = "boolean-mask-identity-replace"
DD_SUBTOPIC = "Numpy: Indexing and selection"
DD_BACKEND_URL = "https://delta-drills-backend.fly.dev"

# Track which exercises passed in this session.
_dd_passed = set()

# %% [markdown]
# ## Concept
#
# `x.abs() < eps` produces a bool mask flagging entries whose magnitude is below a tolerance. Writing `y[mask] = 0.0` through a clone snaps just those small entries to exactly zero without mutating the input — a common denoising / sparsification cleanup.

# %% [markdown]
# ## Faded exercise 1
#
# ### Snap near-zero entries to zero
#
# Implement `snap_small_to_zero(x, eps)` to return a **new** tensor where every entry of `x` with absolute value strictly below `eps` has been replaced with `0.0`. Entries with `|x| >= eps` are unchanged, and `x` must NOT be mutated.
#
# The clone and return are written for you. Complete the masked-write step.
#
# **Fill in:** the boolean-indexed write that sets every entry with absolute value below eps to 0.0

# %%
def snap_small_to_zero(x: Tensor, eps: float) -> Tensor:
    y = x.clone()
    raise NotImplementedError()  # TODO: the boolean-indexed write that sets every entry with absolute value below eps to 0.0
    return y


def _test():
    t.manual_seed(0)
    x = t.randn(3, 5)
    eps = 0.4
    out = snap_small_to_zero(x, eps)
    expected = x.clone()
    expected[x.abs() < eps] = 0.0
    assert t.equal(out, expected), 'output does not match reference snap'
    assert (out[out != 0].abs() >= eps).all(), 'a surviving entry is below eps'
    assert out.shape == x.shape
    # input must be untouched
    assert not x.requires_grad
    assert (x.abs() < eps).any(), 'test fixture should contain small entries'


try:
    _test()
    _dd_passed.add('faded1')
    print('[Delta Drills] faded1 passed.')
except AssertionError as _e:
    print('Test failed:', _e)

# %% [markdown]
# ## Report completion
#
# Run the cell below to report progress. The beacon fires only if the test above passed.

# %%
# === Delta Drills completion beacon ===
import urllib.request as _dd_req, json as _dd_json

_DD_REQUIRED = {'faded1'}

def report_completion():
    missing = _DD_REQUIRED - _dd_passed
    if missing:
        print(f"[Delta Drills] {sorted(missing)} not yet passing — fix the cell above, then re-run this one.")
        return
    if not DD_TOKEN:
        print('[Delta Drills] DD_TOKEN is empty — completion not reported.')
        return
    body = _dd_json.dumps({
        'exercise_title': f'procedural-drill:{DD_ATOM_ID}:faded1',
        'subtopics': [DD_SUBTOPIC],
        'feedback': 'somewhat',  # single-exercise standalone — neutral signal
        'correct': True,
    }).encode('utf-8')
    req = _dd_req.Request(
        f'{DD_BACKEND_URL}/api/practice/arena-rating',
        data=body,
        headers={
            'Content-Type': 'application/json',
            'Authorization': f'Bearer {DD_TOKEN}',
        },
        method='POST',
    )
    try:
        with _dd_req.urlopen(req, timeout=5) as r:
            resp = _dd_json.loads(r.read())
        print(f'[Delta Drills] reported {DD_ATOM_ID} (subtopic={DD_SUBTOPIC!r})')
        print(f'[Delta Drills] EWMA updated: {resp}')
    except Exception as e:
        print(f'[Delta Drills] beacon failed: {e}')

report_completion()

# %% [markdown]
# <details><summary>Solution</summary>
#
# ```python
# def snap_small_to_zero(x: Tensor, eps: float) -> Tensor:
#     y = x.clone()
#     y[y.abs() < eps] = 0.0
#     return y
# ```
# </details>
