# %% [markdown]
# # resnet-stem — faded example 1: Fill in the stem's 7x7 conv
#
# > Faded drill from [Delta Drills](https://delta-drills.vercel.app). Atom: `resnet-stem`. Running the beacon reports progress on the `CNN: ResNet stem block` subtopic.
#
# **Most of the solution is filled in — complete the one blanked step**, run the test, then fire the beacon. Less scaffolding than the worked example, more than the full drill.

# %% [markdown]
# ## Setup

# %%
import numpy as np
import torch as t
from torch import Tensor
import einops
from einops import rearrange, reduce, repeat

t.manual_seed(0)
np.random.seed(0)

# %% [markdown]
# ## Connect to Delta Drills
#
# Paste your Delta Drills auth token below so this drill can report progress on the `CNN: ResNet stem block` subtopic. Copy it from your Delta Drills account page.
#
# This standalone exercises the atom **`resnet-stem`** (exercise 1). Completion fires the beacon at the bottom.

# %%
# === Delta Drills auth ===
DD_TOKEN = ""  # paste your token here, then run this cell
DD_ATOM_ID = "resnet-stem"
DD_SUBTOPIC = "CNN: ResNet stem block"
DD_BACKEND_URL = "https://delta-drills-backend.fly.dev"

_dd_passed = set()

# %% [markdown]
# ## Concept
#
# The ResNet stem opens with a 7x7 stride-2 convolution, padding 3, with `bias=False` (BatchNorm follows). This conv lifts 3 channels to 64 and halves the spatial resolution.

# %% [markdown]
# ## Faded exercise 1
#
# The stem Sequential is partly built — BatchNorm, ReLU, and MaxPool are present. Complete the first layer: the 7x7 stride-2 conv that maps 3 channels to 64 with padding 3 and no bias.
#
# **Fill in:** construct the 7x7 stride-2 padding-3 Conv2d from 3 to 64 channels with bias=False

# %%
import torch.nn as nn


def build_stem():
    conv = None  # TODO: construct the 7x7 stride-2 padding-3 Conv2d from 3 to 64 channels with bias=False
    return nn.Sequential(
        conv,
        nn.BatchNorm2d(64),
        nn.ReLU(inplace=True),
        nn.MaxPool2d(kernel_size=3, stride=2, padding=1),
    )


stem = build_stem().eval()
x = t.zeros(1, 3, 224, 224)
out = stem(x)

def _test():
    stem = build_stem().eval()
    conv = stem[0]
    assert isinstance(conv, nn.Conv2d), 'first layer must be a Conv2d'
    assert conv.in_channels == 3 and conv.out_channels == 64
    assert conv.kernel_size == (7, 7) and conv.stride == (2, 2) and conv.padding == (3, 3)
    assert conv.bias is None, 'conv bias must be False before BatchNorm'
    out = stem(t.zeros(1, 3, 224, 224))
    assert tuple(out.shape) == (1, 64, 56, 56), 'stem must produce (1,64,56,56)'

try:
    _test()
    _dd_passed.add('faded1')
    print('[Delta Drills] faded1 passed.')
except AssertionError as _e:
    print('Test failed:', _e)

# %% [markdown]
# ## Report completion
#
# Run the cell below to report progress. The beacon fires only if the test above passed.

# %%
# === Delta Drills completion beacon ===
import urllib.request as _dd_req, json as _dd_json

_DD_REQUIRED = {'faded1'}

def report_completion():
    missing = _DD_REQUIRED - _dd_passed
    if missing:
        print(f"[Delta Drills] {sorted(missing)} not yet passing — fix the cell above, then re-run this one.")
        return
    if not DD_TOKEN:
        print('[Delta Drills] DD_TOKEN is empty — completion not reported.')
        return
    body = _dd_json.dumps({
        'exercise_title': f'procedural-drill:{DD_ATOM_ID}:faded1',
        'subtopics': [DD_SUBTOPIC],
        'feedback': 'somewhat',
        'correct': True,
    }).encode('utf-8')
    req = _dd_req.Request(
        f'{DD_BACKEND_URL}/api/practice/arena-rating',
        data=body,
        headers={
            'Content-Type': 'application/json',
            'Authorization': f'Bearer {DD_TOKEN}',
        },
        method='POST',
    )
    try:
        with _dd_req.urlopen(req, timeout=5) as r:
            resp = _dd_json.loads(r.read())
        print(f'[Delta Drills] reported {DD_ATOM_ID} (subtopic={DD_SUBTOPIC!r})')
        print(f'[Delta Drills] EWMA updated: {resp}')
    except Exception as e:
        print(f'[Delta Drills] beacon failed: {e}')

report_completion()

# %% [markdown]
# <details><summary>Solution</summary>
#
# ```python
# import torch.nn as nn
#
#
# def build_stem():
#     conv = nn.Conv2d(3, 64, kernel_size=7, stride=2, padding=3, bias=False)
#     return nn.Sequential(
#         conv,
#         nn.BatchNorm2d(64),
#         nn.ReLU(inplace=True),
#         nn.MaxPool2d(kernel_size=3, stride=2, padding=1),
#     )
#
#
# stem = build_stem().eval()
# x = t.zeros(1, 3, 224, 224)
# out = stem(x)
# ```
# </details>
