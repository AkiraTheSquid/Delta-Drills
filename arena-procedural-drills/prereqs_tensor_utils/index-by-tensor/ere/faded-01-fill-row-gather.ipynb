# %% [markdown]
# # index-by-tensor — faded example 1: Fill the row gather expression
#
# > Practice drill from [Delta Drills](https://delta-drills.vercel.app). Atom: `index-by-tensor`. The last cell reports your progress on the `PyTorch: index by tensor` subtopic back to Delta Drills.
#
# **Most of the code is already written — complete the one blanked step**, run the test to check it, then run the last cell to record your progress.

# %% [markdown]
# ## Setup

# %%
import numpy as np
import torch as t
from torch import Tensor
import einops
from einops import rearrange, reduce, repeat

t.manual_seed(0)
np.random.seed(0)

# %% [markdown]
# ## Connect to Delta Drills
#
# Paste your Delta Drills auth token below so this drill can report progress on the `PyTorch: index by tensor` subtopic. Copy it from your Delta Drills account page.
#
# This standalone exercises the atom **`index-by-tensor`** (exercise 1). Completion fires the beacon at the bottom.

# %%
# === Delta Drills auth ===
DD_TOKEN = ""  # paste your token here, then run this cell
DD_ATOM_ID = "index-by-tensor"
DD_SUBTOPIC = "PyTorch: index by tensor"
DD_BACKEND_URL = "https://delta-drills-backend.fly.dev"

_dd_passed = set()

# %% [markdown]
# ## Concept
#
# _First time on this topic? Run the **Setup** cell above and skim it: every class and helper mentioned below is defined there. You don't need to have done any other drill first._
#
# Indexing a `(N, D)` table with a 1-D `LongTensor` of length `K` selects those rows into a `(K, D)` result; the index shape becomes the leading shape.

# %% [markdown]
# ## Faded exercise 1
#
# Implement `gather_rows(table, idx)`. `table` is `(N, D)`, `idx` is a 1-D `LongTensor`. Return the gathered `(K, D)` rows using a single advanced-indexing expression. Complete the blanked return.
#
# **Your task:** complete the one blanked step in the code cell below. The surrounding code, function signatures, and variable names are given — work out the missing expression yourself, then run the test.

# %%
import torch as t

t.manual_seed(3)
table = t.randn(7, 4)
idx = t.tensor([6, 1, 1, 0])

def gather_rows(table, idx):
    out = None  # TODO: fill in this step — read the prompt cell above
    return out

print(gather_rows(table, idx).shape)


def _test():
    out = gather_rows(table, idx)
    assert out.shape == (4, 4), out.shape
    # independent ground truth: build each row by explicit scalar indexing
    expected = t.stack([table[int(i)] for i in idx])
    assert t.equal(out, expected)
    # dtype preserved
    assert out.dtype == table.dtype


try:
    _test()
    _dd_passed.add('faded1')
    print('[Delta Drills] faded1 passed.')
except AssertionError as _e:
    print('Test failed:', _e)

# %% [markdown]
# ## Report your progress
#
# Run the cell below to send your progress to Delta Drills. It only counts if the test above passed.

# %%
# === Delta Drills completion beacon ===
import urllib.request as _dd_req, json as _dd_json

_DD_REQUIRED = {'faded1'}

def report_completion():
    missing = _DD_REQUIRED - _dd_passed
    if missing:
        print(f"[Delta Drills] {sorted(missing)} not yet passing — fix the cell above, then re-run this one.")
        return
    if not DD_TOKEN:
        print('[Delta Drills] DD_TOKEN is empty — completion not reported.')
        return
    body = _dd_json.dumps({
        'exercise_title': f'procedural-drill:{DD_ATOM_ID}:faded1',
        'subtopics': [DD_SUBTOPIC],
        'feedback': 'somewhat',
        'correct': True,
    }).encode('utf-8')
    req = _dd_req.Request(
        f'{DD_BACKEND_URL}/api/practice/arena-rating',
        data=body,
        headers={
            'Content-Type': 'application/json',
            'Authorization': f'Bearer {DD_TOKEN}',
        },
        method='POST',
    )
    try:
        with _dd_req.urlopen(req, timeout=5) as r:
            resp = _dd_json.loads(r.read())
        print(f'[Delta Drills] reported {DD_ATOM_ID} (subtopic={DD_SUBTOPIC!r})')
        print(f'[Delta Drills] EWMA updated: {resp}')
    except Exception as e:
        print(f'[Delta Drills] beacon failed: {e}')

report_completion()

# %% [markdown]
# <details><summary>Solution</summary>
#
# ```python
# import torch as t
#
# t.manual_seed(3)
# table = t.randn(7, 4)
# idx = t.tensor([6, 1, 1, 0])
#
# def gather_rows(table, idx):
#     out = table[idx]
#     return out
#
# print(gather_rows(table, idx).shape)
# ```
# </details>
