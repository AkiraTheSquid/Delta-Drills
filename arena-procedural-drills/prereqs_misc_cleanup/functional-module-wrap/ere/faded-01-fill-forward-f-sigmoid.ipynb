# %% [markdown]
# # functional-module-wrap — faded example 1: Fill the forward of a Sigmoid wrap
#
# > Faded drill from [Delta Drills](https://delta-drills.vercel.app). Atom: `functional-module-wrap`. Running the beacon reports progress on the `PyTorch: functional module wrap` subtopic.
#
# **Most of the solution is filled in — complete the one blanked step**, run the test, then fire the beacon. Less scaffolding than the worked example, more than the full drill.

# %% [markdown]
# ## Setup

# %%
import numpy as np
import torch as t
from torch import Tensor
import einops
from einops import rearrange, reduce, repeat

t.manual_seed(0)
np.random.seed(0)

# %% [markdown]
# ## Connect to Delta Drills
#
# Paste your Delta Drills auth token below so this drill can report progress on the `PyTorch: functional module wrap` subtopic. Copy it from your Delta Drills account page.
#
# This standalone exercises the atom **`functional-module-wrap`** (exercise 1). Completion fires the beacon at the bottom.

# %%
# === Delta Drills auth ===
DD_TOKEN = ""  # paste your token here, then run this cell
DD_ATOM_ID = "functional-module-wrap"
DD_SUBTOPIC = "PyTorch: functional module wrap"
DD_BACKEND_URL = "https://delta-drills-backend.fly.dev"

_dd_passed = set()

# %% [markdown]
# ## Concept
#
# `nn.Sigmoid` is a stateless `nn.Module` whose `forward` calls `F.sigmoid` (equivalently `t.sigmoid`). Wrapping the functional makes it composable and visible in the module tree without holding any parameters.

# %% [markdown]
# ## Faded exercise 1
#
# Implement `MySigmoid(nn.Module)` whose `forward(x)` returns `F.sigmoid(x)`. Subclass `nn.Module` and call `super().__init__()`. Complete the blanked `forward` body — call the functional directly, do not instantiate `nn.Sigmoid`.
#
# **Fill in:** the forward body returning F.sigmoid(x)

# %%
import torch as t
import torch.nn as nn
import torch.nn.functional as F

t.manual_seed(3)

class MySigmoid(nn.Module):
    def __init__(self):
        super().__init__()

    def forward(self, x):
        raise NotImplementedError()  # TODO: the forward body returning F.sigmoid(x)

print(MySigmoid()(t.randn(4)))


def _test():
    m = MySigmoid()
    x = t.randn(6)
    out = m(x)
    # independent ground truth: the analytic logistic function
    expected = 1.0 / (1.0 + t.exp(-x))
    assert t.allclose(out, expected, atol=1e-6), (out, expected)
    # stateless: no parameters
    assert sum(1 for _ in m.parameters()) == 0
    # genuine nn.Module
    assert isinstance(m, nn.Module)


try:
    _test()
    _dd_passed.add('faded1')
    print('[Delta Drills] faded1 passed.')
except AssertionError as _e:
    print('Test failed:', _e)

# %% [markdown]
# ## Report completion
#
# Run the cell below to report progress. The beacon fires only if the test above passed.

# %%
# === Delta Drills completion beacon ===
import urllib.request as _dd_req, json as _dd_json

_DD_REQUIRED = {'faded1'}

def report_completion():
    missing = _DD_REQUIRED - _dd_passed
    if missing:
        print(f"[Delta Drills] {sorted(missing)} not yet passing — fix the cell above, then re-run this one.")
        return
    if not DD_TOKEN:
        print('[Delta Drills] DD_TOKEN is empty — completion not reported.')
        return
    body = _dd_json.dumps({
        'exercise_title': f'procedural-drill:{DD_ATOM_ID}:faded1',
        'subtopics': [DD_SUBTOPIC],
        'feedback': 'somewhat',
        'correct': True,
    }).encode('utf-8')
    req = _dd_req.Request(
        f'{DD_BACKEND_URL}/api/practice/arena-rating',
        data=body,
        headers={
            'Content-Type': 'application/json',
            'Authorization': f'Bearer {DD_TOKEN}',
        },
        method='POST',
    )
    try:
        with _dd_req.urlopen(req, timeout=5) as r:
            resp = _dd_json.loads(r.read())
        print(f'[Delta Drills] reported {DD_ATOM_ID} (subtopic={DD_SUBTOPIC!r})')
        print(f'[Delta Drills] EWMA updated: {resp}')
    except Exception as e:
        print(f'[Delta Drills] beacon failed: {e}')

report_completion()

# %% [markdown]
# <details><summary>Solution</summary>
#
# ```python
# import torch as t
# import torch.nn as nn
# import torch.nn.functional as F
#
# t.manual_seed(3)
#
# class MySigmoid(nn.Module):
#     def __init__(self):
#         super().__init__()
#
#     def forward(self, x):
#         return F.sigmoid(x)
#
# print(MySigmoid()(t.randn(4)))
# ```
# </details>
