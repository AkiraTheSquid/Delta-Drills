# %% [markdown]
# # rmul-scalar-tensor-mix — faded example 3: Why __mul__ alone is not enough
#
# > Faded drill from [Delta Drills](https://delta-drills.vercel.app). Atom: `rmul-scalar-tensor-mix`. Running the beacon reports progress on the `PyTorch: __rmul__ scalar/tensor mix` subtopic.
#
# **Most of the solution is filled in — complete the one blanked step**, run the test, then fire the beacon. Less scaffolding than the worked example, more than the full drill.

# %% [markdown]
# ## Setup

# %%
import numpy as np
import torch as t
from torch import Tensor
import einops
from einops import rearrange, reduce, repeat

t.manual_seed(0)
np.random.seed(0)

# %% [markdown]
# ## Connect to Delta Drills
#
# Paste your Delta Drills auth token below so this drill can report progress on the `PyTorch: __rmul__ scalar/tensor mix` subtopic. Copy it from your Delta Drills account page.
#
# This standalone exercises the atom **`rmul-scalar-tensor-mix`** (exercise 1). Completion fires the beacon at the bottom.

# %%
# === Delta Drills auth ===
DD_TOKEN = ""  # paste your token here, then run this cell
DD_ATOM_ID = "rmul-scalar-tensor-mix"
DD_SUBTOPIC = "PyTorch: __rmul__ scalar/tensor mix"
DD_BACKEND_URL = "https://delta-drills-backend.fly.dev"

_dd_passed = set()

# %% [markdown]
# ## Concept
#
# If a wrapper defines only `__mul__`, then `w * 2` works but `2 * w` fails (or returns the wrong thing) because Python asks `int.__mul__` first and never reaches the wrapper. Defining `__rmul__` is what catches the left-scalar case.

# %% [markdown]
# ## Faded exercise 3
#
# The `Scale` wrapper needs both directions to work. `__mul__` is provided. Complete `__rmul__` so that a left-side scalar multiply returns a `Scale` with the product.
#
# **Fill in:** implement __rmul__ to return Scale(self.data * other)

# %%
class Scale:
    def __init__(self, data):
        self.data = data
    def __mul__(self, other):
        return Scale(self.data * other)
    def __rmul__(self, other):
        result = None  # TODO: implement __rmul__ to return Scale(self.data * other)
        return result
    def __repr__(self):
        return f'Scale({self.data.tolist()})'


s = Scale(t.tensor([1.0, 5.0]))
out = 4 * s

def _test():
    s = Scale(t.tensor([1.0, 5.0]))
    out = 4 * s
    assert isinstance(out, Scale), '4 * s must dispatch to __rmul__ and return Scale'
    assert t.equal(out.data, t.tensor([4.0, 20.0])), 'must equal data * 4'

try:
    _test()
    _dd_passed.add('faded3')
    print('[Delta Drills] faded3 passed.')
except AssertionError as _e:
    print('Test failed:', _e)

# %% [markdown]
# ## Report completion
#
# Run the cell below to report progress. The beacon fires only if the test above passed.

# %%
# === Delta Drills completion beacon ===
import urllib.request as _dd_req, json as _dd_json

_DD_REQUIRED = {'faded3'}

def report_completion():
    missing = _DD_REQUIRED - _dd_passed
    if missing:
        print(f"[Delta Drills] {sorted(missing)} not yet passing — fix the cell above, then re-run this one.")
        return
    if not DD_TOKEN:
        print('[Delta Drills] DD_TOKEN is empty — completion not reported.')
        return
    body = _dd_json.dumps({
        'exercise_title': f'procedural-drill:{DD_ATOM_ID}:faded1',
        'subtopics': [DD_SUBTOPIC],
        'feedback': 'somewhat',
        'correct': True,
    }).encode('utf-8')
    req = _dd_req.Request(
        f'{DD_BACKEND_URL}/api/practice/arena-rating',
        data=body,
        headers={
            'Content-Type': 'application/json',
            'Authorization': f'Bearer {DD_TOKEN}',
        },
        method='POST',
    )
    try:
        with _dd_req.urlopen(req, timeout=5) as r:
            resp = _dd_json.loads(r.read())
        print(f'[Delta Drills] reported {DD_ATOM_ID} (subtopic={DD_SUBTOPIC!r})')
        print(f'[Delta Drills] EWMA updated: {resp}')
    except Exception as e:
        print(f'[Delta Drills] beacon failed: {e}')

report_completion()

# %% [markdown]
# <details><summary>Solution</summary>
#
# ```python
# class Scale:
#     def __init__(self, data):
#         self.data = data
#     def __mul__(self, other):
#         return Scale(self.data * other)
#     def __rmul__(self, other):
#         result = Scale(self.data * other)
#         return result
#     def __repr__(self):
#         return f'Scale({self.data.tolist()})'
#
#
# s = Scale(t.tensor([1.0, 5.0]))
# out = 4 * s
# ```
# </details>
