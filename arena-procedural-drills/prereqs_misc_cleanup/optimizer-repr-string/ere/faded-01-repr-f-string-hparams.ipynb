# %% [markdown]
# # optimizer-repr-string — faded example 1: Simple __repr__ via f-string with two hparams
#
# > Practice drill from [Delta Drills](https://delta-drills.vercel.app). Atom: `optimizer-repr-string`. The last cell reports your progress on the `Optimizer: __repr__ string` subtopic back to Delta Drills.
#
# **Most of the code is already written — complete the one blanked step**, run the test to check it, then run the last cell to record your progress.

# %% [markdown]
# ## Setup

# %%
import numpy as np
import torch as t
from torch import Tensor
import einops
from einops import rearrange, reduce, repeat

t.manual_seed(0)
np.random.seed(0)

# %% [markdown]
# ## Connect to Delta Drills
#
# Paste your Delta Drills auth token below so this drill can report progress on the `Optimizer: __repr__ string` subtopic. Copy it from your Delta Drills account page.
#
# This standalone exercises the atom **`optimizer-repr-string`** (exercise 1). Completion fires the beacon at the bottom.

# %%
# === Delta Drills auth ===
DD_TOKEN = ""  # paste your token here, then run this cell
DD_ATOM_ID = "optimizer-repr-string"
DD_SUBTOPIC = "Optimizer: __repr__ string"
DD_BACKEND_URL = "https://delta-drills-backend.fly.dev"

_dd_passed = set()

# %% [markdown]
# ## Concept
#
# _First time on this topic? Run the **Setup** cell above and skim it: every class and helper mentioned below is defined there. You don't need to have done any other drill first._
#
# The `__repr__` method returns a string in the format `ClassName(hparam1=value, hparam2=value)`. Using an f-string with direct attribute interpolation is the simplest implementation. The parameter tensor list is always excluded from the repr to keep output readable.

# %% [markdown]
# ## Faded exercise 1
#
# The `SGD` class is provided with `__init__`. Implement `__repr__` to return the string `'SGD(lr=<self.lr>, momentum=<self.momentum>)'` using an f-string. No trailing newline. Do not include `self.params` in the output.
#
# **Your task:** complete the one blanked step in the code cell below. The surrounding code, function signatures, and variable names are given — work out the missing expression yourself, then run the test.

# %%
import torch as t

class SGD:
    def __init__(self, params, lr, momentum=0.0):
        self.params   = list(params)
        self.lr       = lr
        self.momentum = momentum

    def __repr__(self):
        raise NotImplementedError()  # TODO: fill in this step — read the prompt cell above

# --- run it ---
opt = SGD([t.tensor([1.0])], lr=0.01, momentum=0.9)
print(repr(opt))  # SGD(lr=0.01, momentum=0.9)


def _test():
    import torch as t
    opt = SGD([t.tensor([1.0])], lr=0.01, momentum=0.9)
    assert repr(opt) == 'SGD(lr=0.01, momentum=0.9)', f'Got: {repr(opt)}'
    assert str(opt)  == 'SGD(lr=0.01, momentum=0.9)', '__str__ should equal __repr__'
    opt2 = SGD([t.tensor([1.0])], lr=1e-4)
    assert repr(opt2) == 'SGD(lr=0.0001, momentum=0.0)'


try:
    _test()
    _dd_passed.add('faded1')
    print('[Delta Drills] faded1 passed.')
except AssertionError as _e:
    print('Test failed:', _e)

# %% [markdown]
# ## Report your progress
#
# Run the cell below to send your progress to Delta Drills. It only counts if the test above passed.

# %%
# === Delta Drills completion beacon ===
import urllib.request as _dd_req, json as _dd_json

_DD_REQUIRED = {'faded1'}

def report_completion():
    missing = _DD_REQUIRED - _dd_passed
    if missing:
        print(f"[Delta Drills] {sorted(missing)} not yet passing — fix the cell above, then re-run this one.")
        return
    if not DD_TOKEN:
        print('[Delta Drills] DD_TOKEN is empty — completion not reported.')
        return
    body = _dd_json.dumps({
        'exercise_title': f'procedural-drill:{DD_ATOM_ID}:faded1',
        'subtopics': [DD_SUBTOPIC],
        'feedback': 'somewhat',
        'correct': True,
    }).encode('utf-8')
    req = _dd_req.Request(
        f'{DD_BACKEND_URL}/api/practice/arena-rating',
        data=body,
        headers={
            'Content-Type': 'application/json',
            'Authorization': f'Bearer {DD_TOKEN}',
        },
        method='POST',
    )
    try:
        with _dd_req.urlopen(req, timeout=5) as r:
            resp = _dd_json.loads(r.read())
        print(f'[Delta Drills] reported {DD_ATOM_ID} (subtopic={DD_SUBTOPIC!r})')
        print(f'[Delta Drills] EWMA updated: {resp}')
    except Exception as e:
        print(f'[Delta Drills] beacon failed: {e}')

report_completion()

# %% [markdown]
# <details><summary>Solution</summary>
#
# ```python
# import torch as t
#
# class SGD:
#     def __init__(self, params, lr, momentum=0.0):
#         self.params   = list(params)
#         self.lr       = lr
#         self.momentum = momentum
#
#     def __repr__(self):
#         return f'SGD(lr={self.lr}, momentum={self.momentum})'
#
# # --- run it ---
# opt = SGD([t.tensor([1.0])], lr=0.01, momentum=0.9)
# print(repr(opt))  # SGD(lr=0.01, momentum=0.9)
# ```
# </details>
