# %% [markdown]
# # einsum-contraction — faded example 2: Matrix trace via repeated index
#
# > Faded drill from [Delta Drills](https://delta-drills.vercel.app). Atom: `einsum-contraction`. Running the beacon reports progress on the `Einsum: Index contraction semantics` subtopic.
#
# **Most of the solution is filled in — complete the one blanked step**, run the test, then fire the beacon. Less scaffolding than the worked example, more than the full drill.

# %% [markdown]
# ## Setup

# %%
import numpy as np
import torch as t
from torch import Tensor
import einops
from einops import rearrange, reduce, repeat

t.manual_seed(0)
np.random.seed(0)

# %% [markdown]
# ## Connect to Delta Drills
#
# Paste your Delta Drills auth token below so this drill can report progress on the `Einsum: Index contraction semantics` subtopic. Copy it from your Delta Drills account page.
#
# This standalone exercises the atom **`einsum-contraction`** (exercise 1). Completion fires the beacon at the bottom.

# %%
# === Delta Drills auth ===
DD_TOKEN = ""  # paste your token here, then run this cell
DD_ATOM_ID = "einsum-contraction"
DD_SUBTOPIC = "Einsum: Index contraction semantics"
DD_BACKEND_URL = "https://delta-drills-backend.fly.dev"

_dd_passed = set()

# %% [markdown]
# ## Concept
#
# Repeating the same index label on one operand selects its diagonal; with no output indices, einsum sums that diagonal to a scalar. `'i i ->'` is therefore the matrix trace — sum of the diagonal entries.

# %% [markdown]
# ## Faded exercise 2
#
# Implement `trace_einsum(M)` for a square matrix `M` of shape `(N, N)`. Use a single `einops.einsum` with a repeated index to sum the diagonal, returning a scalar tensor. Complete the blanked einsum pattern string.
#
# **Fill in:** the einsum pattern that uses a repeated index to sum the diagonal to a scalar

# %%
import torch as t
import einops

t.manual_seed(4)
M = t.randn(5, 5)

def trace_einsum(M):
    pattern = None  # TODO: the einsum pattern that uses a repeated index to sum the diagonal to a scalar
    return einops.einsum(M, pattern)

print(trace_einsum(M))


def _test():
    out = trace_einsum(M)
    # independent ground truth via torch.trace
    gt = t.trace(M)
    assert out.shape == gt.shape, (out.shape, gt.shape)
    assert t.allclose(out, gt, atol=1e-5), (out, gt)


try:
    _test()
    _dd_passed.add('faded2')
    print('[Delta Drills] faded2 passed.')
except AssertionError as _e:
    print('Test failed:', _e)

# %% [markdown]
# ## Report completion
#
# Run the cell below to report progress. The beacon fires only if the test above passed.

# %%
# === Delta Drills completion beacon ===
import urllib.request as _dd_req, json as _dd_json

_DD_REQUIRED = {'faded2'}

def report_completion():
    missing = _DD_REQUIRED - _dd_passed
    if missing:
        print(f"[Delta Drills] {sorted(missing)} not yet passing — fix the cell above, then re-run this one.")
        return
    if not DD_TOKEN:
        print('[Delta Drills] DD_TOKEN is empty — completion not reported.')
        return
    body = _dd_json.dumps({
        'exercise_title': f'procedural-drill:{DD_ATOM_ID}:faded1',
        'subtopics': [DD_SUBTOPIC],
        'feedback': 'somewhat',
        'correct': True,
    }).encode('utf-8')
    req = _dd_req.Request(
        f'{DD_BACKEND_URL}/api/practice/arena-rating',
        data=body,
        headers={
            'Content-Type': 'application/json',
            'Authorization': f'Bearer {DD_TOKEN}',
        },
        method='POST',
    )
    try:
        with _dd_req.urlopen(req, timeout=5) as r:
            resp = _dd_json.loads(r.read())
        print(f'[Delta Drills] reported {DD_ATOM_ID} (subtopic={DD_SUBTOPIC!r})')
        print(f'[Delta Drills] EWMA updated: {resp}')
    except Exception as e:
        print(f'[Delta Drills] beacon failed: {e}')

report_completion()

# %% [markdown]
# <details><summary>Solution</summary>
#
# ```python
# import torch as t
# import einops
#
# t.manual_seed(4)
# M = t.randn(5, 5)
#
# def trace_einsum(M):
#     pattern = 'i i ->'
#     return einops.einsum(M, pattern)
#
# print(trace_einsum(M))
# ```
# </details>
