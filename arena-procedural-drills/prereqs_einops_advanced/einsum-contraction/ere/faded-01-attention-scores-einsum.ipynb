# %% [markdown]
# # einsum-contraction — faded example 1: Attention scores via einsum contraction
#
# > Practice drill from [Delta Drills](https://delta-drills.vercel.app). Atom: `einsum-contraction`. The last cell reports your progress on the `Einsum: Index contraction semantics` subtopic back to Delta Drills.
#
# **Most of the code is already written — complete the one blanked step**, run the test to check it, then run the last cell to record your progress.

# %% [markdown]
# ## Setup

# %%
import numpy as np
import torch as t
from torch import Tensor
import einops
from einops import rearrange, reduce, repeat

t.manual_seed(0)
np.random.seed(0)

# %% [markdown]
# ## Connect to Delta Drills
#
# Paste your Delta Drills auth token below so this drill can report progress on the `Einsum: Index contraction semantics` subtopic. Copy it from your Delta Drills account page.
#
# This standalone exercises the atom **`einsum-contraction`** (exercise 1). Completion fires the beacon at the bottom.

# %%
# === Delta Drills auth ===
DD_TOKEN = ""  # paste your token here, then run this cell
DD_ATOM_ID = "einsum-contraction"
DD_SUBTOPIC = "Einsum: Index contraction semantics"
DD_BACKEND_URL = "https://delta-drills-backend.fly.dev"

_dd_passed = set()

# %% [markdown]
# ## Concept
#
# _First time on this topic? Run the **Setup** cell above and skim it: every class and helper mentioned below is defined there. You don't need to have done any other drill first._
#
# Raw attention scores are `Q @ Kᵀ` per batch element. As an einsum, the head/feature axis `d` is shared by queries and keys and is contracted, while the query position `t` and key position `s` are preserved, producing the `(B, T, S)` score matrix.

# %% [markdown]
# ## Faded exercise 1
#
# Implement `attention_scores(Q, K)`. `Q` has shape `(B, T, D)` and `K` has shape `(B, S, D)`. Return the `(B, T, S)` raw attention scores using a single `einops.einsum`, contracting the feature axis `d`. Complete the blanked einsum pattern string.
#
# **Your task:** complete the one blanked step in the code cell below. The surrounding code, function signatures, and variable names are given — work out the missing expression yourself, then run the test.

# %%
import torch as t
import einops

t.manual_seed(3)
Q = t.randn(2, 3, 4)
K = t.randn(2, 5, 4)

def attention_scores(Q, K):
    pattern = None  # TODO: fill in this step — read the prompt cell above
    return einops.einsum(Q, K, pattern)

print(attention_scores(Q, K).shape)


def _test():
    out = attention_scores(Q, K)
    assert out.shape == (2, 3, 5), out.shape
    # independent ground truth: batched Q @ K^T
    gt = t.bmm(Q, K.transpose(1, 2))
    assert t.allclose(out, gt, atol=1e-5), (out - gt).abs().max()


try:
    _test()
    _dd_passed.add('faded1')
    print('[Delta Drills] faded1 passed.')
except AssertionError as _e:
    print('Test failed:', _e)

# %% [markdown]
# ## Report your progress
#
# Run the cell below to send your progress to Delta Drills. It only counts if the test above passed.

# %%
# === Delta Drills completion beacon ===
import urllib.request as _dd_req, json as _dd_json

_DD_REQUIRED = {'faded1'}

def report_completion():
    missing = _DD_REQUIRED - _dd_passed
    if missing:
        print(f"[Delta Drills] {sorted(missing)} not yet passing — fix the cell above, then re-run this one.")
        return
    if not DD_TOKEN:
        print('[Delta Drills] DD_TOKEN is empty — completion not reported.')
        return
    body = _dd_json.dumps({
        'exercise_title': f'procedural-drill:{DD_ATOM_ID}:faded1',
        'subtopics': [DD_SUBTOPIC],
        'feedback': 'somewhat',
        'correct': True,
    }).encode('utf-8')
    req = _dd_req.Request(
        f'{DD_BACKEND_URL}/api/practice/arena-rating',
        data=body,
        headers={
            'Content-Type': 'application/json',
            'Authorization': f'Bearer {DD_TOKEN}',
        },
        method='POST',
    )
    try:
        with _dd_req.urlopen(req, timeout=5) as r:
            resp = _dd_json.loads(r.read())
        print(f'[Delta Drills] reported {DD_ATOM_ID} (subtopic={DD_SUBTOPIC!r})')
        print(f'[Delta Drills] EWMA updated: {resp}')
    except Exception as e:
        print(f'[Delta Drills] beacon failed: {e}')

report_completion()

# %% [markdown]
# <details><summary>Solution</summary>
#
# ```python
# import torch as t
# import einops
#
# t.manual_seed(3)
# Q = t.randn(2, 3, 4)
# K = t.randn(2, 5, 4)
#
# def attention_scores(Q, K):
#     pattern = 'b t d, b s d -> b t s'
#     return einops.einsum(Q, K, pattern)
#
# print(attention_scores(Q, K).shape)
# ```
# </details>
