# %% [markdown]
# # kaiming-uniform-init — faded example 1: Compute the Kaiming bound — fill in the formula
#
# > Practice drill from [Delta Drills](https://delta-drills.vercel.app). Atom: `kaiming-uniform-init`. The last cell reports your progress on the `Init: Kaiming uniform` subtopic back to Delta Drills.
#
# **Most of the code is already written — complete the one blanked step**, run the test to check it, then run the last cell to record your progress.

# %% [markdown]
# ## Setup

# %%
import numpy as np
import torch as t
from torch import Tensor
import einops
from einops import rearrange, reduce, repeat

t.manual_seed(0)
np.random.seed(0)
import math
import matplotlib.pyplot as plt

# %% [markdown]
# ## Connect to Delta Drills
#
# Paste your Delta Drills auth token below so this drill can report progress on the `Init: Kaiming uniform` subtopic. Copy it from your Delta Drills account page.
#
# This standalone exercises the atom **`kaiming-uniform-init`** (exercise 1). Completion fires the beacon at the bottom.

# %%
# === Delta Drills auth ===
DD_TOKEN = ""  # paste your token here, then run this cell
DD_ATOM_ID = "kaiming-uniform-init"
DD_SUBTOPIC = "Init: Kaiming uniform"
DD_BACKEND_URL = "https://delta-drills-backend.fly.dev"

_dd_passed = set()

# %% [markdown]
# ## Concept
#
# _First time on this topic? Run the **Setup** cell above and skim it: every class and helper mentioned below is defined there. You don't need to have done any other drill first._
#
# The Kaiming-uniform bound for a `Linear` layer is `1/sqrt(fan_in)`, where `fan_in` is the number of input features. This value sets both the upper and lower limits of the uniform distribution used to initialize the weight and bias parameters.

# %% [markdown]
# ## Faded exercise 1
#
# A `KaimingLinear.__init__` is mostly written. Fill in the computation of `bound` using the Kaiming-uniform formula, then use it to sample the weight and bias tensors.
#
# **Your task:** complete the one blanked step in the code cell below. The surrounding code, function signatures, and variable names are given — work out the missing expression yourself, then run the test.

# %%
import torch as t
import torch.nn as nn
import math

t.manual_seed(3)

class KaimingLinear(nn.Module):
    def __init__(self, in_features: int, out_features: int):
        super().__init__()
        self.in_features = in_features
        self.out_features = out_features
        bound = 1.0 / math.sqrt(in_features)
        w_init = t.empty(out_features, in_features).uniform_(-bound, bound)
        self.weight = nn.Parameter(w_init)
        b_init = t.empty(out_features).uniform_(-bound, bound)
        self.bias = nn.Parameter(b_init)

    def forward(self, x):
        return x @ self.weight.T + self.bias


def _test():
    import torch as t
    import math

    t.manual_seed(3)
    layer = KaimingLinear(20, 10)
    expected_bound = 1.0 / math.sqrt(20)
    eps = 1e-6
    assert layer.weight.shape == (10, 20)
    assert layer.bias.shape == (10,)
    assert layer.weight.abs().max().item() <= expected_bound + eps, 'weight outside bound'
    assert layer.bias.abs().max().item() <= expected_bound + eps, 'bias outside bound'
    # forward shape
    x = t.randn(4, 20)
    out = layer(x)
    assert out.shape == (4, 10)


try:
    _test()
    _dd_passed.add('faded1')
    print('[Delta Drills] faded1 passed.')
except AssertionError as _e:
    print('Test failed:', _e)

# %% [markdown]
# ## Report your progress
#
# Run the cell below to send your progress to Delta Drills. It only counts if the test above passed.

# %%
# === Delta Drills completion beacon ===
import urllib.request as _dd_req, json as _dd_json

_DD_REQUIRED = {'faded1'}

def report_completion():
    missing = _DD_REQUIRED - _dd_passed
    if missing:
        print(f"[Delta Drills] {sorted(missing)} not yet passing — fix the cell above, then re-run this one.")
        return
    if not DD_TOKEN:
        print('[Delta Drills] DD_TOKEN is empty — completion not reported.')
        return
    body = _dd_json.dumps({
        'exercise_title': f'procedural-drill:{DD_ATOM_ID}:faded1',
        'subtopics': [DD_SUBTOPIC],
        'feedback': 'somewhat',
        'correct': True,
    }).encode('utf-8')
    req = _dd_req.Request(
        f'{DD_BACKEND_URL}/api/practice/arena-rating',
        data=body,
        headers={
            'Content-Type': 'application/json',
            'Authorization': f'Bearer {DD_TOKEN}',
        },
        method='POST',
    )
    try:
        with _dd_req.urlopen(req, timeout=5) as r:
            resp = _dd_json.loads(r.read())
        print(f'[Delta Drills] reported {DD_ATOM_ID} (subtopic={DD_SUBTOPIC!r})')
        print(f'[Delta Drills] EWMA updated: {resp}')
    except Exception as e:
        print(f'[Delta Drills] beacon failed: {e}')

report_completion()

# %% [markdown]
# <details><summary>Solution</summary>
#
# ```python
# import torch as t
# import torch.nn as nn
# import math
#
# t.manual_seed(3)
#
# class KaimingLinear(nn.Module):
#     def __init__(self, in_features: int, out_features: int):
#         super().__init__()
#         self.in_features = in_features
#         self.out_features = out_features
#         bound = 1.0 / math.sqrt(in_features)
#         w_init = t.empty(out_features, in_features).uniform_(-bound, bound)
#         self.weight = nn.Parameter(w_init)
#         b_init = t.empty(out_features).uniform_(-bound, bound)
#         self.bias = nn.Parameter(b_init)
#
#     def forward(self, x):
#         return x @ self.weight.T + self.bias
# ```
# </details>
