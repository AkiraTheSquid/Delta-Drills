# %% [markdown]
# # exp-back — faded example 3: exp_back on a 2-D Matrix: Shape Preservation
#
# > Practice drill from [Delta Drills](https://delta-drills.vercel.app). Atom: `exp-back`. The last cell reports your progress on the `Backprop: exp_back` subtopic back to Delta Drills.
#
# **Most of the code is already written — complete the one blanked step**, run the test to check it, then run the last cell to record your progress.

# %% [markdown]
# ## Setup

# %%
import numpy as np
import torch as t
from torch import Tensor
import einops
from einops import rearrange, reduce, repeat

t.manual_seed(0)
np.random.seed(0)

# %% [markdown]
# ## Connect to Delta Drills
#
# Paste your Delta Drills auth token below so this drill can report progress on the `Backprop: exp_back` subtopic. Copy it from your Delta Drills account page.
#
# This standalone exercises the atom **`exp-back`** (exercise 1). Completion fires the beacon at the bottom.

# %%
# === Delta Drills auth ===
DD_TOKEN = ""  # paste your token here, then run this cell
DD_ATOM_ID = "exp-back"
DD_SUBTOPIC = "Backprop: exp_back"
DD_BACKEND_URL = "https://delta-drills-backend.fly.dev"

_dd_passed = set()

# %% [markdown]
# ## Concept
#
# _First time on this topic? Run the **Setup** cell above and skim it: every class and helper mentioned below is defined there. You don't need to have done any other drill first._
#
# The `exp_back` function is purely elementwise — it multiplies two tensors of identical shape. This means it works identically on scalars, vectors, and matrices without any modification. The returned gradient always has the same shape as the input `x`, which is the requirement for any elementwise backward function.

# %% [markdown]
# ## Faded exercise 3
#
# Implement `exp_back_2d(grad_out, out)` (no `x` parameter needed — the cached `out = exp(x)` is sufficient). Return `dL/dx = grad_out * out`. Then verify it gives the correct gradient for a `(3, 4)` input matrix by checking against torch.autograd.
#
# **Your task:** complete the one blanked step in the code cell below. The surrounding code, function signatures, and variable names are given — work out the missing expression yourself, then run the test.

# %%
import torch as t
from torch import Tensor

def exp_back_2d(grad_out: Tensor, out: Tensor) -> Tensor:
    raise NotImplementedError()  # TODO: fill in this step — read the prompt cell above


def _test():
    import torch as t
    t.manual_seed(9)
    x = t.randn(3, 4)
    out = t.exp(x)
    grad_out = t.randn(3, 4)
    my_grad = exp_back_2d(grad_out, out)
    assert my_grad.shape == (3, 4)
    # compare to autograd
    xa = x.clone().requires_grad_(True)
    (grad_out * t.exp(xa)).sum().backward()
    assert t.allclose(my_grad, xa.grad, atol=1e-6)


try:
    _test()
    _dd_passed.add('faded3')
    print('[Delta Drills] faded3 passed.')
except AssertionError as _e:
    print('Test failed:', _e)

# %% [markdown]
# ## Report your progress
#
# Run the cell below to send your progress to Delta Drills. It only counts if the test above passed.

# %%
# === Delta Drills completion beacon ===
import urllib.request as _dd_req, json as _dd_json

_DD_REQUIRED = {'faded3'}

def report_completion():
    missing = _DD_REQUIRED - _dd_passed
    if missing:
        print(f"[Delta Drills] {sorted(missing)} not yet passing — fix the cell above, then re-run this one.")
        return
    if not DD_TOKEN:
        print('[Delta Drills] DD_TOKEN is empty — completion not reported.')
        return
    body = _dd_json.dumps({
        'exercise_title': f'procedural-drill:{DD_ATOM_ID}:faded1',
        'subtopics': [DD_SUBTOPIC],
        'feedback': 'somewhat',
        'correct': True,
    }).encode('utf-8')
    req = _dd_req.Request(
        f'{DD_BACKEND_URL}/api/practice/arena-rating',
        data=body,
        headers={
            'Content-Type': 'application/json',
            'Authorization': f'Bearer {DD_TOKEN}',
        },
        method='POST',
    )
    try:
        with _dd_req.urlopen(req, timeout=5) as r:
            resp = _dd_json.loads(r.read())
        print(f'[Delta Drills] reported {DD_ATOM_ID} (subtopic={DD_SUBTOPIC!r})')
        print(f'[Delta Drills] EWMA updated: {resp}')
    except Exception as e:
        print(f'[Delta Drills] beacon failed: {e}')

report_completion()

# %% [markdown]
# <details><summary>Solution</summary>
#
# ```python
# import torch as t
# from torch import Tensor
#
# def exp_back_2d(grad_out: Tensor, out: Tensor) -> Tensor:
#     return grad_out * out
# ```
# </details>
