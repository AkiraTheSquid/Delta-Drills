# %% [markdown]
# # Optimizers: EWMA running statistics (BatchNorm / Adam / RMSprop)
#
# **Practice notebook — Delta Drills #458**
#
# This drill uses PyTorch, which the Delta Drills in-app runner can't execute. Work it here, run your code, then return to Delta Drills and rate yourself. The full worked answer is in the separate *solution* notebook (Show solution in the app).

# %% [markdown]
# ## Problem
#
# Adam's first-moment estimate is an EWMA of the gradients with decay `beta`: the moment keeps a `beta` share of itself and absorbs a `(1-beta)` share of each new gradient — the same update as the previous drill with $\mu = 1-\beta$. The starter has `m` at zeros, beta 0.9, and three gradients to fold in, in order. Print the final biased (un-corrected) moment: print([round(float(x), 4) for x in m]).

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# Use the running-stat update with mu = 1 - beta, applied component-wise to each gradient in order; skip any bias correction.
#
# </details>

# %%
# %pip install -q numpy torch --index-url https://download.pytorch.org/whl/cpu

# %% [markdown]
# ## Your solution
#
# Edit the cell below and run it. Print exactly what the problem asks.

# %%
import torch
beta = 0.9
m = torch.zeros(2)
grads = [
    torch.tensor([1.0, -2.0]),
    torch.tensor([3.0, 0.0]),
    torch.tensor([-1.0, 4.0]),
]
# TODO: for each g, apply Adam first-moment EWMA
for g in grads:
    pass  # TODO: update m
print([round(float(x), 4) for x in m])
