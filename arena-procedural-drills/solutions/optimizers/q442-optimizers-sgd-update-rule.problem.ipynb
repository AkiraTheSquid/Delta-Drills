# %% [markdown]
# # Optimizers: SGD update rule
#
# **Practice notebook — Delta Drills #442**
#
# This drill uses PyTorch, which the Delta Drills in-app runner can't execute. Work it here, run your code, then return to Delta Drills and rate yourself. The full worked answer is in the separate *solution* notebook (Show solution in the app).

# %% [markdown]
# ## Problem
#
# Minimize $(x-5)^2$ from $x=2$ with three hand-rolled gradient-descent steps (lr 0.3 — all in the starter). Each step: build the loss, backprop it, update `x` in place inside `torch.no_grad()` (why is that context required for a leaf that requires grad?), and zero the gradient before the next iteration (what would accumulate if you didn't?). Then print round(float(x.detach()), 4).

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# Loop three times: backward for the gradient, then update x in-place under no_grad and clear x.grad.
#
# </details>

# %%
# %pip install -q numpy torch --index-url https://download.pytorch.org/whl/cpu

# %% [markdown]
# ## Your solution
#
# Edit the cell below and run it. Print exactly what the problem asks.

# %%
import torch
x = torch.tensor([2.0], requires_grad=True)
lr = 0.3
for _ in range(3):
    # TODO: compute loss
    # then under torch.no_grad() do x -= lr * x.grad, then x.grad.zero_()
    raise NotImplementedError()
print(round(float(x.detach()), 4))
