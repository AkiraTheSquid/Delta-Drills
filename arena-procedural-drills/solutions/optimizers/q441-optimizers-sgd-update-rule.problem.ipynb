# %% [markdown]
# # Optimizers: SGD update rule
#
# **Practice notebook — Delta Drills #441**
#
# This drill uses PyTorch, which the Delta Drills in-app runner can't execute. Work it here, run your code, then return to Delta Drills and rate yourself. The full worked answer is in the separate *solution* notebook (Show solution in the app).

# %% [markdown]
# ## Problem
#
# One step of vanilla SGD by hand: parameters move a small step AGAINST the gradient. The starter gives `theta`, `grad`, and `lr` as float64 tensors. Apply the SGD update rule from memory to get `theta_new`, and print [round(v, 4) for v in theta_new.tolist()].

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# Subtract lr times the gradient from the parameters — one elementwise update.
#
# </details>

# %%
# %pip install -q numpy torch --index-url https://download.pytorch.org/whl/cpu

# %% [markdown]
# ## Your solution
#
# Edit the cell below and run it. Print exactly what the problem asks.

# %%
import torch
theta = torch.tensor([1.0, 2.0, 3.0], dtype=torch.float64)
grad = torch.tensor([0.5, -1.0, 2.0], dtype=torch.float64)
lr = 0.1
# TODO: apply one vanilla SGD step
theta_new = None  # TODO: fill in theta_new
print([round(v, 4) for v in theta_new.tolist()])
