# %% [markdown]
# # PyTorch Fundamentals: Freezing parameters with requires_grad_
#
# **Practice notebook — Delta Drills #478**
#
# This drill uses PyTorch, which the Delta Drills in-app runner can't execute. Work it here, run your code, then return to Delta Drills and rate yourself. The full worked answer is in the separate *solution* notebook (Show solution in the app).

# %% [markdown]
# ## Problem
#
# A frozen module's output is detached from the autograd graph. Freeze the starter's `nn.Linear(4, 1)` with one recursive call, run `x` through it and sum to get `y`. Print two lines: print(y.requires_grad), then print(y.grad_fn is None) — both tell the same story from different angles.

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# If no input to an operation requires grad, the result carries neither a requires_grad flag nor a grad_fn.
#
# </details>

# %%
# %pip install -q numpy torch --index-url https://download.pytorch.org/whl/cpu

# %% [markdown]
# ## Your solution
#
# Edit the cell below and run it. Print exactly what the problem asks.

# %%
import torch
import torch.nn as nn

torch.manual_seed(0)
model = nn.Linear(4, 1)
# TODO: freeze the model
x = torch.tensor([[1.0, 2.0, 3.0, 4.0]])
y = None  # TODO: fill in y
print(y.requires_grad)
print(y.grad_fn is None)
