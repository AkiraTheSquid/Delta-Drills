# %% [markdown]
# # PyTorch Fundamentals: nn.Module extra_repr
#
# **Practice notebook — Delta Drills #470**
#
# This drill uses PyTorch, which the Delta Drills in-app runner can't execute. Work it here, run your code, then return to Delta Drills and rate yourself. The full worked answer is in the separate *solution* notebook (Show solution in the app).

# %% [markdown]
# ## Problem
#
# When a module has BOTH an `extra_repr` and child submodules, the printed repr interleaves them. Build `MyBlock(nn.Module)`: `__init__` stores `channels` and `p` as attributes and creates the child `self.lin = nn.Linear(channels, channels)`; `extra_repr` returns `channels=..., p=...`. Construct `MyBlock(3, 0.5)` and print(repr(m)) — note where your extra_repr line lands relative to the `(lin): ...` child line.

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# With a submodule present, the repr expands to multiple indented lines: your extra_repr first, then each child module.
#
# </details>

# %%
# %pip install -q numpy torch --index-url https://download.pytorch.org/whl/cpu

# %% [markdown]
# ## Your solution
#
# Edit the cell below and run it. Print exactly what the problem asks.

# %%
import torch.nn as nn

class MyBlock(nn.Module):
    def __init__(self, channels, p):
        super().__init__()
        # TODO: complete this step (see the problem statement above)
        raise NotImplementedError()
    def extra_repr(self):
        # TODO: complete this step (see the problem statement above)
        raise NotImplementedError()

m = MyBlock(3, 0.5)
print(repr(m))
