# %% [markdown]
# # PyTorch Fundamentals: BatchNorm variance: biased vs unbiased
#
# **Practice notebook — Delta Drills #453**
#
# This drill uses PyTorch, which the Delta Drills in-app runner can't execute. Work it here, run your code, then return to Delta Drills and rate yourself. The full worked answer is in the separate *solution* notebook (Show solution in the app).

# %% [markdown]
# ## Problem
#
# `.var()` hides a convention choice: BIASED divides by $N$, UNBIASED by $N-1$ — and BatchNorm normalizes with the biased one while torch's default is unbiased. On the starter's 2×4 tensor, compute the variance over ALL elements both ways (the `unbiased=` flag) and print [biased, unbiased] with each value round(float(v), 4).

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# Call .var twice, toggling the unbiased flag; the only difference is dividing by N versus N-1.
#
# </details>

# %%
# %pip install -q numpy torch --index-url https://download.pytorch.org/whl/cpu

# %% [markdown]
# ## Your solution
#
# Edit the cell below and run it. Print exactly what the problem asks.

# %%
import torch
x = torch.tensor([[1.,2.,3.,4.],[5.,6.,7.,8.]])
# TODO: compute variance over ALL elements both ways
var_biased = None  # TODO: fill in var_biased
var_unbiased = None  # TODO: fill in var_unbiased
print([round(float(var_biased),4), round(float(var_unbiased),4)])
