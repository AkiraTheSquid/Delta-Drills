# %% [markdown]
# # PyTorch Fundamentals: BatchNorm variance: biased vs unbiased
#
# **Practice notebook — Delta Drills #454**
#
# This drill uses PyTorch, which the Delta Drills in-app runner can't execute. Work it here, run your code, then return to Delta Drills and rate yourself. The full worked answer is in the separate *solution* notebook (Show solution in the app).

# %% [markdown]
# ## Problem
#
# BatchNorm2d computes PER-CHANNEL statistics over the batch and spatial dims. On the starter's (2, 3, 2, 2) tensor, compute the per-channel mean and the BIASED variance — reduce over exactly the dims that are not the channel dim. Print mean.tolist() on the first line, then [round(v,4) for v in var.tolist()] on the second.

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# Reduce over every axis except the channel axis (dim 1), and use the biased variance flag.
#
# </details>

# %%
# %pip install -q numpy torch --index-url https://download.pytorch.org/whl/cpu

# %% [markdown]
# ## Your solution
#
# Edit the cell below and run it. Print exactly what the problem asks.

# %%
import torch
x = torch.arange(24, dtype=torch.float32).reshape(2,3,2,2)
# TODO: per-channel mean and BIASED variance over dims (0,2,3)
mean = None  # TODO: fill in mean
var = None  # TODO: fill in var
print(mean.tolist())
print([round(v,4) for v in var.tolist()])
