# %% [markdown]
# # PyTorch Fundamentals: Autograd: .grad on leaf parameters
#
# **Practice notebook — Delta Drills #475**
#
# This drill uses PyTorch, which the Delta Drills in-app runner can't execute. Work it here, run your code, then return to Delta Drills and rate yourself. The full worked answer is in the separate *solution* notebook (Show solution in the app).

# %% [markdown]
# ## Problem
#
# A gradient always has the same shape as its parameter. The starter gives a matrix `W` (requires grad) and a constant vector `x`. Build the scalar loss: the sum of squares of the matvec $Wx$. Backprop, then print two lines: print(W.grad.shape == W.shape), then print(W.grad.tolist()).

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# The gradient of each weight is 2 times the corresponding pre-activation output times the input feature that multiplied it.
#
# </details>

# %%
# %pip install -q numpy torch --index-url https://download.pytorch.org/whl/cpu

# %% [markdown]
# ## Your solution
#
# Edit the cell below and run it. Print exactly what the problem asks.

# %%
import torch
W = torch.tensor([[1.0, 2.0], [3.0, 4.0]], requires_grad=True)
x = torch.tensor([1.0, 1.0])
# TODO: compute loss
print(W.grad.shape == W.shape)
print(W.grad.tolist())
