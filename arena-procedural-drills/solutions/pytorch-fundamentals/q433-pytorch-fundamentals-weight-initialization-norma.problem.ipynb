# %% [markdown]
# # PyTorch Fundamentals: Weight Initialization (normal_ / constant_)
#
# **Practice notebook — Delta Drills #433**
#
# This drill uses PyTorch, which the Delta Drills in-app runner can't execute. Work it here, run your code, then return to Delta Drills and rate yourself. The full worked answer is in the separate *solution* notebook (Show solution in the app).

# %% [markdown]
# ## Problem
#
# Sampling initializers take distribution parameters. Fill the starter's empty length-5 tensor in place from a normal distribution with mean 2.0 and std 0.0 — a zero standard deviation makes every draw exactly the mean, which is why this output is deterministic. Print with print(w.tolist()).

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# Zero standard deviation makes every normal sample equal the mean.
#
# </details>

# %%
# %pip install -q numpy torch --index-url https://download.pytorch.org/whl/cpu

# %% [markdown]
# ## Your solution
#
# Edit the cell below and run it. Print exactly what the problem asks.

# %%
import torch
torch.manual_seed(0)
w = torch.empty(5)
# TODO: fill w in place
raise NotImplementedError()  # TODO: complete this step
print(w.tolist())
