# %% [markdown]
# # PyTorch Fundamentals: Reduction ops: amax
#
# **Practice notebook — Delta Drills #429**
#
# This drill uses PyTorch, which the Delta Drills in-app runner can't execute. Work it here, run your code, then return to Delta Drills and rate yourself. The full worked answer is in the separate *solution* notebook (Show solution in the app).

# %% [markdown]
# ## Problem
#
# `x` (starter) is a fixed 2×3 float tensor. Reduce it with `torch.amax` to the maximum of each ROW — one value per row, so think about which `dim` gets reduced away. Print the result with print(result.tolist()).

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# Reduce over the column axis to collapse each row to its largest entry.
#
# </details>

# %%
# %pip install -q numpy torch --index-url https://download.pytorch.org/whl/cpu

# %% [markdown]
# ## Your solution
#
# Edit the cell below and run it. Print exactly what the problem asks.

# %%
import torch
x = torch.tensor([[1.0, 5.0, 3.0], [4.0, 2.0, 6.0]])
# TODO: complete this step (see the problem statement above)
result = None  # TODO: fill in result
print(result.tolist())
