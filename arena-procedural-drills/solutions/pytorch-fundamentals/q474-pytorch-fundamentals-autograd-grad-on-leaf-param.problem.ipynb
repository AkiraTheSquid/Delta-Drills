# %% [markdown]
# # PyTorch Fundamentals: Autograd: .grad on leaf parameters
#
# **Practice notebook — Delta Drills #474**
#
# This drill uses PyTorch, which the Delta Drills in-app runner can't execute. Work it here, run your code, then return to Delta Drills and rate yourself. The full worked answer is in the separate *solution* notebook (Show solution in the app).

# %% [markdown]
# ## Problem
#
# The most basic autograd round trip: the starter's `w` requires grad, `x` is a constant. Build the scalar loss — the sum of the elementwise product of `w` and `x` — and backprop it. Predict `w.grad` before running: for this loss you can read it directly off one of the inputs. Print with print(w.grad.tolist()).

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# Differentiate a sum of products with respect to one factor and the other factor is what remains.
#
# </details>

# %%
# %pip install -q numpy torch --index-url https://download.pytorch.org/whl/cpu

# %% [markdown]
# ## Your solution
#
# Edit the cell below and run it. Print exactly what the problem asks.

# %%
import torch
w = torch.tensor([1.0, 2.0, 3.0], requires_grad=True)
x = torch.tensor([4.0, 5.0, 6.0])
# TODO: compute loss
print(w.grad.tolist())
