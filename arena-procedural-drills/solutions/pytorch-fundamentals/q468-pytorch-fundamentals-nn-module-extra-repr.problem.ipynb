# %% [markdown]
# # PyTorch Fundamentals: nn.Module extra_repr
#
# **Practice notebook — Delta Drills #468**
#
# This drill uses PyTorch, which the Delta Drills in-app runner can't execute. Work it here, run your code, then return to Delta Drills and rate yourself. The full worked answer is in the separate *solution* notebook (Show solution in the app).

# %% [markdown]
# ## Problem
#
# `extra_repr` is how a custom Module earns a readable one-line description. Subclass `nn.Module` as `Linear`: store `in_features`, `out_features`, and `bias` as plain attributes in `__init__`, and override `extra_repr` to return the string `in_features=..., out_features=..., bias=...` filled with the stored values (an f-string). Construct `Linear(8, 4, bias=False)` and print the result of calling its `extra_repr()` directly.

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# Store the constructor arguments as attributes and have extra_repr format them into the requested f-string.
#
# </details>

# %%
# %pip install -q numpy torch --index-url https://download.pytorch.org/whl/cpu

# %% [markdown]
# ## Your solution
#
# Edit the cell below and run it. Print exactly what the problem asks.

# %%
import torch.nn as nn

class Linear(nn.Module):
    def __init__(self, in_features, out_features, bias=True):
        super().__init__()
        # TODO: store in_features, out_features, bias as attributes
        raise NotImplementedError()
    def extra_repr(self):
        # TODO: complete this step (see the problem statement above)
        raise NotImplementedError()

m = Linear(8, 4, bias=False)
print(m.extra_repr())
