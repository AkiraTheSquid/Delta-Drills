# %% [markdown]
# # PyTorch Fundamentals: Reduction ops: amax
#
# **Practice notebook — Delta Drills #431**
#
# This drill uses PyTorch, which the Delta Drills in-app runner can't execute. Work it here, run your code, then return to Delta Drills and rate yourself. The full worked answer is in the separate *solution* notebook (Show solution in the app).

# %% [markdown]
# ## Problem
#
# Implement a 2×2, stride-2 max-pool by hand on the starter's (1,1,4,4) tensor. Two steps: carve the two spatial dims into 2×2 windows with `.unfold` (called once per spatial dim — mind its size and step arguments), then reduce BOTH window dims away with a single `.amax` over the two trailing dims. Print the pooled result with print(result.tolist()).

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# Unfold both spatial axes into 2x2 patches, then take the max over the patch dimensions.
#
# </details>

# %%
# %pip install -q numpy torch --index-url https://download.pytorch.org/whl/cpu

# %% [markdown]
# ## Your solution
#
# Edit the cell below and run it. Print exactly what the problem asks.

# %%
import torch
x = torch.tensor([[[[1., 7., 2., 0.],
                    [3., 4., 6., 5.],
                    [8., 1., 9., 2.],
                    [0., 4., 3., 7.]]]])
# TODO: extract 2x2 windows
# then take amax over dim=(4, 5) to max-pool
result = None  # TODO: fill in result
print(result.tolist())
