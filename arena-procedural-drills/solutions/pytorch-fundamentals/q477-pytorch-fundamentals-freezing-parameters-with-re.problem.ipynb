# %% [markdown]
# # PyTorch Fundamentals: Freezing parameters with requires_grad_
#
# **Practice notebook — Delta Drills #477**
#
# This drill uses PyTorch, which the Delta Drills in-app runner can't execute. Work it here, run your code, then return to Delta Drills and rate yourself. The full worked answer is in the separate *solution* notebook (Show solution in the app).

# %% [markdown]
# ## Problem
#
# Calling `requires_grad_(False)` on a MODULE recurses into every parameter. Freeze the starter's 3-layer Sequential with that single call, then print two lines: the list of `requires_grad` flags across all parameters, and the number of trainable parameter ELEMENTS remaining (weight the count by numel, not per-tensor).

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# The call freezes every parameter recursively; count only those whose requires_grad survives.
#
# </details>

# %%
# %pip install -q numpy torch --index-url https://download.pytorch.org/whl/cpu

# %% [markdown]
# ## Your solution
#
# Edit the cell below and run it. Print exactly what the problem asks.

# %%
import torch
import torch.nn as nn

model = nn.Sequential(
    nn.Linear(3, 4),
    nn.ReLU(),
    nn.Linear(4, 2),
)
# TODO: freeze all params
flags = None  # TODO: fill in flags
n_trainable = None  # TODO: fill in n_trainable
print(flags)
print(n_trainable)
