# %% [markdown]
# # PyTorch Fundamentals: BatchNorm variance: biased vs unbiased
#
# **Solution notebook — Delta Drills #453**
#
# Run the cells top-to-bottom to see the reference answer execute.

# %% [markdown]
# ## Problem
#
# Using torch, build the fixed 2x4 tensor x = [[1,2,3,4],[5,6,7,8]] as float32. Compute the variance over ALL elements two ways: biased (unbiased=False, divides by N) and unbiased (unbiased=True, divides by N-1). Print a single list [biased, unbiased] where each value is round(float(v),4). This shows BatchNorm uses the biased estimator while torch's default .var() is unbiased.

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# Call .var twice, toggling the unbiased flag; the only difference is dividing by N versus N-1.
#
# </details>

# %%
# %pip install -q numpy torch --index-url https://download.pytorch.org/whl/cpu

# %% [markdown]
# ## Reference solution

# %%
import torch
x = torch.tensor([[1., 2., 3., 4.], [5., 6., 7., 8.]])
var_biased = x.var(unbiased=False)
var_unbiased = x.var(unbiased=True)
print([round(float(var_biased), 4), round(float(var_unbiased), 4)])

# %% [markdown]
# ## Why this works
#
# Biased variance divides the summed squared deviations by N, unbiased by N-1 (Bessel's correction). For these 8 values the biased value is 5.25 and the unbiased is 6.0; BatchNorm uses the biased estimator while torch's .var() defaults to unbiased.
