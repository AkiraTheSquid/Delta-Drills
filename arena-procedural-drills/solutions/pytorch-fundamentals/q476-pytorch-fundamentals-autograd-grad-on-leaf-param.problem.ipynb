# %% [markdown]
# # PyTorch Fundamentals: Autograd: .grad on leaf parameters
#
# **Practice notebook — Delta Drills #476**
#
# This drill uses PyTorch, which the Delta Drills in-app runner can't execute. Work it here, run your code, then return to Delta Drills and rate yourself. The full worked answer is in the separate *solution* notebook (Show solution in the app).

# %% [markdown]
# ## Problem
#
# The gradient of a MEAN divides by the element count — a classic off-by-factor trap. The starter gives leaf `b` and constant `target`. Build loss = the mean squared error between them, backprop, and print the two gradient components with print(round(float(b.grad[0]), 4), round(float(b.grad[1]), 4)). Then take one SGD step with lr 0.1 inside the starter's `no_grad` block to compute `updated`, and print [round(float(v), 4) for v in updated].

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# Differentiate the mean-squared term, then apply a single gradient-descent step inside a no-grad block.
#
# </details>

# %%
# %pip install -q numpy torch --index-url https://download.pytorch.org/whl/cpu

# %% [markdown]
# ## Your solution
#
# Edit the cell below and run it. Print exactly what the problem asks.

# %%
import torch
b = torch.tensor([2.0, -1.0], requires_grad=True)
target = torch.tensor([0.0, 0.0])
# TODO: compute loss
lr = 0.1
with torch.no_grad():
    updated = None  # TODO: fill in updated
print(round(float(b.grad[0]), 4), round(float(b.grad[1]), 4))
print([round(float(v), 4) for v in updated])
