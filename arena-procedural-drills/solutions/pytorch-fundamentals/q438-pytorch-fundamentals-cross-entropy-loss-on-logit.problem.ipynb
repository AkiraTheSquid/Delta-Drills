# %% [markdown]
# # PyTorch Fundamentals: Cross-Entropy Loss on Logits
#
# **Practice notebook — Delta Drills #438**
#
# This drill uses PyTorch, which the Delta Drills in-app runner can't execute. Work it here, run your code, then return to Delta Drills and rate yourself. The full worked answer is in the separate *solution* notebook (Show solution in the app).

# %% [markdown]
# ## Problem
#
# Cross-entropy in PyTorch is computed straight from LOGITS (pre-softmax scores) — you never softmax first. The starter gives a 2×3 logits batch and integer class targets. Compute the mean cross-entropy with the right `torch.nn.functional` call and print round(float(loss), 4).

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# Pass raw logits and integer targets straight into F.cross_entropy — no manual softmax.
#
# </details>

# %%
# %pip install -q numpy torch --index-url https://download.pytorch.org/whl/cpu

# %% [markdown]
# ## Your solution
#
# Edit the cell below and run it. Print exactly what the problem asks.

# %%
import torch
import torch.nn.functional as F
logits = torch.tensor([[2.0, 0.5, -1.0],
                       [0.1, 1.2, 3.0]])
targets = torch.tensor([0, 2])
# TODO: compute mean cross-entropy
loss = None  # TODO: fill in loss
print(round(float(loss), 4))
