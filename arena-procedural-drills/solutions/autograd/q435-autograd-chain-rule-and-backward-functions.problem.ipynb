# %% [markdown]
# # Autograd: Chain Rule and Backward Functions
#
# **Practice notebook — Delta Drills #435**
#
# This drill uses PyTorch, which the Delta Drills in-app runner can't execute. Work it here, run your code, then return to Delta Drills and rate yourself. The full worked answer is in the separate *solution* notebook (Show solution in the app).

# %% [markdown]
# ## Problem
#
# Backprop through a cube. The starter's `x` requires grad. Compute `out` as x cubed elementwise, then backprop the starter's all-ones upstream gradient through it by passing that gradient to `out.backward(...)`. Before printing, predict `x.grad`: what is the derivative of $x^3$, evaluated at 2, −3, and 4? Print with print(x.grad.tolist()).

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# Differentiate x cubed elementwise (3x^2) and scale by the incoming gradient.
#
# </details>

# %%
# %pip install -q numpy torch --index-url https://download.pytorch.org/whl/cpu

# %% [markdown]
# ## Your solution
#
# Edit the cell below and run it. Print exactly what the problem asks.

# %%
import torch
x = torch.tensor([2.0, -3.0, 4.0], requires_grad=True)
grad_out = torch.tensor([1.0, 1.0, 1.0])
# TODO: compute out
out = None  # TODO: fill in out
out.backward(grad_out)
print(x.grad.tolist())
