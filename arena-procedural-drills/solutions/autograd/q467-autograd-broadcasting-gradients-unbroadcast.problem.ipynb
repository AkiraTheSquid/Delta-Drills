# %% [markdown]
# # Autograd: Broadcasting gradients (unbroadcast)
#
# **Practice notebook — Delta Drills #467**
#
# This drill uses PyTorch, which the Delta Drills in-app runner can't execute. Work it here, run your code, then return to Delta Drills and rate yourself. The full worked answer is in the separate *solution* notebook (Show solution in the app).

# %% [markdown]
# ## Problem
#
# Watch autograd do the unbroadcast for you. The starter defines `x` of shape (1,3) and `y` of shape (2,1), both requiring grad. Add them — broadcasting gives (2,3) — reduce the sum to a scalar, and backprop it. Predict both gradients first: how many broadcast copies does each original element fan out to? Print both with print(x.grad.tolist(), y.grad.tolist()).

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# Each operand's gradient equals the number of times broadcasting replicated it along its size-1 axis.
#
# </details>

# %%
# %pip install -q numpy torch --index-url https://download.pytorch.org/whl/cpu

# %% [markdown]
# ## Your solution
#
# Edit the cell below and run it. Print exactly what the problem asks.

# %%
import torch
x = torch.tensor([[1.0, 2.0, 3.0]], requires_grad=True)  # (1,3)
y = torch.tensor([[1.0],[2.0]], requires_grad=True)       # (2,1)
# TODO: compute z
z = None  # TODO: fill in z
# TODO: complete this step (see the problem statement above)
print(x.grad.tolist(), y.grad.tolist())
