# %% [markdown]
# # Autograd: Global grad-mode flag (torch.set_grad_enabled / no_grad)
#
# **Practice notebook — Delta Drills #472**
#
# This drill uses PyTorch, which the Delta Drills in-app runner can't execute. Work it here, run your code, then return to Delta Drills and rate yourself. The full worked answer is in the separate *solution* notebook (Show solution in the app).

# %% [markdown]
# ## Problem
#
# The global grad flag can be flipped back and forth mid-script. The starter records `prev = torch.is_grad_enabled()` before anything changes. Flip the flag OFF and compute `a` — the sum of `x + 1`; flip it back ON and compute `b` the same way. Predict all three booleans, then print exactly print([a.requires_grad, b.requires_grad, prev]).

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# Capture the default flag first, then observe how each result's requires_grad mirrors the flag state at compute time.
#
# </details>

# %%
# %pip install -q numpy torch --index-url https://download.pytorch.org/whl/cpu

# %% [markdown]
# ## Your solution
#
# Edit the cell below and run it. Print exactly what the problem asks.

# %%
import torch
x = torch.tensor([2.0, 4.0], requires_grad=True)
prev = torch.is_grad_enabled()
# TODO: set global grad flag False, compute a
a = None  # TODO: fill in a
# TODO: set global grad flag True, compute b
b = None  # TODO: fill in b
print([a.requires_grad, b.requires_grad, prev])
