# %% [markdown]
# # Autograd: Global grad-mode flag (torch.set_grad_enabled / no_grad)
#
# **Practice notebook — Delta Drills #471**
#
# This drill uses PyTorch, which the Delta Drills in-app runner can't execute. Work it here, run your code, then return to Delta Drills and rate yourself. The full worked answer is in the separate *solution* notebook (Show solution in the app).

# %% [markdown]
# ## Problem
#
# Autograd has a GLOBAL on/off switch, and it beats per-tensor settings. Flip gradient tracking off globally (the subtopic names the function), then create the starter's `x` (requires_grad=True) and compute `y`, the sum of the elementwise square of `x`. No graph gets built despite `requires_grad=True`. Print two lines: print(y.requires_grad), then print(round(float(y), 4)).

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# The global flag wins over a tensor's requires_grad for graph construction, but it does not change the computed numbers.
#
# </details>

# %%
# %pip install -q numpy torch --index-url https://download.pytorch.org/whl/cpu

# %% [markdown]
# ## Your solution
#
# Edit the cell below and run it. Print exactly what the problem asks.

# %%
import torch
# TODO: turn the global grad-tracking flag OFF
x = torch.tensor([1.0, 2.0, 3.0], requires_grad=True)
# TODO: compute y
y = None  # TODO: fill in y
print(y.requires_grad)
print(round(float(y), 4))
