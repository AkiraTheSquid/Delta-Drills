# %% [markdown]
# # Autograd: Global grad-mode flag (torch.set_grad_enabled / no_grad)
#
# **Solution notebook — Delta Drills #471**
#
# Run the cells top-to-bottom to see the reference answer execute.

# %% [markdown]
# ## Problem
#
# Using torch, flip the global gradient-tracking flag OFF with torch.set_grad_enabled(False). Then create x = torch.tensor([1.0, 2.0, 3.0], requires_grad=True) and compute y = (x * x).sum(). Even though x has requires_grad=True, the global flag suppresses building the autograd graph. Print two lines: first print(y.requires_grad), then print(round(float(y), 4)).

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# The global flag wins over a tensor's requires_grad for graph construction, but it does not change the computed numbers.
#
# </details>

# %%
# %pip install -q numpy torch --index-url https://download.pytorch.org/whl/cpu

# %% [markdown]
# ## Reference solution

# %%
import torch
torch.set_grad_enabled(False)
x = torch.tensor([1.0, 2.0, 3.0], requires_grad=True)
y = (x * x).sum()
print(y.requires_grad)
print(round(float(y), 4))

# %% [markdown]
# ## Why this works
#
# torch.set_grad_enabled(False) flips the global grad-mode flag, which overrides per-tensor requires_grad during forward computation: no autograd graph is built, so y.requires_grad is False. The numeric value is unaffected: 1+4+9 = 14.0.
