# %% [markdown]
# # Autograd: Matrix multiplication backward (dL/dX = dL/dM @ Y^T, dL/dY = X^T @ dL/dM)
#
# **Practice notebook — Delta Drills #451**
#
# This drill uses PyTorch, which the Delta Drills in-app runner can't execute. Work it here, run your code, then return to Delta Drills and rate yourself. The full worked answer is in the separate *solution* notebook (Show solution in the app).

# %% [markdown]
# ## Problem
#
# Apply the matmul backward rules directly — no autograd. For $M = XY$: $\partial L/\partial X = (\partial L/\partial M)\, Y^\top$ and $\partial L/\partial Y = X^\top (\partial L/\partial M)$. The starter gives `X`, `Y`, and `dLdM`. Translate both rules to torch code and print dLdX.tolist() on the first line and dLdY.tolist() on the second.

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# Post-multiply the upstream gradient by Y transposed for dL/dX; pre-multiply by X transposed for dL/dY.
#
# </details>

# %%
# %pip install -q numpy torch --index-url https://download.pytorch.org/whl/cpu

# %% [markdown]
# ## Your solution
#
# Edit the cell below and run it. Print exactly what the problem asks.

# %%
import torch
X = torch.tensor([[2., 0., 1.], [1., 3., 2.]])
Y = torch.tensor([[1., 2.], [0., 1.], [3., 0.]])
dLdM = torch.tensor([[1., 1.], [2., 0.]])
# TODO: apply the matmul backward rules
dLdX = None  # TODO: fill in dLdX
dLdY = None  # TODO: fill in dLdY
print(dLdX.tolist())
print(dLdY.tolist())
