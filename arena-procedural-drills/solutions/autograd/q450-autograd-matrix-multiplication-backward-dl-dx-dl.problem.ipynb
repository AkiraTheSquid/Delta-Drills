# %% [markdown]
# # Autograd: Matrix multiplication backward (dL/dX = dL/dM @ Y^T, dL/dY = X^T @ dL/dM)
#
# **Practice notebook — Delta Drills #450**
#
# This drill uses PyTorch, which the Delta Drills in-app runner can't execute. Work it here, run your code, then return to Delta Drills and rate yourself. The full worked answer is in the separate *solution* notebook (Show solution in the app).

# %% [markdown]
# ## Problem
#
# Autograd through a matmul. The starter's `X` (2×3) and `Y` (3×2) require grad, and an upstream gradient `dLdM` (2×2) is given. Compute the product `M`, then backpropagate the upstream gradient through it by passing it to `M.backward(...)`. Predict the SHAPES of `X.grad` and `Y.grad` before running. Print X.grad.tolist() on the first line and Y.grad.tolist() on the second.

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# Call backward on M with the upstream gradient tensor; let autograd populate X.grad and Y.grad for you.
#
# </details>

# %%
# %pip install -q numpy torch --index-url https://download.pytorch.org/whl/cpu

# %% [markdown]
# ## Your solution
#
# Edit the cell below and run it. Print exactly what the problem asks.

# %%
import torch
X = torch.tensor([[1., 2., 3.], [4., 5., 6.]], requires_grad=True)
Y = torch.tensor([[1., 0.], [0., 1.], [1., 1.]], requires_grad=True)
dLdM = torch.tensor([[1., 2.], [3., 4.]])
# TODO: compute M
raise NotImplementedError()
print(X.grad.tolist())
print(Y.grad.tolist())
