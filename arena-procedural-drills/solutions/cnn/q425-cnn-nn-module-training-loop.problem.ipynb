# %% [markdown]
# # CNN: nn.Module & training loop
#
# **Practice notebook — Delta Drills #425**
#
# This drill uses PyTorch, which the Delta Drills in-app runner can't execute. Work it here, run your code, then return to Delta Drills and rate yourself. The full worked answer is in the separate *solution* notebook (Show solution in the app).

# %% [markdown]
# ## Problem
#
# From memory, write the canonical training step as a single printed string: zero the grads, compute the loss from the forward pass, backpropagate, step the optimizer. Use exactly the four calls `opt.zero_grad()`, `loss = loss_fn(model(x), y)`, `loss.backward()`, `opt.step()`, joined by `; ` in the right ORDER — the order is the drill.

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# Order is zero_grad, forward+loss, backward, step — emit them as one semicolon-joined string.
#
# </details>

# %%
# %pip install -q numpy torch --index-url https://download.pytorch.org/whl/cpu

# %% [markdown]
# ## Your solution
#
# Edit the cell below and run it. Print exactly what the problem asks.

# %%
def solve():
    # Write your solution here
    return None

print(solve())
