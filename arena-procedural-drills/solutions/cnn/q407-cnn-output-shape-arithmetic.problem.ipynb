# %% [markdown]
# # CNN: Output shape & arithmetic
#
# **Practice notebook — Delta Drills #407**
#
# This drill uses PyTorch, which the Delta Drills in-app runner can't execute. Work it here, run your code, then return to Delta Drills and rate yourself. The full worked answer is in the separate *solution* notebook (Show solution in the app).

# %% [markdown]
# ## Problem
#
# Shape arithmetic is easy to get subtly wrong, so verify it empirically. The starter builds `x` of shape (1, 3, 32, 32) and `conv = nn.Conv2d(3, 8, kernel_size=3, stride=2, padding=1)`. Predict the output shape, then run the input through the conv and print the ACTUAL output shape as a plain tuple (wrap the shape in `tuple(...)` for the expected format).

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# Build the actual nn.Conv2d, push a zero tensor through it, and read tuple(out.shape).
#
# </details>

# %%
# %pip install -q numpy torch --index-url https://download.pytorch.org/whl/cpu

# %% [markdown]
# ## Your solution
#
# Edit the cell below and run it. Print exactly what the problem asks.

# %%
import numpy as np

def solve():
    """Verify the output shape of a Conv2d empirically. Input shape (1, 3, 32, 32), kernel=3, stride=2, padding=1, out_channels=8. Print the output shape as tuple.

    Return the value the prompt asks for."""
    raise NotImplementedError()


print(solve())
