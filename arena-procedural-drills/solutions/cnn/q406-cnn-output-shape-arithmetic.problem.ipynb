# %% [markdown]
# # CNN: Output shape & arithmetic
#
# **Practice notebook — Delta Drills #406**
#
# This drill uses PyTorch, which the Delta Drills in-app runner can't execute. Work it here, run your code, then return to Delta Drills and rate yourself. The full worked answer is in the separate *solution* notebook (Show solution in the app).

# %% [markdown]
# ## Problem
#
# Conv output-size arithmetic, one step up: a 224×224 input goes through a conv with kernel 7, stride 2, padding 3 (`H, K, S, P` in the starter). Work out the spatial output side — recall the output-size formula from memory rather than looking it up. Print the result as an int.

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# Apply floor((H + 2P - K)/S + 1); the stride of 2 is what roughly halves the side length.
#
# </details>

# %%
# %pip install -q numpy torch --index-url https://download.pytorch.org/whl/cpu

# %% [markdown]
# ## Your solution
#
# Edit the cell below and run it. Print exactly what the problem asks.

# %%
import numpy as np

def solve():
    """Conv2d output size with stride and padding: input H=W=224, kernel=7, stride=2, padding=3. Compute output side using floor((H+2P-K)/S+1). Print as int.

    Return the value the prompt asks for."""
    raise NotImplementedError()


print(solve())
