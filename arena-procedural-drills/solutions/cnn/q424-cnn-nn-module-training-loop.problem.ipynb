# %% [markdown]
# # CNN: nn.Module & training loop
#
# **Practice notebook — Delta Drills #424**
#
# This drill uses PyTorch, which the Delta Drills in-app runner can't execute. Work it here, run your code, then return to Delta Drills and rate yourself. The full worked answer is in the separate *solution* notebook (Show solution in the app).

# %% [markdown]
# ## Problem
#
# A raw tensor stored as a Module attribute is INVISIBLE to `.parameters()`. Inside a Module subclass's `__init__`, wrap `torch.randn(3, 4)` in the class that registers it as learnable, then print exactly `param_count: N` where N counts the module's parameters (an f-string over the count).

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# nn.Parameter assigned as a Module attribute is auto-registered; count what .parameters() yields.
#
# </details>

# %%
# %pip install -q numpy torch --index-url https://download.pytorch.org/whl/cpu

# %% [markdown]
# ## Your solution
#
# Edit the cell below and run it. Print exactly what the problem asks.

# %%
import numpy as np

def solve():
    """Wrap a raw torch.randn(3, 4) tensor as a learnable parameter on a Module using nn.Parameter. Print whether it appears in .parameters() as `param_count: 1`.

    Return the value the prompt asks for."""
    raise NotImplementedError()


print(solve())
