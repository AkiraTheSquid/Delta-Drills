# %% [markdown]
# # CNN: Pooling, Flatten, BatchNorm
#
# **Practice notebook — Delta Drills #421**
#
# This drill uses PyTorch, which the Delta Drills in-app runner can't execute. Work it here, run your code, then return to Delta Drills and rate yourself. The full worked answer is in the separate *solution* notebook (Show solution in the app).

# %% [markdown]
# ## Problem
#
# BatchNorm tracks its running statistics as BUFFERS, not parameters — so they get no gradients and don't appear in `.parameters()`. Using the starter's `bn = nn.BatchNorm2d(8)`, collect the NAMES of all registered buffers (the module has an API for iterating buffers by name) and print them as a Python list of strings.

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# Enumerate named_buffers and collect their keys; expect the two running stats plus a counter.
#
# </details>

# %%
# %pip install -q numpy torch --index-url https://download.pytorch.org/whl/cpu

# %% [markdown]
# ## Your solution
#
# Edit the cell below and run it. Print exactly what the problem asks.

# %%
import numpy as np

def solve():
    """BatchNorm2d keeps running mean/var as buffers, not parameters. Print the names of all buffers on nn.BatchNorm2d(8) using list(dict(bn.named_buffers()).keys()).

    Return the value the prompt asks for."""
    raise NotImplementedError()


print(solve())
