# %% [markdown]
# # CNN: Pooling, Flatten, BatchNorm
#
# **Practice notebook — Delta Drills #420**
#
# This drill uses PyTorch, which the Delta Drills in-app runner can't execute. Work it here, run your code, then return to Delta Drills and rate yourself. The full worked answer is in the separate *solution* notebook (Show solution in the app).

# %% [markdown]
# ## Problem
#
# How many LEARNABLE parameters does `nn.BatchNorm2d(num_features=32)` carry? Think about which per-channel vectors are learnable and which are running buffers (buffers don't count), then verify by counting parameters programmatically on the starter's `bn`. Print the total as an int.

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# Each learnable BN tensor has num_features entries and there are two of them.
#
# </details>

# %%
# %pip install -q numpy torch --index-url https://download.pytorch.org/whl/cpu

# %% [markdown]
# ## Your solution
#
# Edit the cell below and run it. Print exactly what the problem asks.

# %%
import numpy as np

def solve():
    """Print the number of learnable parameters in nn.BatchNorm2d(num_features=32). Expected: 2 * num_features (weight + bias).

    Return the value the prompt asks for."""
    raise NotImplementedError()


print(solve())
