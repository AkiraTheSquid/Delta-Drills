# %% [markdown]
# # CNN: Output shape & arithmetic
#
# **Practice notebook — Delta Drills #410**
#
# This drill uses PyTorch, which the Delta Drills in-app runner can't execute. Work it here, run your code, then return to Delta Drills and rate yourself. The full worked answer is in the separate *solution* notebook (Show solution in the app).

# %% [markdown]
# ## Problem
#
# Zero-pad a 1-D tensor by hand: from `x = tensor([1, 2, 3, 4])`, produce the length-6 tensor with one 0 on each side. Allocate the padded buffer with `x.new_full` (which preserves `x`'s dtype and device — that's why it beats `torch.zeros` here), then copy `x` into the middle with slice assignment. Print the padded tensor.

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# Allocate a zero buffer two longer than x, then copy x into the middle slice.
#
# </details>

# %%
# %pip install -q numpy torch --index-url https://download.pytorch.org/whl/cpu

# %% [markdown]
# ## Your solution
#
# Edit the cell below and run it. Print exactly what the problem asks.

# %%
import numpy as np

def solve():
    """Pad a 1-D tensor x=tensor([1,2,3,4]) with one zero on each side using new_full to allocate the padded buffer then copy in. Print the result tensor.

    Return the value the prompt asks for."""
    raise NotImplementedError()


print(solve())
