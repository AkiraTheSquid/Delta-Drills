# %% [markdown]
# # CNN: Conv2d module mechanics
#
# **Solution notebook — Delta Drills #414**
#
# Run the cells top-to-bottom to see the reference answer execute.

# %% [markdown]
# ## Problem
#
# Use torch.nn.functional.conv2d to apply a single 3x3 averaging kernel to a (1,1,4,4) ones input. Print the output tensor (use kernel = torch.ones(1,1,3,3)/9).

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# Call F.conv2d(x, k) directly; with all-ones input the averaging kernel returns ones at every valid position.
#
# </details>

# %%
# %pip install -q numpy torch --index-url https://download.pytorch.org/whl/cpu

# %% [markdown]
# ## Reference solution

# %%
import torch
import torch.nn.functional as F

def solve():
    x = torch.ones(1, 1, 4, 4)
    k = torch.ones(1, 1, 3, 3)/9
    return F.conv2d(x, k).detach().numpy()

print(solve())

# %% [markdown]
# ## Why this works
#
# F.conv2d with no padding slides the 3x3 kernel over the 4x4 input giving a 2x2 output. Each window is all ones averaged by the 1/9 kernel, so every output value is 1.0, yielding a (1,1,2,2) tensor of ones.
