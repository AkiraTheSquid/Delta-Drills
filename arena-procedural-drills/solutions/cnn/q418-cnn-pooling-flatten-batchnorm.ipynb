# %% [markdown]
# # CNN: Pooling, Flatten, BatchNorm
#
# **Solution notebook — Delta Drills #418**
#
# Run the cells top-to-bottom to see the reference answer execute.

# %% [markdown]
# ## Problem
#
# Global average pool a (1, 64, 7, 7) feature map down to (1, 64) using x.mean(dim=(2,3)). Print the resulting shape as tuple.

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# Reduce the two spatial axes with mean(dim=(2,3)) and inspect the remaining shape.
#
# </details>

# %%
# %pip install -q numpy torch --index-url https://download.pytorch.org/whl/cpu

# %% [markdown]
# ## Reference solution

# %%
import torch

def solve():
    x = torch.zeros(1, 64, 7, 7)
    return tuple(x.mean(dim=(2,3)).shape)

print(solve())

# %% [markdown]
# ## Why this works
#
# Averaging over dims 2 and 3 collapses the entire spatial grid into a single value per channel, producing (1, 64). This global average pooling is the parameter-free head used before a classifier in many CNNs.
