# %% [markdown]
# # CNN: Conv2d module mechanics
#
# **Practice notebook — Delta Drills #411**
#
# This drill uses PyTorch, which the Delta Drills in-app runner can't execute. Work it here, run your code, then return to Delta Drills and rate yourself. The full worked answer is in the separate *solution* notebook (Show solution in the app).

# %% [markdown]
# ## Problem
#
# The starter builds `conv = nn.Conv2d(3, 16, kernel_size=3)`. In what ORDER does PyTorch lay out a Conv2d weight's four dimensions? Predict it, then check yourself: print the weight's shape as a plain tuple.

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# Read conv.weight.shape and recall the order is out, in, then the kernel height and width.
#
# </details>

# %%
# %pip install -q numpy torch --index-url https://download.pytorch.org/whl/cpu

# %% [markdown]
# ## Your solution
#
# Edit the cell below and run it. Print exactly what the problem asks.

# %%
import numpy as np

def solve():
    """Print the weight shape of a nn.Conv2d(in_channels=3, out_channels=16, kernel_size=3). Expected order is (out_channels, in_channels, kH, kW).

    Return the value the prompt asks for."""
    raise NotImplementedError()


print(solve())
