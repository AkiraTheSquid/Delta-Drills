# %% [markdown]
# # CNN: Pooling, Flatten, BatchNorm
#
# **Practice notebook — Delta Drills #417**
#
# This drill uses PyTorch, which the Delta Drills in-app runner can't execute. Work it here, run your code, then return to Delta Drills and rate yourself. The full worked answer is in the separate *solution* notebook (Show solution in the app).

# %% [markdown]
# ## Problem
#
# Max-pooling with kernel 2 and stride 2 halves each spatial side. The starter defines `x` of shape (1, 4, 8, 8) and the pool module. Apply it and print the output shape as a plain tuple — note which dims changed and which didn't.

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# Pass the tensor through the pool and read the shape; a stride-2 2x2 window halves H and W.
#
# </details>

# %%
# %pip install -q numpy torch --index-url https://download.pytorch.org/whl/cpu

# %% [markdown]
# ## Your solution
#
# Edit the cell below and run it. Print exactly what the problem asks.

# %%
import numpy as np

def solve():
    """Apply nn.MaxPool2d(kernel_size=2, stride=2) to an input of shape (1, 4, 8, 8). Print the output shape as tuple.

    Return the value the prompt asks for."""
    raise NotImplementedError()


print(solve())
