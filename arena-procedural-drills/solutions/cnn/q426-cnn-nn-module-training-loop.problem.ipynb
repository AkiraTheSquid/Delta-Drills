# %% [markdown]
# # CNN: nn.Module & training loop
#
# **Practice notebook — Delta Drills #426**
#
# This drill uses PyTorch, which the Delta Drills in-app runner can't execute. Work it here, run your code, then return to Delta Drills and rate yourself. The full worked answer is in the separate *solution* notebook (Show solution in the app).

# %% [markdown]
# ## Problem
#
# Evaluation code shouldn't build autograd graphs. Inside the starter's `torch.inference_mode()` context, compute the sum of `torch.ones(3)` and print whether the result requires grad. (Compare: outside the context, the same op on a grad-requiring input WOULD track.)

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# Tensors created inside the inference_mode context never track gradients.
#
# </details>

# %%
# %pip install -q numpy torch --index-url https://download.pytorch.org/whl/cpu

# %% [markdown]
# ## Your solution
#
# Edit the cell below and run it. Print exactly what the problem asks.

# %%
import numpy as np

import torch
with torch.inference_mode():
    y = torch.ones(3).sum()

def solve():
    # Write your solution here
    return None

print(solve())
