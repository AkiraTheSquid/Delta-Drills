# %% [markdown]
# # CNN: Conv2d module mechanics
#
# **Solution notebook — Delta Drills #413**
#
# Run the cells top-to-bottom to see the reference answer execute.

# %% [markdown]
# ## Problem
#
# Why is `bias=False` safe when a Conv2d feeds straight into BatchNorm2d? Because BatchNorm's own per-channel shift makes a conv bias redundant. The starter builds the pair as `seq`. Count its learnable parameters — the conv weight plus BatchNorm's weight and bias — and print the total as an int.

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# Sum p.numel() over the Sequential; remember the conv has no bias and BN contributes two vectors of size num_features.
#
# </details>

# %%
# %pip install -q numpy torch --index-url https://download.pytorch.org/whl/cpu

# %% [markdown]
# ## Reference solution

# %%
import torch.nn as nn

def solve():
    seq = nn.Sequential(nn.Conv2d(3, 16, 3, bias=False), nn.BatchNorm2d(16))
    return sum(p.numel() for p in seq.parameters())

print(solve())

# %% [markdown]
# ## Why this works
#
# BatchNorm immediately re-centers and re-scales conv outputs, so any conv bias would be cancelled by BN's mean subtraction, making it redundant. The conv has 16*3*3*3 = 432 weights and no bias; BN adds weight+bias of 16 each, so 432 + 32 = 464 learnable params.
