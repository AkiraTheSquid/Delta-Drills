# %% [markdown]
# # CNN: Pooling, Flatten, BatchNorm
#
# **Practice notebook — Delta Drills #418**
#
# This drill uses PyTorch, which the Delta Drills in-app runner can't execute. Work it here, run your code, then return to Delta Drills and rate yourself. The full worked answer is in the separate *solution* notebook (Show solution in the app).

# %% [markdown]
# ## Problem
#
# Global average pooling collapses each channel's spatial map to a single number. Reduce the starter's (1, 64, 7, 7) feature map `x` to shape (1, 64) by averaging over the spatial dimensions — pick the right `dim` argument yourself. Print the resulting shape as a plain tuple.

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# Reduce the two spatial axes with mean(dim=(2,3)) and inspect the remaining shape.
#
# </details>

# %%
# %pip install -q numpy torch --index-url https://download.pytorch.org/whl/cpu

# %% [markdown]
# ## Your solution
#
# Edit the cell below and run it. Print exactly what the problem asks.

# %%
import numpy as np

def solve():
    """Global average pool a (1, 64, 7, 7) feature map down to (1, 64) using x.mean(dim=(2,3)). Print the resulting shape as tuple.

    Return the value the prompt asks for."""
    raise NotImplementedError()


print(solve())
