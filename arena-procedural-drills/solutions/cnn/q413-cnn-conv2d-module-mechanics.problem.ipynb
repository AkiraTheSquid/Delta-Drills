# %% [markdown]
# # CNN: Conv2d module mechanics
#
# **Practice notebook — Delta Drills #413**
#
# This drill uses PyTorch, which the Delta Drills in-app runner can't execute. Work it here, run your code, then return to Delta Drills and rate yourself. The full worked answer is in the separate *solution* notebook (Show solution in the app).

# %% [markdown]
# ## Problem
#
# Why is `bias=False` safe when a Conv2d feeds straight into BatchNorm2d? Because BatchNorm's own per-channel shift makes a conv bias redundant. The starter builds the pair as `seq`. Count its learnable parameters — the conv weight plus BatchNorm's weight and bias — and print the total as an int.

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# Sum p.numel() over the Sequential; remember the conv has no bias and BN contributes two vectors of size num_features.
#
# </details>

# %%
# %pip install -q numpy torch --index-url https://download.pytorch.org/whl/cpu

# %% [markdown]
# ## Your solution
#
# Edit the cell below and run it. Print exactly what the problem asks.

# %%
import numpy as np

def solve():
    """Why is bias=False used when a Conv2d is immediately followed by BatchNorm2d? Build the pair `nn.Sequential(nn.Conv2d(3,16,3,bias=False), nn.BatchNorm2d(16))` and print the number of learnable parameters using sum(p.numel() for p in seq.parameters()).

    Return the value the prompt asks for."""
    raise NotImplementedError()


print(solve())
