# %% [markdown]
# # CNN: Conv2d module mechanics
#
# **Practice notebook — Delta Drills #412**
#
# This drill uses PyTorch, which the Delta Drills in-app runner can't execute. Work it here, run your code, then return to Delta Drills and rate yourself. The full worked answer is in the separate *solution* notebook (Show solution in the app).

# %% [markdown]
# ## Problem
#
# Conv layers immediately followed by BatchNorm are usually built with `bias=False`. The starter creates such a conv. Confirm the bias really is absent: check the module's `bias` attribute and print exactly `bias is None: True` or `bias is None: False` (an f-string works well).

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# Construct the conv with bias disabled and format whether conv.bias is None into the string.
#
# </details>

# %%
# %pip install -q numpy torch --index-url https://download.pytorch.org/whl/cpu

# %% [markdown]
# ## Your solution
#
# Edit the cell below and run it. Print exactly what the problem asks.

# %%
import numpy as np

def solve():
    """Create nn.Conv2d(3, 16, kernel_size=3, bias=False) and confirm bias is None. Print 'bias is None: True' or False.

    Return the value the prompt asks for."""
    raise NotImplementedError()


print(solve())
