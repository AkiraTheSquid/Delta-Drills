# %% [markdown]
# # CNN: nn.Module & training loop
#
# **Practice notebook — Delta Drills #428**
#
# This drill uses PyTorch, which the Delta Drills in-app runner can't execute. Work it here, run your code, then return to Delta Drills and rate yourself. The full worked answer is in the separate *solution* notebook (Show solution in the app).

# %% [markdown]
# ## Problem
#
# Dropout behaves differently in train vs eval mode, so getting the mode right matters. The starter builds a `Sequential` containing a Dropout and calls `model.eval()`. Print the module flag that records which mode the model is in (the same flag `.train()` and `.eval()` flip).

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# model.eval() sets the training flag — just read it back.
#
# </details>

# %%
# %pip install -q numpy torch --index-url https://download.pytorch.org/whl/cpu

# %% [markdown]
# ## Your solution
#
# Edit the cell below and run it. Print exactly what the problem asks.

# %%
import numpy as np

def solve():
    """Distinguish .train() vs .eval() modes on a Module. Build nn.Sequential(nn.Linear(4,2), nn.Dropout(0.5)), put in eval mode, then print model.training.

    Return the value the prompt asks for."""
    raise NotImplementedError()


print(solve())
