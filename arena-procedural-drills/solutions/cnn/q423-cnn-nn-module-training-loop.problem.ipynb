# %% [markdown]
# # CNN: nn.Module & training loop
#
# **Practice notebook — Delta Drills #423**
#
# This drill uses PyTorch, which the Delta Drills in-app runner can't execute. Work it here, run your code, then return to Delta Drills and rate yourself. The full worked answer is in the separate *solution* notebook (Show solution in the app).

# %% [markdown]
# ## Problem
#
# Subclass `nn.Module`: in `__init__`, call `super().__init__()` and register a single `nn.Linear(4, 2)` as an attribute, and give the class a `forward` that applies it. Instantiate it, predict how many learnable scalars the linear contributes (weight AND bias), then print the parameter count as an int.

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# Register the Linear inside __init__ and sum p.numel() over model.parameters(); count weight plus bias.
#
# </details>

# %%
# %pip install -q numpy torch --index-url https://download.pytorch.org/whl/cpu

# %% [markdown]
# ## Your solution
#
# Edit the cell below and run it. Print exactly what the problem asks.

# %%
import numpy as np

def solve():
    """Subclass nn.Module with a single nn.Linear(4, 2) inside __init__. Print the number of learnable parameters using sum(p.numel() for p in model.parameters()).

    Return the value the prompt asks for."""
    raise NotImplementedError()


print(solve())
