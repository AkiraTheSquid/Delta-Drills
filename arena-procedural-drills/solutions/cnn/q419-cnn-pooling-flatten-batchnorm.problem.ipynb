# %% [markdown]
# # CNN: Pooling, Flatten, BatchNorm
#
# **Practice notebook — Delta Drills #419**
#
# This drill uses PyTorch, which the Delta Drills in-app runner can't execute. Work it here, run your code, then return to Delta Drills and rate yourself. The full worked answer is in the separate *solution* notebook (Show solution in the app).

# %% [markdown]
# ## Problem
#
# Between a conv stack and a linear head, activations of shape (B, C, H, W) must become (B, C·H·W). Apply `nn.Flatten()` (default `start_dim=1`) to the starter's `x` of shape (8, 16, 4, 4) and print the flattened shape as a plain tuple. Why does the default leave dim 0 alone?

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# Flatten everything except the batch dimension; multiply the non-batch dims together.
#
# </details>

# %%
# %pip install -q numpy torch --index-url https://download.pytorch.org/whl/cpu

# %% [markdown]
# ## Your solution
#
# Edit the cell below and run it. Print exactly what the problem asks.

# %%
import numpy as np

def solve():
    """Flatten the output of a conv stack before a linear head. Given x of shape (8, 16, 4, 4), use nn.Flatten() (default start_dim=1) and print the flattened shape.

    Return the value the prompt asks for."""
    raise NotImplementedError()


print(solve())
