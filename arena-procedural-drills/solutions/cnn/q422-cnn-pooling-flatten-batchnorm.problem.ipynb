# %% [markdown]
# # CNN: Pooling, Flatten, BatchNorm
#
# **Practice notebook — Delta Drills #422**
#
# This drill uses PyTorch, which the Delta Drills in-app runner can't execute. Work it here, run your code, then return to Delta Drills and rate yourself. The full worked answer is in the separate *solution* notebook (Show solution in the app).

# %% [markdown]
# ## Problem
#
# Modules record train/eval state on a boolean flag. The starter puts a BatchNorm2d into eval mode — in eval mode it normalizes with running statistics instead of batch statistics. Print the value of the module attribute that records this mode.

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# Switch the module to eval mode and read the boolean training attribute.
#
# </details>

# %%
# %pip install -q numpy torch --index-url https://download.pytorch.org/whl/cpu

# %% [markdown]
# ## Your solution
#
# Edit the cell below and run it. Print exactly what the problem asks.

# %%
import numpy as np

def solve():
    """Toggle a BatchNorm module to eval mode and confirm running stats are used instead of batch stats. After bn.eval(), print bn.training.

    Return the value the prompt asks for."""
    raise NotImplementedError()


print(solve())
