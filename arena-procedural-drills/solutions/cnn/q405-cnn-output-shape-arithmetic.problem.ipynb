# %% [markdown]
# # CNN: Output shape & arithmetic
#
# **Practice notebook — Delta Drills #405**
#
# This drill uses PyTorch, which the Delta Drills in-app runner can't execute. Work it here, run your code, then return to Delta Drills and rate yourself. The full worked answer is in the separate *solution* notebook (Show solution in the app).

# %% [markdown]
# ## Problem
#
# A convolution slides a $K \times K$ kernel with stride $S$ over an input padded by $P$ on each side. For an input of side $H$, the output side is $\lfloor (H + 2P - K)/S \rfloor + 1$.
#
# The starter defines `H, K, S, P` for a 32×32 input, kernel 5, stride 1, no padding. Compute the output side with torch-free integer arithmetic and print it as an int.

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# Plug the four values straight into floor((H + 2P - K)/S + 1) using integer division for the floor.
#
# </details>

# %%
# %pip install -q numpy torch --index-url https://download.pytorch.org/whl/cpu

# %% [markdown]
# ## Your solution
#
# Edit the cell below and run it. Print exactly what the problem asks.

# %%
import numpy as np

def solve():
    """Conv2d output size: given input H=W=32, kernel=5, stride=1, padding=0, compute the spatial output side using floor((H + 2P - K)/S + 1). Print as int.

    Return the value the prompt asks for."""
    raise NotImplementedError()


print(solve())
