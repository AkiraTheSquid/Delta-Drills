# %% [markdown]
# # PyTorch tensors: Core array literacy
#
# **Solution notebook — Delta Drills #19**
#
# Run the cells top-to-bottom to see the reference answer execute.

# %% [markdown]
# ## Problem
#
# Write a function solve(z) that takes a 1-D complex-valued PyTorch tensor and returns a tuple of two real-valued tensors of the same length: the first holding the real part of each entry, the second holding the imaginary part.

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# Complex tensors expose their two components either as tensor attributes or through a matching pair of PyTorch functions.
#
# </details>

# %%
# %pip install -q numpy torch --index-url https://download.pytorch.org/whl/cpu

# %% [markdown]
# ## Reference solution

# %%
import torch as t

def solve(z):
    return z.real, z.imag


example = t.tensor([1 + 2j, 3 + 4j])
print(solve(example))
