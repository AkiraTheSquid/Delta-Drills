# %% [markdown]
# # PyTorch tensors: Indexing and selection
#
# **Solution notebook — Delta Drills #140**
#
# Run the cells top-to-bottom to see the reference answer execute.

# %% [markdown]
# ## Problem
#
# Write a function solve(z, k) that takes a 2-D square integer tensor and an integer offset k (positive, zero, or negative), and returns the SUM of the entries on the k-th diagonal — the main diagonal for k = 0, above it for positive k, below it for negative k — as a plain Python int. (An earlier drill extracts the diagonal; this one reduces it.)

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# Extract the offset diagonal and sum it — or use the trace function, which takes the very same offset directly.
#
# </details>

# %%
# %pip install -q numpy torch --index-url https://download.pytorch.org/whl/cpu

# %% [markdown]
# ## Reference solution

# %%
import torch as t

def solve(z, k):
    return int(t.diag(z, diagonal=k).sum())


example = t.arange(1, 10).reshape(3, 3)
print(solve(example, -1))

# %% [markdown]
# ## Why this works
#
# t.diag(z, k).sum() and t.trace(z, offset=k) both add up the entries z[i, i+k]; trace skips materializing the diagonal. Either way, int(...) converts the PyTorch scalar into the plain int the grader type-checks.
