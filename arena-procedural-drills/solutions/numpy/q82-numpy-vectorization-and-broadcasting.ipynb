# %% [markdown]
# # Numpy: Vectorization and broadcasting
#
# **Solution notebook — Delta Drills #82**
#
# Run the cells top-to-bottom to see the reference answer execute.

# %% [markdown]
# ## Problem
#
# Write a function solve(z) that takes a 2-D numpy integer array and returns an array of the same shape in which entry [i, j] equals the running total of row i from column 0 through column j inclusive (a cumulative sum along each row).

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# The cumulative-sum function takes an axis — choose the one that walks across each row.
#
# </details>

# %%
# %pip install -q numpy

# %% [markdown]
# ## Reference solution

# %%
import numpy as np

def solve(z):
    return z.cumsum(axis=1)


example = np.arange(6).reshape(2, 3)
print(solve(example))

# %% [markdown]
# ## Why this works
#
# z.cumsum(axis=1) accumulates along axis 1, so each row's totals build left to right independently of the other rows. With axis=0 the totals would instead run down the columns — the single-column case distinguishes the two.
