# %% [markdown]
# # Numpy: Applied patterns and advanced
#
# **Solution notebook — Delta Drills #186**
#
# Run the cells top-to-bottom to see the reference answer execute.

# %% [markdown]
# ## Problem
#
# Given an arbitrary array, implement a function that retrieves a fixed-size subarray centered around a specified element, using a specified fill value for any areas outside the original array. (★★★)

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# Compute the centered window's start/stop in Z, clip them to the array bounds, and copy into the aligned slice of a fill-initialized output.
#
# </details>

# %%
# %pip install -q numpy

# %% [markdown]
# ## Reference solution

# %%
import numpy as np

def solve():
    shape = (5, 5)
    fill = 0
    position = (1, 1)
    R = np.ones(shape, dtype=Z.dtype) * fill
    P = np.array(list(position)).astype(int)
    Rs = np.array(list(R.shape)).astype(int)
    Zs = np.array(list(Z.shape)).astype(int)
    R_start = np.zeros((len(shape),)).astype(int)
    R_stop = np.array(list(shape)).astype(int)
    Z_start = (P - Rs // 2)
    Z_stop = (P + Rs // 2) + Rs % 2
    R_start = (R_start - np.minimum(Z_start, 0)).tolist()
    Z_start = (np.maximum(Z_start, 0)).tolist()
    R_stop = np.maximum(R_start, (R_stop - np.maximum(Z_stop - Zs, 0))).tolist()
    Z_stop = (np.minimum(Z_stop, Zs)).tolist()
    r = tuple([slice(start, stop) for start, stop in zip(R_start, R_stop)])
    z = tuple([slice(start, stop) for start, stop in zip(Z_start, Z_stop)])
    R[r] = Z[z]
    return R

# %% [markdown]
# ## Why this works
#
# The window centered at the position may extend past the array edges, so the code computes the desired source range in Z and clips it to valid bounds, then computes the matching destination range in the fill-initialized output R. Copying the clipped Z slice into the corresponding R slice leaves out-of-bounds regions filled with the fill value.
