# %% [markdown]
# # Numpy: Vectorization and broadcasting
#
# **Solution notebook — Delta Drills #153**
#
# Run the cells top-to-bottom to see the reference answer execute.

# %% [markdown]
# ## Problem
#
# Given a 2D array Z, scale each row so that its length becomes 1, ensuring that the operation handles rows that may be zero. (★★★)

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# Take per-row norms with keepdims, then divide using the where/out guard to skip zero-norm rows.
#
# </details>

# %%
# %pip install -q numpy

# %% [markdown]
# ## Reference solution

# %%
import numpy as np

def solve():
    np.random.seed(0)
    Z = np.random.rand(5, 4)
    norms = np.linalg.norm(Z, axis=1, keepdims=True)
    Z_unit = np.divide(Z, norms, out=np.zeros_like(Z), where=norms!=0)
    return Z_unit

print(solve())

# %% [markdown]
# ## Why this works
#
# Compute each row's L2 norm with keepdims so it broadcasts back over the columns. Using np.divide with out and where performs the division only where the norm is nonzero, leaving all-zero rows untouched and so safely avoiding division by zero.
