# %% [markdown]
# # PyTorch tensors: Core array literacy
#
# **Solution notebook — Delta Drills #18**
#
# Run the cells top-to-bottom to see the reference answer execute.

# %% [markdown]
# ## Problem
#
# Write a function solve(z) that takes a 1-D PyTorch tensor of floats that may contain NaN entries (but no infinities) and returns a new tensor in which every NaN has been replaced by 0.0 while every other value is unchanged. Do not modify the input tensor.

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# Either use PyTorch's NaN-replacement helper, or build a boolean NaN mask and select between 0.0 and the original values.
#
# </details>

# %%
# %pip install -q numpy torch --index-url https://download.pytorch.org/whl/cpu

# %% [markdown]
# ## Reference solution

# %%
import torch as t

def solve(z):
    return t.nan_to_num(z, nan=0.0)


example = t.tensor([0.5, t.nan, 1.0])
print(solve(example))

# %% [markdown]
# ## Why this works
#
# t.nan_to_num(z, nan=0.0) returns a copy with NaNs replaced by 0.0. t.where(t.isnan(z), 0.0, z) does the same thing explicitly: NaN never equals anything (even itself), so t.isnan is the only reliable way to find those entries.
