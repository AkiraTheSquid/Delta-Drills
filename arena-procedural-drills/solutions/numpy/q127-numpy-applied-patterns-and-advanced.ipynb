# %% [markdown]
# # PyTorch tensors: Applied patterns and advanced
#
# **Solution notebook — Delta Drills #127**
#
# Run the cells top-to-bottom to see the reference answer execute.

# %% [markdown]
# ## Problem
#
# Write a function solve(z) that takes a 2-D tensor of shape (n, 2) whose rows are 2-D points, and returns the n x n matrix of pairwise Euclidean distances: entry [i, j] is the distance between point i and point j. The diagonal is 0. Do not use Python loops.

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# Insert one new axis on each operand so the points broadcast against each other — the difference tensor then has shape (n, n, 2).
#
# </details>

# %%
# %pip install -q numpy torch --index-url https://download.pytorch.org/whl/cpu

# %% [markdown]
# ## Reference solution

# %%
import torch as t

def solve(z):
    diff = z[:, None, :] - z[None, :, :]
    return t.sqrt((diff ** 2).sum(dim=2))


example = t.tensor([[0.0, 0.0], [3.0, 4.0]])
print(solve(example))

# %% [markdown]
# ## Why this works
#
# z[:, None, :] against z[None, :, :] broadcasts to all (i, j) point pairs at once; squaring, summing the coordinate axis, and square-rooting gives every distance simultaneously. The diagonal is zero because each point's difference with itself vanishes.
