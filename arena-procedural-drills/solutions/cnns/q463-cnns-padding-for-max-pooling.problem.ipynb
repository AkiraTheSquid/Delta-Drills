# %% [markdown]
# # CNNs: Padding for Max Pooling
#
# **Practice notebook — Delta Drills #463**
#
# This drill uses PyTorch, which the Delta Drills in-app runner can't execute. Work it here, run your code, then return to Delta Drills and rate yourself. The full worked answer is in the separate *solution* notebook (Show solution in the app).

# %% [markdown]
# ## Problem
#
# PyTorch's MaxPool pads with $-\infty$, not 0 — so padding can never fabricate a winning value. Build an `nn.MaxPool1d` with kernel 2, stride 2, padding 1, apply it to the starter's all-negative (1,1,6) input, and print exactly print(y[0].tolist()). Look at the edge outputs: real negative values, not 0.

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# Remember which fill value PyTorch's pooling layers use at the boundary, and slide non-overlapping windows of size 2.
#
# </details>

# %%
# %pip install -q numpy torch --index-url https://download.pytorch.org/whl/cpu

# %% [markdown]
# ## Your solution
#
# Edit the cell below and run it. Print exactly what the problem asks.

# %%
import torch
import torch.nn as nn
x = torch.tensor([[[-5.0, -2.0, -9.0, -1.0, -6.0, -8.0]]])
# TODO: complete this step (see the problem statement above)
pool = None  # TODO: fill in pool
y = None  # TODO: fill in y
print(y[0].tolist())
