# %% [markdown]
# # CNNs: Padding for Max Pooling
#
# **Practice notebook — Delta Drills #462**
#
# This drill uses PyTorch, which the Delta Drills in-app runner can't execute. Work it here, run your code, then return to Delta Drills and rate yourself. The full worked answer is in the separate *solution* notebook (Show solution in the app).

# %% [markdown]
# ## Problem
#
# Padding for max-pooling must never beat real values. The starter gives an all-negative 1-D signal. Build a padded sliding max TWICE (pad one cell on each side with `F.pad`, carve windows of size 3, stride 1 with `.unfold`, then take each window's max): once padding with $-\infty$ (correct) and once padding with 0.0 (wrong — 0 outranks every negative at the edges). Print exactly print([correct[0].tolist(), wrong[0].tolist()]).

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# Think about what value, when placed in a window, is guaranteed to lose a max comparison against any real number.
#
# </details>

# %%
# %pip install -q numpy torch --index-url https://download.pytorch.org/whl/cpu

# %% [markdown]
# ## Your solution
#
# Edit the cell below and run it. Print exactly what the problem asks.

# %%
import torch
import torch.nn.functional as F
x = torch.tensor([[-3.0, -1.0, -7.0, -2.0]])
# TODO: pad one cell each side then sliding-max over windows of size 3, stride 1.
# Do it twice: once with value=float('-inf') (correct) and once with value=0.0 (wrong).
correct = None  # TODO: fill in correct
wrong = None  # TODO: fill in wrong
print([correct[0].tolist(), wrong[0].tolist()])
