# %% [markdown]
# # CNNs: BatchNorm per-channel broadcasting
#
# **Practice notebook — Delta Drills #460**
#
# This drill uses PyTorch, which the Delta Drills in-app runner can't execute. Work it here, run your code, then return to Delta Drills and rate yourself. The full worked answer is in the separate *solution* notebook (Show solution in the app).

# %% [markdown]
# ## Problem
#
# A length-C vector broadcasts against a (B, C, H, W) tensor only if its channel axis lines up with dim 1. Reshape the starter's length-4 `weight` so the batch, height, and width axes are singletons and C sits on the channel axis. Print list(shaped.shape).

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# Put the channel count on dim 1 and make the batch and spatial dims singletons.
#
# </details>

# %%
# %pip install -q numpy torch --index-url https://download.pytorch.org/whl/cpu

# %% [markdown]
# ## Your solution
#
# Edit the cell below and run it. Print exactly what the problem asks.

# %%
import torch

C = 4
weight = torch.tensor([1.0, 2.0, 3.0, 4.0])
# TODO: reshape weight to (1, C, 1, 1) so the channel axis lines up
shaped = None  # TODO: fill in shaped
print(list(shaped.shape))
