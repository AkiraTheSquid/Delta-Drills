# %% [markdown]
# # Einops: Rearrange
#
# **Solution notebook — Delta Drills #381**
#
# Run the cells top-to-bottom to see the reference answer execute.

# %% [markdown]
# ## Problem
#
# Write solve(img_a, img_b, img_c, img_d) for four identical-shape (H, W, C) images: combine them into one (2·H, 2·W, C) image laid out as a 2×2 grid, row-major (a top-left, b top-right, c bottom-left, d bottom-right). Pattern: einops.rearrange([a, b, c, d], '(r nc) h w ch -> (r h) (nc w) ch', r=2).

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# '(r nc) h w ch -> (r h) (nc w) ch' with r=2 — 4 images, 2×2 grid, row-major.
#
# </details>

# %%
# %pip install -q numpy einops

# %% [markdown]
# ## Reference solution

# %%
import numpy as np
import einops

arr = np.moveaxis(np.load('/delta_numbers.npy'), 1, -1)
img_a = arr[0]
img_b = arr[0]
img_c = arr[0]
img_d = arr[0]

def solve(img_a, img_b, img_c, img_d):
    return einops.rearrange([img_a, img_b, img_c, img_d], '(r nc) h w ch -> (r h) (nc w) ch', r=2)

print(solve(img_a, img_b, img_c, img_d))

# %% [markdown]
# ## Why this works
#
# The four-image list reads as a batch of (r nc) = (2, 2): r is the grid row, nc the grid column. Output groups (r h)/(nc w) then concatenate rows vertically and columns horizontally — a, b on top; c, d below.
