# %% [markdown]
# # Einops: Deep Learning
#
# **Solution notebook — Delta Drills #322**
#
# Run the cells top-to-bottom to see the reference answer execute.

# %% [markdown]
# ## Problem
#
# Write solve(x, hs, ws) for a (B, C, H, W) batch and integer subgrid factors: carve each image's height into hs strips and width into ws strips, moving the (hs, ws) subgrid indices OUT into the batch axis — output (hs·ws·B, C, H/hs, W/ws), subgrid-major then batch. Pattern: 'b c (h hs) (w ws) -> (hs ws b) c h w'.

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# 'b c (h hs) (w ws) -> (hs ws b) c h w' — subgrid indices move out to the batch.
#
# </details>

# %%
# %pip install -q numpy einops torch --index-url https://download.pytorch.org/whl/cpu

# %% [markdown]
# ## Reference solution

# %%
import torch as t
import einops

arr = t.tensor(np.load('/delta_numbers.npy'))
x = arr[:2]
hs = 2
ws = 2

def solve(x, hs, ws):
    return einops.rearrange(x, 'b c (h hs) (w ws) -> (hs ws b) c h w', hs=hs, ws=ws)

print(solve(x, hs, ws))

# %% [markdown]
# ## Why this works
#
# Each image is carved into an hs×ws grid of sub-images; putting (hs ws b) in the output makes the subgrid position the SLOWEST-varying index — all images' top-left crops first. This is the inverse spirit of a pixel-shuffle: spatial structure trades into the batch axis.
