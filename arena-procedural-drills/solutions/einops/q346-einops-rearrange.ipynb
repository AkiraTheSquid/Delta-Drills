# %% [markdown]
# # Einops: Rearrange
#
# **Solution notebook — Delta Drills #346**
#
# Run the cells top-to-bottom to see the reference answer execute.

# %% [markdown]
# ## Problem
#
# Write a function solve(arr) that takes a channels-FIRST batch (b, c, h, w) and concatenates the images side by side WITHIN the channels-first layout: return shape (c, h, b*w) via 'b c h w -> c h (b w)'. (A companion drill does this for channels-last input.)

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# Batch merges into width with b outermost — but first the axes must be brought adjacent, which the pattern does implicitly.
#
# </details>

# %%
# %pip install -q numpy einops

# %% [markdown]
# ## Reference solution

# %%
import numpy as np
import einops
from einops import rearrange, reduce, repeat

def solve(arr):
    return einops.rearrange(arr, 'b c h w -> c h (b w)')


print(solve(np.arange(8.0).reshape(2, 1, 2, 2)))

# %% [markdown]
# ## Why this works
#
# 'b c h w -> c h (b w)' both permutes (channel and height forward) and merges (batch into width, whole images side by side). In numpy that's a transpose to (c, h, b, w) followed by a reshape — einops fuses the two steps.
