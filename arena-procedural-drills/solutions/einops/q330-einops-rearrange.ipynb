# %% [markdown]
# # Einops: Rearrange
#
# **Solution notebook — Delta Drills #330**
#
# Run the cells top-to-bottom to see the reference answer execute.

# %% [markdown]
# ## Problem
#
# Write a function solve(arr) that takes a batch of shape (b, c, h, w) and returns shape (c, h, w, b) — the batch axis moved to the END, everything else in order.

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# Move the first letter to the end of the output list — one axis relocation.
#
# </details>

# %%
# %pip install -q numpy einops torch --index-url https://download.pytorch.org/whl/cpu

# %% [markdown]
# ## Reference solution

# %%
import torch as t
import einops
from einops import rearrange, reduce, repeat

def solve(arr):
    return einops.rearrange(arr, 'b c h w -> c h w b')


print(solve(t.arange(4.0).reshape(2, 1, 1, 2)))
