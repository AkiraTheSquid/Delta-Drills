# %% [markdown]
# # Einops: Rearrange
#
# **Solution notebook — Delta Drills #404**
#
# Run the cells top-to-bottom to see the reference answer execute.

# %% [markdown]
# ## Problem
#
# Write a function solve(img, p) that takes a channels-first image (c, h*p, w*p) and EXTRACTS its non-overlapping p x p patches: return shape (h*w, c, p, p) — patches listed row-major — via 'c (h p1) (w p2) -> (h w) c p1 p2'. (The inverse of patch reassembly.)

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# Factor both spatial axes into (tile, within-tile) and merge the two tile indices into the leading patch-list axis.
#
# </details>

# %%
# %pip install -q numpy einops torch --index-url https://download.pytorch.org/whl/cpu

# %% [markdown]
# ## Reference solution

# %%
import torch as t
import einops
from einops import rearrange, reduce, repeat

def solve(img, p):
    return einops.rearrange(img, 'c (h p1) (w p2) -> (h w) c p1 p2', p1=p, p2=p)


print(solve(t.arange(16.0).reshape(1, 4, 4), 2))

# %% [markdown]
# ## Why this works
#
# 'c (h p1) (w p2) -> (h w) c p1 p2' is patch extraction — the patchify step of vision transformers — and the exact inverse of the reassembly pattern. Each patch keeps its channels-first layout.
