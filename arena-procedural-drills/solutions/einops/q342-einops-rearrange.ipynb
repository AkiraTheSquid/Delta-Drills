# %% [markdown]
# # Einops: Rearrange
#
# **Solution notebook — Delta Drills #342**
#
# Run the cells top-to-bottom to see the reference answer execute.

# %% [markdown]
# ## Problem
#
# Write a function solve(arr) that takes a channels-last batch (b, h, w, c) and MERGES batch into height: return shape (b*h, w, c), all images stacked top-to-bottom in batch order — 'b h w c -> (b h) w c'.

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# Adjacent axes merging in their existing order is a plain reshape — no transpose needed.
#
# </details>

# %%
# %pip install -q numpy einops torch --index-url https://download.pytorch.org/whl/cpu

# %% [markdown]
# ## Reference solution

# %%
import torch as t
import einops
from einops import rearrange, reduce, repeat

def solve(arr):
    return einops.rearrange(arr, 'b h w c -> (b h) w c')


print(solve(t.arange(8.0).reshape(2, 1, 2, 2)))

# %% [markdown]
# ## Why this works
#
# '(b h)' with b outer keeps each image's rows together, one image below the next — arr.reshape(b*h, w, c). Because b and h are already adjacent and in order, no data movement happens; a vertical filmstrip for free.
