# %% [markdown]
# # Einops: Rearrange
#
# **Solution notebook — Delta Drills #357**
#
# Run the cells top-to-bottom to see the reference answer execute.

# %% [markdown]
# ## Problem
#
# Write solve(img) for a (C, H, W) channels-first image: combine channels and height into one tall strip — output ((C·H), W), channel 0's rows first, then channel 1's, … Pattern: 'c h w -> (c h) w'.

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# 'c h w -> (c h) w' — channels become stacked bands of rows.
#
# </details>

# %%
# %pip install -q numpy einops

# %% [markdown]
# ## Reference solution

# %%
import numpy as np
import einops

arr = np.load('/delta_numbers.npy')
img = arr[0]

def solve(img):
    return einops.rearrange(img, 'c h w -> (c h) w')

print(solve(img))

# %% [markdown]
# ## Why this works
#
# Merging (c h) makes channel the SLOW axis: all of channel 0's rows, then channel 1's, then channel 2's — three grayscale bands stacked vertically. '(h c)' would interleave rows across channels instead; the group order IS the layout.
