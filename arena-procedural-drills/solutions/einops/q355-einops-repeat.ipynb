# %% [markdown]
# # Einops: Repeat
#
# **Solution notebook — Delta Drills #355**
#
# Run the cells top-to-bottom to see the reference answer execute.

# %% [markdown]
# ## Problem
#
# Write a function solve(arr, k) that takes a channels-first batch (b, c, h, w) with b >= 2, keeps the FIRST TWO images, stacks them vertically, and repeats the whole strip k times horizontally: return shape (c, 2*h, k*w) via einops.repeat(arr[:2], 'b c h w -> c (b h) (k w)', k=k).

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# Slice, then one repeat pattern that BOTH merges batch into height and introduces a new horizontal copy index.
#
# </details>

# %%
# %pip install -q numpy einops torch --index-url https://download.pytorch.org/whl/cpu

# %% [markdown]
# ## Reference solution

# %%
import torch as t
import einops
from einops import rearrange, reduce, repeat

def solve(arr, k):
    return einops.repeat(arr[:2], 'b c h w -> c (b h) (k w)', k=k)


print(solve(t.arange(8.0).reshape(2, 1, 2, 2), 2))

# %% [markdown]
# ## Why this works
#
# repeat can merge existing axes and mint new ones simultaneously: '(b h)' stacks the two images top-to-bottom while '(k w)' tiles the result k times across. Slicing first keeps selection out of the pattern.
