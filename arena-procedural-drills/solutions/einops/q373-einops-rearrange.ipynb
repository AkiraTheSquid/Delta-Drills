# %% [markdown]
# # Einops: Rearrange
#
# **Solution notebook — Delta Drills #373**
#
# Run the cells top-to-bottom to see the reference answer execute.

# %% [markdown]
# ## Problem
#
# Write solve(img) for an (H, W, C) image: unroll the CHANNEL dimension along the height axis — all of channel 0's rows, then channel 1's, then channel 2's — with a trailing singleton axis so the result is ((C·H), W, 1). Pattern: 'h w c -> (c h) w ()'.

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# 'h w c -> (c h) w ()' — channel-major row stack plus a trailing singleton.
#
# </details>

# %%
# %pip install -q numpy einops torch --index-url https://download.pytorch.org/whl/cpu

# %% [markdown]
# ## Reference solution

# %%
import torch as t
import einops

arr = t.movedim(t.tensor(np.load('/delta_numbers.npy')), 1, -1)
img = arr[4]

def solve(img):
    return einops.rearrange(img, 'h w c -> (c h) w ()')

print(solve(img))

# %% [markdown]
# ## Why this works
#
# (c h) unrolls the channels into vertical bands (channel-major), and the bare () appends a length-1 axis so downstream code that expects a channel dimension still gets one — a grayscale-shaped (C·H, W, 1) result.
