# %% [markdown]
# # Einops: Rearrange
#
# **Solution notebook — Delta Drills #335**
#
# Run the cells top-to-bottom to see the reference answer execute.

# %% [markdown]
# ## Problem
#
# Write a function solve(img) that takes a channels-last image (h, w, c) and returns the channels-FIRST version (c, h, w).

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# Move the trailing letter to the front — the inverse of the channels-last conversion.
#
# </details>

# %%
# %pip install -q numpy einops torch --index-url https://download.pytorch.org/whl/cpu

# %% [markdown]
# ## Reference solution

# %%
import torch as t
import einops
from einops import rearrange, reduce, repeat

def solve(img):
    return einops.rearrange(img, 'h w c -> c h w')


print(solve(t.arange(6.0).reshape(1, 2, 3)))
