# %% [markdown]
# # Einops: Rearrange
#
# **Solution notebook — Delta Drills #360**
#
# Run the cells top-to-bottom to see the reference answer execute.

# %% [markdown]
# ## Problem
#
# Write a function solve(x2d) that takes a plain 2-D array (h, w) and returns the 3-D version (1, h, w) with a leading singleton channel axis — 'h w -> () h w'.

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# A leading '()' output group adds the channel axis a grayscale image needs to enter image pipelines.
#
# </details>

# %%
# %pip install -q numpy einops

# %% [markdown]
# ## Reference solution

# %%
import numpy as np
import einops
from einops import rearrange, reduce, repeat

def solve(x2d):
    return einops.rearrange(x2d, 'h w -> () h w')


print(solve(np.ones((2, 3))))

# %% [markdown]
# ## Why this works
#
# rearrange(x2d, 'h w -> () h w') equals x2d[None]: a 1-channel channels-first image. The inverse '() h w -> h w' strips the axis back off (and errors helpfully if it isn't singleton — unlike silent squeeze).
