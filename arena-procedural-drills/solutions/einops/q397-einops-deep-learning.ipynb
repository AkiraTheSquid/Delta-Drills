# %% [markdown]
# # Einops: Deep Learning
#
# **Solution notebook — Delta Drills #397**
#
# Run the cells top-to-bottom to see the reference answer execute.

# %% [markdown]
# ## Problem
#
# Write a function solve(arr) that takes a batch (b, c, h, w) and returns shape (h, w, b*c): spatial axes leading, batch and channels merged (batch slowest) at the END — 'b c h w -> h w (b c)'.

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# Permute spatial to the front, then merge the two remaining axes in their stated order.
#
# </details>

# %%
# %pip install -q numpy einops torch --index-url https://download.pytorch.org/whl/cpu

# %% [markdown]
# ## Reference solution

# %%
import torch as t
import einops
from einops import rearrange, reduce, repeat

def solve(arr):
    return einops.rearrange(arr, 'b c h w -> h w (b c)')


print(solve(t.arange(8.0).reshape(2, 1, 2, 2)))

# %% [markdown]
# ## Why this works
#
# 'b c h w -> h w (b c)' treats every (image, channel) combination as one plane and stacks those planes along a trailing axis — transpose then reshape, with b outer so each image's channels stay adjacent.
