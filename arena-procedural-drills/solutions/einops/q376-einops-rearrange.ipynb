# %% [markdown]
# # Einops: Rearrange
#
# **Solution notebook — Delta Drills #376**
#
# Run the cells top-to-bottom to see the reference answer execute.

# %% [markdown]
# ## Problem
#
# Write solve(img_a, img_b) for two identical-shape (H, W, C) images: place them SIDE BY SIDE into one (H, 2·W, C) image, img_a on the left. Pattern: einops.rearrange([img_a, img_b], 'b h w c -> h (b w) c').

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# 'b h w c -> h (b w) c' — the (b w) group lays the images side by side.
#
# </details>

# %%
# %pip install -q numpy einops

# %% [markdown]
# ## Reference solution

# %%
import numpy as np
import einops

arr = np.moveaxis(np.load('/delta_numbers.npy'), 1, -1)
img_a = arr[0]
img_b = arr[0]

def solve(img_a, img_b):
    return einops.rearrange([img_a, img_b], 'b h w c -> h (b w) c')

print(solve(img_a, img_b))

# %% [markdown]
# ## Why this works
#
# The list becomes a batch axis; putting b BEFORE w in the output group means all of image a's columns come before image b's — side by side, a on the left. '(w b)' would interleave columns instead.
