# %% [markdown]
# # Einsum: Vectorization and broadcasting
#
# **Solution notebook — Delta Drills #296**
#
# Run the cells top-to-bottom to see the reference answer execute.

# %% [markdown]
# ## Problem
#
# Write a function solve(x) that takes a 2-D tensor of shape (t, d) and returns the (t, t, d) tensor whose entry [i, j] holds the ELEMENTWISE product of rows i and j — the per-feature interaction of every pair of rows (d is NOT summed).

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# Two row letters, one shared feature letter kept in the output — pairs multiply feature-by-feature without any summing.
#
# </details>

# %%
# %pip install -q numpy torch --index-url https://download.pytorch.org/whl/cpu

# %% [markdown]
# ## Reference solution

# %%
import torch as t

def solve(x):
    return t.einsum('id,jd->ijd', x, x)


print(solve(t.tensor([[1.0, 2.0], [3.0, 4.0]])))

# %% [markdown]
# ## Why this works
#
# einsum('id,jd->ijd', x, x) aligns every row pair on the shared d and keeps d in the output, so nothing contracts — the elementwise pair products that, once summed over d ('id,jd->ij'), would become the Gram matrix.
