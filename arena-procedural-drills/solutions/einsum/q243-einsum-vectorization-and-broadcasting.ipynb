# %% [markdown]
# # Einsum: Vectorization and broadcasting
#
# **Solution notebook — Delta Drills #243**
#
# Run the cells top-to-bottom to see the reference answer execute.

# %% [markdown]
# ## Problem
#
# Write a function solve(u, v) that takes two batches of vectors — u of shape (b, i) and v of shape (b, j) — and returns the batch of OUTER PRODUCTS: a (b, i, j) array where entry [n] is the outer product of u[n] with v[n] (every element of u[n] times every element of v[n]). Einsum states it directly; broadcasting works too.

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# Keep the batch index on both sides of the arrow, keep i and j separate in the output, and contract over nothing.
#
# </details>

# %%
# %pip install -q numpy einops

# %% [markdown]
# ## Reference solution

# %%
import numpy as np

def solve(u, v):
    return np.einsum('bi,bj->bij', u, v)


print(solve(np.array([[1.0, 2.0]]), np.array([[3.0, 4.0, 5.0]])))

# %% [markdown]
# ## Why this works
#
# einsum('bi,bj->bij', u, v) shares the batch index b, and because both i and j survive to the output with no repeated summation index, every element of u[n] multiplies every element of v[n] — a batch of outer products. u[:, :, None] * v[:, None, :] broadcasts to the identical result.
