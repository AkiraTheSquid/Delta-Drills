# %% [markdown]
# # Einsum: Applied patterns and advanced
#
# **Solution notebook — Delta Drills #311**
#
# Run the cells top-to-bottom to see the reference answer execute.

# %% [markdown]
# ## Problem
#
# Write a function solve(a, v, b) that takes an (i, j) matrix a, a length-j vector v representing a DIAGONAL matrix, and a (j, k) matrix b, and returns the (i, k) product a @ diag(v) @ b — without ever materializing the diagonal matrix.

# %% [markdown]
# <details><summary>💡 Hint (click to reveal)</summary>
#
# A diagonal matrix in a product just scales along the shared index — write the vector with that single letter between the two matrices.
#
# </details>

# %%
# %pip install -q numpy torch --index-url https://download.pytorch.org/whl/cpu

# %% [markdown]
# ## Reference solution

# %%
import torch as t

def solve(a, v, b):
    return t.einsum('ij,j,jk->ik', a, v, b)


print(solve(t.eye(2), t.tensor([2.0, 3.0]), t.eye(2)))

# %% [markdown]
# ## Why this works
#
# einsum('ij,j,jk->ik', a, v, b) scales the j-axis by v during the contraction, computing a @ diag(v) @ b without building the n x n diagonal — the standard trick for factorized or spectral forms like U diag(s) V^T.
