# %% [markdown]
# # linalg-solve-batched — faded example 3: Multi-RHS batched solve — fill in the b shape and call
#
# > Faded drill from [Delta Drills](https://delta-drills.vercel.app). Atom: `linalg-solve-batched`. Running the beacon reports progress on the `PyTorch: Batched linalg.solve` subtopic.
#
# **Most of the solution is filled in — complete the one blanked step**, run the test, then fire the beacon. Less scaffolding than the worked example, more than the full drill.

# %% [markdown]
# ## Setup

# %%
import numpy as np
import torch as t
from torch import Tensor
import einops
from einops import rearrange, reduce, repeat

t.manual_seed(0)
np.random.seed(0)

# %% [markdown]
# ## Connect to Delta Drills
#
# Paste your Delta Drills auth token below so this drill can report progress on the `PyTorch: Batched linalg.solve` subtopic. Copy it from your Delta Drills account page.
#
# This standalone exercises the atom **`linalg-solve-batched`** (exercise 1). Completion fires the beacon at the bottom.

# %%
# === Delta Drills auth ===
DD_TOKEN = ""  # paste your token here, then run this cell
DD_ATOM_ID = "linalg-solve-batched"
DD_SUBTOPIC = "PyTorch: Batched linalg.solve"
DD_BACKEND_URL = "https://delta-drills-backend.fly.dev"

_dd_passed = set()

# %% [markdown]
# ## Concept
#
# When each of K systems has M right-hand sides, `b` should have shape `(K, n, M)`. Pass it directly to `t.linalg.solve(A, b)` — the function handles the additional trailing dimension and returns `x: (K, n, M)`.

# %% [markdown]
# ## Faded exercise 3
#
# Stack M individual right-hand side vectors into a `(K, n, M)` tensor `B`, then fill in the single batched solve call.
#
# **Fill in:** Call t.linalg.solve with A and B where B has shape (K, n, M) to solve all systems at once.

# %%
import torch as t

t.manual_seed(5)
K, n, M = 3, 4, 6
A = t.randn(K, n, n) + 4 * t.eye(n)
B = t.randn(K, n, M)  # M right-hand sides per system

X = None  # TODO: Call t.linalg.solve with A and B where B has shape (K, n, M) to solve all systems at once.


def _test():
    import torch as t

    assert X is not None
    assert X.shape == (K, n, M), f'expected ({K},{n},{M}) got {X.shape}'
    residual = (A @ X - B).abs().max().item()
    assert residual < 1e-4, f'residual too large: {residual}'


try:
    _test()
    _dd_passed.add('faded3')
    print('[Delta Drills] faded3 passed.')
except AssertionError as _e:
    print('Test failed:', _e)

# %% [markdown]
# ## Report completion
#
# Run the cell below to report progress. The beacon fires only if the test above passed.

# %%
# === Delta Drills completion beacon ===
import urllib.request as _dd_req, json as _dd_json

_DD_REQUIRED = {'faded3'}

def report_completion():
    missing = _DD_REQUIRED - _dd_passed
    if missing:
        print(f"[Delta Drills] {sorted(missing)} not yet passing — fix the cell above, then re-run this one.")
        return
    if not DD_TOKEN:
        print('[Delta Drills] DD_TOKEN is empty — completion not reported.')
        return
    body = _dd_json.dumps({
        'exercise_title': f'procedural-drill:{DD_ATOM_ID}:faded1',
        'subtopics': [DD_SUBTOPIC],
        'feedback': 'somewhat',
        'correct': True,
    }).encode('utf-8')
    req = _dd_req.Request(
        f'{DD_BACKEND_URL}/api/practice/arena-rating',
        data=body,
        headers={
            'Content-Type': 'application/json',
            'Authorization': f'Bearer {DD_TOKEN}',
        },
        method='POST',
    )
    try:
        with _dd_req.urlopen(req, timeout=5) as r:
            resp = _dd_json.loads(r.read())
        print(f'[Delta Drills] reported {DD_ATOM_ID} (subtopic={DD_SUBTOPIC!r})')
        print(f'[Delta Drills] EWMA updated: {resp}')
    except Exception as e:
        print(f'[Delta Drills] beacon failed: {e}')

report_completion()

# %% [markdown]
# <details><summary>Solution</summary>
#
# ```python
# import torch as t
#
# t.manual_seed(5)
# K, n, M = 3, 4, 6
# A = t.randn(K, n, n) + 4 * t.eye(n)
# B = t.randn(K, n, M)
#
# X = t.linalg.solve(A, B)
# ```
# </details>
