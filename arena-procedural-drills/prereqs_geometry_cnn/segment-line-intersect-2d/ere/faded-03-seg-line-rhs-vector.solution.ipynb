# %% [markdown]
# # segment-line-intersect-2d — faded example 3: Form the right-hand side vector b = L0 - S0
#
# > Practice drill from [Delta Drills](https://delta-drills.vercel.app). Atom: `segment-line-intersect-2d`. The last cell reports your progress on the `Geometry: Segment-line intersect 2-D` subtopic back to Delta Drills.
#
# **Most of the code is already written — complete the one blanked step**, run the test to check it, then run the last cell to record your progress.

# %% [markdown]
# ## Setup

# %%
import numpy as np
import torch as t
from torch import Tensor
import einops
from einops import rearrange, reduce, repeat

t.manual_seed(0)
np.random.seed(0)
import matplotlib.pyplot as plt

# %% [markdown]
# ## Connect to Delta Drills
#
# Paste your Delta Drills auth token below so this drill can report progress on the `Geometry: Segment-line intersect 2-D` subtopic. Copy it from your Delta Drills account page.
#
# This standalone exercises the atom **`segment-line-intersect-2d`** (exercise 1). Completion fires the beacon at the bottom.

# %%
# === Delta Drills auth ===
DD_TOKEN = ""  # paste your token here, then run this cell
DD_ATOM_ID = "segment-line-intersect-2d"
DD_SUBTOPIC = "Geometry: Segment-line intersect 2-D"
DD_BACKEND_URL = "https://delta-drills-backend.fly.dev"

_dd_passed = set()

# %% [markdown]
# ## Concept
#
# _First time on this topic? Run the **Setup** cell above and skim it: every class and helper mentioned below is defined there. You don't need to have done any other drill first._
#
# In the parametric intersection system, the right-hand side of the equation is `b = L0 - S0`, the vector from the segment's start point to a point on the line. This makes sense geometrically: both the t*d term and the s*e term are measured from S0, so the displacement to reach the line must also be measured from S0. Getting this sign wrong (e.g. writing `S0 - L0`) gives a reflected solution.

# %% [markdown]
# ## Faded exercise 3
#
# Given specific 2D points, set up the complete solve for segment (S0, S1) vs line through (L0, L1) and verify the intersection point.
#
# 1. Compute d, e.
# 2. Build A = stack([d, -e], dim=1).
# 3. Compute the right-hand side b.
# 4. Solve and return the t_seg parameter.
#
# The blank step is forming the right-hand side b correctly.
#
# **Your task:** complete the one blanked step in the code cell below. The surrounding code, function signatures, and variable names are given — work out the missing expression yourself, then run the test.

# %%
import torch as t

t.manual_seed(0)

S0 = t.tensor([1.0, 1.0])
S1 = t.tensor([5.0, 3.0])
L0 = t.tensor([3.0, 0.0])
L1 = t.tensor([3.0, 5.0])

d = S1 - S0
e = L1 - L0
A = t.stack([d, -e], dim=1)
b = L0 - S0
ts = t.linalg.solve(A, b)
t_seg = ts[0].item()
hit = (0.0 <= t_seg <= 1.0)

print(f't_seg={t_seg:.4f}  hit={hit}')
pt = S0 + t_seg * d
print(f'Intersection point: {pt.tolist()}')


def _test():
    import torch as t

    S0 = t.tensor([1.0, 1.0])
    S1 = t.tensor([5.0, 3.0])
    L0 = t.tensor([3.0, 0.0])
    L1 = t.tensor([3.0, 5.0])

    d = S1 - S0
    e = L1 - L0
    A = t.stack([d, -e], dim=1)
    b_ref = L0 - S0
    assert t.allclose(b, b_ref, atol=1e-5), f'b={b} expected={b_ref}'
    # the resulting t_seg should place intersection at x=3
    ts_ref = t.linalg.solve(A, b_ref)
    t_ref = ts_ref[0].item()
    assert abs(t_seg - t_ref) < 1e-5
    pt = S0 + t_seg * d
    assert abs(pt[0].item() - 3.0) < 1e-4, f'x coord: {pt[0].item()}'


try:
    _test()
    _dd_passed.add('faded3')
    print('[Delta Drills] faded3 passed.')
except AssertionError as _e:
    print('Test failed:', _e)

# %% [markdown]
# ## Report your progress
#
# Run the cell below to send your progress to Delta Drills. It only counts if the test above passed.

# %%
# === Delta Drills completion beacon ===
import urllib.request as _dd_req, json as _dd_json

_DD_REQUIRED = {'faded3'}

def report_completion():
    missing = _DD_REQUIRED - _dd_passed
    if missing:
        print(f"[Delta Drills] {sorted(missing)} not yet passing — fix the cell above, then re-run this one.")
        return
    if not DD_TOKEN:
        print('[Delta Drills] DD_TOKEN is empty — completion not reported.')
        return
    body = _dd_json.dumps({
        'exercise_title': f'procedural-drill:{DD_ATOM_ID}:faded1',
        'subtopics': [DD_SUBTOPIC],
        'feedback': 'somewhat',
        'correct': True,
    }).encode('utf-8')
    req = _dd_req.Request(
        f'{DD_BACKEND_URL}/api/practice/arena-rating',
        data=body,
        headers={
            'Content-Type': 'application/json',
            'Authorization': f'Bearer {DD_TOKEN}',
        },
        method='POST',
    )
    try:
        with _dd_req.urlopen(req, timeout=5) as r:
            resp = _dd_json.loads(r.read())
        print(f'[Delta Drills] reported {DD_ATOM_ID} (subtopic={DD_SUBTOPIC!r})')
        print(f'[Delta Drills] EWMA updated: {resp}')
    except Exception as e:
        print(f'[Delta Drills] beacon failed: {e}')

report_completion()

# %% [markdown]
# <details><summary>Solution</summary>
#
# ```python
# import torch as t
#
# t.manual_seed(0)
#
# S0 = t.tensor([1.0, 1.0])
# S1 = t.tensor([5.0, 3.0])
# L0 = t.tensor([3.0, 0.0])
# L1 = t.tensor([3.0, 5.0])
#
# d = S1 - S0
# e = L1 - L0
# A = t.stack([d, -e], dim=1)
# b = L0 - S0
# ts = t.linalg.solve(A, b)
# t_seg = ts[0].item()
# hit = (0.0 <= t_seg <= 1.0)
#
# print(f't_seg={t_seg:.4f}  hit={hit}')
# pt = S0 + t_seg * d
# print(f'Intersection point: {pt.tolist()}')
# ```
# </details>
