# %% [markdown]
# # ray-parametric-form — faded example 3: Solve for u at the y=0 plane crossing
#
# > Faded drill from [Delta Drills](https://delta-drills.vercel.app). Atom: `ray-parametric-form`. Running the beacon reports progress on the `Geometry: Ray parametric form` subtopic.
#
# **Most of the solution is filled in — complete the one blanked step**, run the test, then fire the beacon. Less scaffolding than the worked example, more than the full drill.

# %% [markdown]
# ## Setup

# %%
import numpy as np
import torch as t
from torch import Tensor
import einops
from einops import rearrange, reduce, repeat

t.manual_seed(0)
np.random.seed(0)
import matplotlib.pyplot as plt

# %% [markdown]
# ## Connect to Delta Drills
#
# Paste your Delta Drills auth token below so this drill can report progress on the `Geometry: Ray parametric form` subtopic. Copy it from your Delta Drills account page.
#
# This standalone exercises the atom **`ray-parametric-form`** (exercise 1). Completion fires the beacon at the bottom.

# %%
# === Delta Drills auth ===
DD_TOKEN = ""  # paste your token here, then run this cell
DD_ATOM_ID = "ray-parametric-form"
DD_SUBTOPIC = "Geometry: Ray parametric form"
DD_BACKEND_URL = "https://delta-drills-backend.fly.dev"

_dd_passed = set()

# %% [markdown]
# ## Concept
#
# The ground plane `y = 0` intersection parameter is `u = -O.y / D.y`. This algebraic rearrangement of `O.y + u * D.y = 0` is used in every ray-ground intersection test. Once you have `u`, substitute back into `R(u) = O + u * D` to get the hit point.

# %% [markdown]
# ## Faded exercise 3
#
# ### Exercise — Solve for u at y=0 crossing
#
# Complete `ray_y0_hit(ray)`. Return `(u_hit, hit_point)` where `u_hit = -O[1] / D[1]` and `hit_point = O + u_hit * D`.
#
# Fill in the formula for u_hit.
#
# **Fill in:** Compute u_hit as -O[1] / D[1], the parameter value where the ray's y-coordinate reaches zero.

# %%
import torch as t

def ray_y0_hit(ray: t.Tensor):
    O, D = ray[0], ray[1]
    u_hit = None  # TODO: Compute u_hit as -O[1] / D[1], the parameter value where the ray's y-coordinate reaches zero.
    hit_point = O + u_hit * D
    return u_hit, hit_point

t.manual_seed(72)
O = t.tensor([0.0, 4.0, 0.0])
D = t.tensor([1.0, -2.0, 0.0])
ray = t.stack([O, D])
u, H = ray_y0_hit(ray)
print(f'u={u.item()}, H.y={H[1].item():.6f}')


def _test():
    import torch as t
    # Ray from y=4 pointing down
    O = t.tensor([0.0, 4.0, 0.0])
    D = t.tensor([1.0, -2.0, 0.0])
    ray = t.stack([O, D])
    u, H = ray_y0_hit(ray)
    assert abs(u.item() - 2.0) < 1e-5, f'u should be 2.0, got {u.item()}'
    assert abs(H[1].item()) < 1e-5, f'H.y should be ~0, got {H[1].item()}'
    assert u.item() > 0, 'u should be positive (hit in front)'
    # Verify H is on the ray
    expected_H = O + u * D
    assert t.allclose(H, expected_H)


try:
    _test()
    _dd_passed.add('faded3')
    print('[Delta Drills] faded3 passed.')
except AssertionError as _e:
    print('Test failed:', _e)

# %% [markdown]
# ## Report completion
#
# Run the cell below to report progress. The beacon fires only if the test above passed.

# %%
# === Delta Drills completion beacon ===
import urllib.request as _dd_req, json as _dd_json

_DD_REQUIRED = {'faded3'}

def report_completion():
    missing = _DD_REQUIRED - _dd_passed
    if missing:
        print(f"[Delta Drills] {sorted(missing)} not yet passing — fix the cell above, then re-run this one.")
        return
    if not DD_TOKEN:
        print('[Delta Drills] DD_TOKEN is empty — completion not reported.')
        return
    body = _dd_json.dumps({
        'exercise_title': f'procedural-drill:{DD_ATOM_ID}:faded1',
        'subtopics': [DD_SUBTOPIC],
        'feedback': 'somewhat',
        'correct': True,
    }).encode('utf-8')
    req = _dd_req.Request(
        f'{DD_BACKEND_URL}/api/practice/arena-rating',
        data=body,
        headers={
            'Content-Type': 'application/json',
            'Authorization': f'Bearer {DD_TOKEN}',
        },
        method='POST',
    )
    try:
        with _dd_req.urlopen(req, timeout=5) as r:
            resp = _dd_json.loads(r.read())
        print(f'[Delta Drills] reported {DD_ATOM_ID} (subtopic={DD_SUBTOPIC!r})')
        print(f'[Delta Drills] EWMA updated: {resp}')
    except Exception as e:
        print(f'[Delta Drills] beacon failed: {e}')

report_completion()

# %% [markdown]
# <details><summary>Solution</summary>
#
# ```python
# import torch as t
#
# def ray_y0_hit(ray: t.Tensor):
#     O, D = ray[0], ray[1]
#     u_hit = -O[1] / D[1]
#     hit_point = O + u_hit * D
#     return u_hit, hit_point
#
# t.manual_seed(72)
# O = t.tensor([0.0, 4.0, 0.0])
# D = t.tensor([1.0, -2.0, 0.0])
# ray = t.stack([O, D])
# u, H = ray_y0_hit(ray)
# print(f'u={u.item()}, H.y={H[1].item():.6f}')
# ```
# </details>
