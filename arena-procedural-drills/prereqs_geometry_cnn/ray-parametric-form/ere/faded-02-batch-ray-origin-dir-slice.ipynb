# %% [markdown]
# # ray-parametric-form — faded example 2: Slice batch ray origins and directions
#
# > Practice drill from [Delta Drills](https://delta-drills.vercel.app). Atom: `ray-parametric-form`. The last cell reports your progress on the `Geometry: Ray parametric form` subtopic back to Delta Drills.
#
# **Most of the code is already written — complete the one blanked step**, run the test to check it, then run the last cell to record your progress.

# %% [markdown]
# ## Setup

# %%
import numpy as np
import torch as t
from torch import Tensor
import einops
from einops import rearrange, reduce, repeat

t.manual_seed(0)
np.random.seed(0)
import matplotlib.pyplot as plt

# %% [markdown]
# ## Connect to Delta Drills
#
# Paste your Delta Drills auth token below so this drill can report progress on the `Geometry: Ray parametric form` subtopic. Copy it from your Delta Drills account page.
#
# This standalone exercises the atom **`ray-parametric-form`** (exercise 1). Completion fires the beacon at the bottom.

# %%
# === Delta Drills auth ===
DD_TOKEN = ""  # paste your token here, then run this cell
DD_ATOM_ID = "ray-parametric-form"
DD_SUBTOPIC = "Geometry: Ray parametric form"
DD_BACKEND_URL = "https://delta-drills-backend.fly.dev"

_dd_passed = set()

# %% [markdown]
# ## Concept
#
# _First time on this topic? Run the **Setup** cell above and skim it: every class and helper mentioned below is defined there. You don't need to have done any other drill first._
#
# For a batch of rays stored as `(B, 2, 3)`, origins are `rays[:, 0]` (shape `(B, 3)`) and directions are `rays[:, 1]` (shape `(B, 3)`). Slicing correctly is the first step before any evaluation. After slicing, the point batch `O + u * D` follows by simple scalar-tensor broadcasting.

# %% [markdown]
# ## Faded exercise 2
#
# ### Exercise — Slice origins and directions from batch rays
#
# Complete `eval_batch_rays(rays, u)`. Given `rays` of shape `(B, 2, 3)` and scalar `u`, return the `(B, 3)` endpoints.
#
# Fill in the slicing and the parametric evaluation.
#
# **Your task:** complete the one blanked step in the code cell below. The surrounding code, function signatures, and variable names are given — work out the missing expression yourself, then run the test.

# %%
import torch as t

def eval_batch_rays(rays: t.Tensor, u: float) -> t.Tensor:
    raise NotImplementedError()  # TODO: fill in this step — read the prompt cell above

t.manual_seed(71)
B = 6
origins = t.randn(B, 3)
dirs = t.randn(B, 3)
rays = t.stack([origins, dirs], dim=1)
pts = eval_batch_rays(rays, 2.0)
print(pts.shape)


def _test():
    import torch as t
    t.manual_seed(71)
    B = 6
    origins = t.randn(B, 3)
    dirs = t.randn(B, 3)
    rays = t.stack([origins, dirs], dim=1)
    pts = eval_batch_rays(rays, 2.0)
    assert pts.shape == (B, 3)
    # u=0 -> origins
    pts0 = eval_batch_rays(rays, 0.0)
    assert t.equal(pts0, origins)
    # u=1 -> origins + dirs
    pts1 = eval_batch_rays(rays, 1.0)
    assert t.allclose(pts1, origins + dirs)


try:
    _test()
    _dd_passed.add('faded2')
    print('[Delta Drills] faded2 passed.')
except AssertionError as _e:
    print('Test failed:', _e)

# %% [markdown]
# ## Report your progress
#
# Run the cell below to send your progress to Delta Drills. It only counts if the test above passed.

# %%
# === Delta Drills completion beacon ===
import urllib.request as _dd_req, json as _dd_json

_DD_REQUIRED = {'faded2'}

def report_completion():
    missing = _DD_REQUIRED - _dd_passed
    if missing:
        print(f"[Delta Drills] {sorted(missing)} not yet passing — fix the cell above, then re-run this one.")
        return
    if not DD_TOKEN:
        print('[Delta Drills] DD_TOKEN is empty — completion not reported.')
        return
    body = _dd_json.dumps({
        'exercise_title': f'procedural-drill:{DD_ATOM_ID}:faded1',
        'subtopics': [DD_SUBTOPIC],
        'feedback': 'somewhat',
        'correct': True,
    }).encode('utf-8')
    req = _dd_req.Request(
        f'{DD_BACKEND_URL}/api/practice/arena-rating',
        data=body,
        headers={
            'Content-Type': 'application/json',
            'Authorization': f'Bearer {DD_TOKEN}',
        },
        method='POST',
    )
    try:
        with _dd_req.urlopen(req, timeout=5) as r:
            resp = _dd_json.loads(r.read())
        print(f'[Delta Drills] reported {DD_ATOM_ID} (subtopic={DD_SUBTOPIC!r})')
        print(f'[Delta Drills] EWMA updated: {resp}')
    except Exception as e:
        print(f'[Delta Drills] beacon failed: {e}')

report_completion()

# %% [markdown]
# <details><summary>Solution</summary>
#
# ```python
# import torch as t
#
# def eval_batch_rays(rays: t.Tensor, u: float) -> t.Tensor:
#     O = rays[:, 0]
#     D = rays[:, 1]
#     return O + u * D
#
# t.manual_seed(71)
# B = 6
# origins = t.randn(B, 3)
# dirs = t.randn(B, 3)
# rays = t.stack([origins, dirs], dim=1)
# pts = eval_batch_rays(rays, 2.0)
# print(pts.shape)
# ```
# </details>
