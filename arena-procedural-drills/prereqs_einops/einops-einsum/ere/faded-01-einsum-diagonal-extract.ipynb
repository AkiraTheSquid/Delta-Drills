# %% [markdown]
# # einops-einsum — faded example 1: Extract the diagonal of a square matrix
#
# > Practice drill from [Delta Drills](https://delta-drills.vercel.app). Atom: `einops-einsum`. The last cell reports your progress on the `Einops: Deep Learning` subtopic back to Delta Drills.
#
# **Most of the code is already written — complete the one blanked step**, run the test to check it, then run the last cell to record your progress.

# %% [markdown]
# ## Setup

# %%
import numpy as np
import torch as t
from torch import Tensor
import einops
from einops import einsum

t.manual_seed(0)
np.random.seed(0)

# %% [markdown]
# ## Connect to Delta Drills
#
# Paste your Delta Drills auth token below so this drill can report progress on the `Einops: Deep Learning` subtopic.
# You can copy the token from your Delta Drills account page.
#
# This drill exercises the **atom `einops-einsum`**, which bridges to the bank subtopic `Einops: Deep Learning` for EWMA state. Completing all 5 exercises triggers a single `arena-rating` beacon at the end of the notebook.

# %%
# === Delta Drills auth ===
DD_TOKEN = ""  # paste your token here, then run this cell
DD_ATOM_ID = "einops-einsum"
DD_SUBTOPIC = "Einops: Deep Learning"
DD_BACKEND_URL = "https://delta-drills-backend.fly.dev"

# Track which exercises passed in this session.
_dd_passed = set()

# %% [markdown]
# ## Concept
#
# _First time on this topic? Run the **Setup** cell above and skim it: every class and helper mentioned below is defined there. You don't need to have done any other drill first._
#
# Repeating a single index letter on **one operand** (`'i i'`) selects the diagonal. The difference from the trace is what you put on the output: keep `i` on the output (`-> i`) to *return* the diagonal vector instead of summing it away.

# %% [markdown]
# ## Faded exercise 1
#
# ### Faded — diagonal extraction
#
# Implement `diagonal_via_einsum(A)` for a square `(n, n)` tensor so it returns the length-`n` vector of diagonal entries `A[i, i]`.
#
# Use a single `einops.einsum` call. The body has been removed — fill in the one `einsum` pattern that selects the diagonal *and keeps it* (does not reduce it). Equivalent to `torch.diagonal(A)`.
#
# **Your task:** complete the one blanked step in the code cell below. The surrounding code, function signatures, and variable names are given — work out the missing expression yourself, then run the test.

# %%
def diagonal_via_einsum(A: Tensor) -> Tensor:
    raise NotImplementedError()  # TODO: fill in this step — read the prompt cell above


def _test():
    t.manual_seed(1)
    A = t.randn(6, 6)
    out = diagonal_via_einsum(A)
    ref = t.diagonal(A)
    assert tuple(out.shape) == (6,), f'expected shape (6,), got {tuple(out.shape)}'
    assert t.allclose(out, ref, atol=1e-6), 'diagonal values do not match torch.diagonal'
    A2 = t.eye(4) * 3.0
    assert t.allclose(diagonal_via_einsum(A2), t.full((4,), 3.0), atol=1e-6)


try:
    _test()
    _dd_passed.add('faded1')
    print('[Delta Drills] faded1 passed.')
except AssertionError as _e:
    print('Test failed:', _e)

# %% [markdown]
# ## Report your progress
#
# Run the cell below to send your progress to Delta Drills. It only counts if the test above passed.

# %%
# === Delta Drills completion beacon ===
import urllib.request as _dd_req, json as _dd_json

_DD_REQUIRED = {'faded1'}

def report_completion():
    missing = _DD_REQUIRED - _dd_passed
    if missing:
        print(f"[Delta Drills] {sorted(missing)} not yet passing — fix the cell above, then re-run this one.")
        return
    if not DD_TOKEN:
        print('[Delta Drills] DD_TOKEN is empty — completion not reported.')
        return
    body = _dd_json.dumps({
        'exercise_title': f'procedural-drill:{DD_ATOM_ID}:faded1',
        'subtopics': [DD_SUBTOPIC],
        'feedback': 'somewhat',  # single-exercise standalone — neutral signal
        'correct': True,
    }).encode('utf-8')
    req = _dd_req.Request(
        f'{DD_BACKEND_URL}/api/practice/arena-rating',
        data=body,
        headers={
            'Content-Type': 'application/json',
            'Authorization': f'Bearer {DD_TOKEN}',
        },
        method='POST',
    )
    try:
        with _dd_req.urlopen(req, timeout=5) as r:
            resp = _dd_json.loads(r.read())
        print(f'[Delta Drills] reported {DD_ATOM_ID} (subtopic={DD_SUBTOPIC!r})')
        print(f'[Delta Drills] EWMA updated: {resp}')
    except Exception as e:
        print(f'[Delta Drills] beacon failed: {e}')

report_completion()

# %% [markdown]
# <details><summary>Solution</summary>
#
# ```python
# def diagonal_via_einsum(A: Tensor) -> Tensor:
#     return einsum(A, 'i i -> i')
# ```
# </details>
